# %%
from hypergraphs import *
from kegg import *
import pandas as pd
import os
import logging

from Bio.KEGG.KGML.KGML_parser import read
import Bio.KEGG.KGML.KGML_pathway
from ast import literal_eval
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
import requests
from Levenshtein import ratio
import scipy.stats
import pathlib
from qf.cc import cardon_crochemore_colored, cardon_crochemore
import random

from reportlab.lib.units import inch
import PIL.Image
from io import BytesIO
import reportlab.pdfgen.canvas
import reportlab.lib.colors

# %%
organismDict = {"hsa": "Homo sapiens (human)"}
outputDirectory = "/Users/boldi/Desktop/pw/"
inputDirectory = "../../LaTeX/Data/KEGG-Pathways/Feb2024/"
dataDirectory = "../../LaTeX/Data/KEGG-Pathways"

# %%
pathwaylistFilename = "KEGG-pathways.txt"  # In inputDirectory, csv: ID, type, name
superpathway = "All"                  # Name of the superpathway
organism = "hsa"
confidence = 0.05

produceGraphsWithCCcoloring = False
produceGraphsWithAnomalies = True
useCCcoloringForAnomalies = False
produceAnomaliesForNonsignificantPairs = True

# %%
safeSuperpathway = makesafe(superpathway)

# %%
pws = pd.read_csv(os.path.join(inputDirectory, "KEGG-pathways.txt"), 
            names=["Pathway ID", "Pathway type", "Pathway name"], dtype="string", keep_default_na=False)

# %%
superpathwayDict = {
    superpathway: [(x,y) for x,y in zip(pws["Pathway ID"], pws["Pathway name"])]
}

# %%
def words2set(words):
    """
        Given a space-separated list of words, returns it as a set of words
    """
    return set(words.split())

# %%
from typing import NamedTuple

class Relation(NamedTuple):
    """
        Represents a relation. It is characterized by:
        - a type (e.g. "PPRel") 
        - a list of subtypes (e.g. [('activation', '-->'), ('indirect effect', '..>')])
        - a set of components (source)
        - a list of sets of components (target)
    """
    relType: str
    relSubtypes: list
    source: set
    target: list
    sourceg: Bio.KEGG.KGML.KGML_pathway.Graphics
    targetg: Bio.KEGG.KGML.KGML_pathway.Graphics
        
    @classmethod
    def fromKEGG(cls, relation, pathway):
        """
            Constructor: builds a Relation from a KEGG relation
        """
        if relation.entry2.name == "undefined":
            s = []
            for component in relation.entry2.components:
                s += [words2set(pathway.entries[component.id].name)]
            targetg = pathway.entries[component.id].graphics[0]
        else:
            s = [words2set(relation.entry2.name)]
            targetg = relation.entry2.graphics[0]
        return cls(relation.type, relation.subtypes, words2set(relation.entry1.name), s, targetg, relation.entry1.graphics[0])

# %%
def relationsFromKEGGpathway(pathway):
    """
        Given a KEGG pathway, returns the list of relations it contains (represented as Relation).
    """
    return [Relation.fromKEGG(r, pathway) for r in pathway.relations]

# %%
def pathwayFromFile(dataDirectory, organism, pathwayID):
    """
        Load and return a KEGG pathway, given the data directory, the organism specifying the subdirectory,
        and the pathwayID (the filename should be organism+pathwayID+"xml".
    """
    return KGML_parser.read(open(os.path.join(dataDirectory, organism, organism+pathwayID+".xml"), "r"))

# %%
def relationsFromFile(dataDirectory, organism, pathwayID):
    """
        Given a pathway file (specified by a root dataDirectory, the name of the organism subdirectory, and the name
        of the file [organism+pathwayID.xml]), reads it and returns the list of its relations.
    """
    pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
    return relationsFromKEGGpathway(pathway)

# %%
def relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway):
    """
        Given a superpathDict (whose keys are superpathway names and whose values are list of
        pairs (pathwayID, pathwayName)), reads all the pathway file for a specific superpathway name
        and returns a dictionary whose keys are the pathwayID's and whose values are the list of relations.
    """
    rel = {}
    for k,v in superpathwayDict[superpathway]:
        #logging.info("Reading", k, v)
        rel[k] = relationsFromFile(dataDirectory, organism, k)
    return rel

# %%
def subtypes(rel):
    """
        Given a map whose values are relations, accumulate all subtypes appearing and assign them a number.
        The result is a map from subtype string to number.
    """
    all_subtypes = set([])
    for pathwayid, relations in rel.items():
        for relation in relations:
            all_subtypes |= set([str(relation.relSubtypes)])
        
    s = sorted(list(all_subtypes))
    subtype2color = {v:k for k,v in enumerate(s)}
    color2subtype = {k:v for k,v in enumerate(s)}

    return subtype2color, color2subtype

# %%
def set2can(s):
    """
        Convert a set to a string in a canonical way.
    """
    return str(sorted(list(s)))

def can2set(c):
    """
        Does the converse of set2can.
    """
    return set(literal_eval(c))

# %%
def indices(rel):
    """
        Given a map whose values are lists of relations, it considers all the relations one by one, and attributes a unique id 
        to each element (i.e., set of components appearing as source or in the target of some relation) and block (the set of
        element id appearing as target of some relation).
        This function returns the dictionaries to move from/to an element or block to the corresponding id.
        Elements are string representations of sorted lists of strings.
        Blocks are string representations of sorted lists of ints.
    """
    element2id = {}
    id2element = {}
    block2id = {}
    id2block = {}

    for relations in rel.values():
        for relation in relations:
            s = set2can(relation.source)
            if s not in element2id.keys():
                element2id[s] = len(element2id)
            targetset = set([])
            for targ in relation.target:
                t = set2can(targ)
                if t not in element2id.keys():
                    element2id[t] = len(element2id)
                targetset |= set([element2id[t]])
            ts = set2can(targetset)
            if ts not in block2id.keys():
                block2id[ts] = len(block2id)

    for k,v in element2id.items():
        id2element[v] = k
    for k,v in block2id.items():
        id2block[v] = k
    return element2id, id2element, block2id, id2block

# %%
def search_gene_KEGG(geneID):
    """
        Search for gene on KEGG. 
        
        Returns list of names.
    """
    url1 = "https://www.kegg.jp/entry/"+geneID
    response1 = requests.get(url1, allow_redirects=False)    
    soup = BeautifulSoup(response1.text, "html.parser")
    tds = [tds for tds in soup.find_all("td", {"class": "td11 defd"})]
    names = tds[0].getText().strip().split(", ")
    return names

# %%
def get_temp_imagefilename(url):
    """Return filename of temporary file containing downloaded image.

    Create a new temporary file to hold the image file at the passed URL
    and return the filename.
    """
    img = urlopen(url).read()
    im = PIL.Image.open(BytesIO(img))
    # im.transpose(Image.FLIP_TOP_BOTTOM)
    f = tempfile.NamedTemporaryFile(delete=False, suffix=".png")
    fname = f.name
    f.close()
    im.save(fname, "PNG")
    return fname


#def enhance_method(klass, method_name, replacement):
#    'replace a method with an enhanced version'
#    method = getattr(klass, method_name)
#    def enhanced(*args, **kwds): return replacement(*args, **kwds)
#    setattr(klass, method_name, enhanced)

def new_draw(self, filename, relations, elaborateArc = None):
        """Add the map elements to the drawing."""
        # Instantiate the drawing, first
        # size x_max, y_max for now - we can add margins, later
        if self.import_imagemap:
            # We're drawing directly on the image, so we set the canvas to the
            # same size as the image
            if os.path.isfile(self.pathway.image):
                imfilename = self.pathway.image
            else:
                imfilename = get_temp_imagefilename(self.pathway.image)
            im = PIL.Image.open(imfilename)
            cwidth, cheight = im.size
        else:
            # No image, so we set the canvas size to accommodate visible
            # elements
            cwidth, cheight = (self.pathway.bounds[1][0], self.pathway.bounds[1][1])
        # Instantiate canvas
        self.drawing = reportlab.pdfgen.canvas.Canvas(
            filename,
            bottomup=0,
            pagesize=(
                cwidth * (1 + 2 * self.margins[0]),
                cheight * (1 + 2 * self.margins[1]),
            ),
        )
        self.drawing.setFont(self.fontname, self.fontsize)
        # Transform the canvas to add the margins
        self.drawing.translate(
            self.margins[0] * self.pathway.bounds[1][0],
            self.margins[1] * self.pathway.bounds[1][1],
        )
        # Add the map image, if required
        if self.import_imagemap:
            self.drawing.saveState()
            self.drawing.scale(1, -1)
            self.drawing.translate(0, -cheight)
            self.drawing.drawImage(imfilename, 0, 0)
            self.drawing.restoreState()
        # Add the reactions, compounds and maps
        # Maps go on first, to be overlaid by more information.
        # By default, they're slightly transparent.
        if self.show_maps:
            self.__add_maps()
        if self.show_reaction_entries:
            KGMLCanvas._KGMLCanvas__add_reaction_entries(self)
        if self.show_orthologs:
            KGMLCanvas._KGMLCanvas__add_orthologs(self)
        if self.show_compounds:
            KGMLCanvas._KGMLCanvas__add_compounds(self)
        if self.show_genes:
            KGMLCanvas._KGMLCanvas__add_genes(self)
        # TODO: complete draw_relations code
        # if self.draw_relations:
        #    self.__add_relations()
        # Write the pathway map to PDF
        if elaborateArc is not None:
            for relation in relations:
                elaborateArc(relation, self.drawing)
        self.drawing.save()
        
#enhance_method(KGMLCanvas, 'draw',  new_draw)
setattr(KGMLCanvas, 'new_draw', new_draw)

# %%
# Build all data needed for the relations of the superpathway
rel = relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway)
element2id, id2element, block2id, id2block = indices(rel)
subtype2color, color2subtype = subtypes(rel)
elements = list(set.union(*[can2set(k) for k in element2id.keys()]))

# %%
# name2gene is a function mapping names to gene IDs (hsa:xxxx)
# e.g. KCNE3, BRGDA6 etc are all mapped to hsa:10008 (see https://www.kegg.jp/entry/hsa:10008)
# This map was produced by scraping kegg, but this has been done only once.
# After that, we just read a pkl file

name2keggFilename = os.path.join(inputDirectory, "name2kegg.pkl")

if os.path.exists(name2keggFilename):
    print("Reading gene names")
    with open(name2keggFilename, "rb") as handle:
        name2gene = pickle.load(handle)
else:
    print("Producing gene names")
    d = {}
    nelements = len(elements)
    for count,element in enumerate(elements):
        if count % 10 == 0:
            print(f"{count}/{nelements}")
        if element.startswith("hsa"):
            names = search_gene_KEGG(element)
            for name in names:
                d[name] = element
    with open(name2keggFilename, "wb") as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
    name2gene = d
# Out:
# Reading gene names

# %%
# Read patient data
print("Reading patient data")
genes = pd.read_csv(os.path.join(inputDirectory, "genes.csv"), dtype={"name": str})
patients = genes["name"].values.tolist()
classification = pd.read_csv(os.path.join(inputDirectory, "classification.csv"), dtype={"name": str})

patient2class = {patient: classification.loc[classification["name"]==patient]["classification"].values.flatten().tolist()[0] for patient in patients}
numHealthy = sum([x == 'healthy' for x in patient2class.values()])
numDiseased = sum([x == 'diseased' for x in patient2class.values()])
# Out:
# Reading patient data

# %%
# Dividing genes into two frames (one for healthy individuals and one for diseased individuals)
genesHealthy = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="healthy"]
genesDiseased = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="diseased"]

# %%
# Building the graph of all relations contained in rel values
# Nodes are IDs, and node x correspond to the set of genes (and/or compound) id2element[x]
print("Building the relation graph")
G = nx.DiGraph() 
for pathwayID, relations in rel.items():
    for relation in relations:
        source = element2id[set2can(relation.source)]
        for targ in relation.target:
            target = element2id[set2can(targ)]
            newType = str(relation.relSubtypes)
            color = subtype2color[newType]
            pl = []
            if G.has_edge(source, target):
                d = G.get_edge_data(source, target)
                if d["color"] != color:
                    oldType = color2subtype[d["color"]]
                    print("- Edge ({},{}) of type {} for {} appears as {} for {}. ".format(
                        source, target, color2subtype[d["color"]], d["pathwayIDs"], 
                        str(relation.relSubtypes), pathwayID
                    ), end="")
                    if oldType[1:-1] in newType[1:-1]:
                        print("Overwriting with type {}".format(newType))
                    elif newType[1:-1] in oldType[1:-1]:
                        print("Overwriting with type {}".format(oldType))
                        color = subtype2color[oldType]
                    else:
                        print("\n****Conflict! Rewriting as {}".format(newType))
                pl = d["pathwayIDs"]
            G.add_edge(source, target, color=color, pathwayIDs=pl + [pathwayID])
            

# Computing the minimum fibres
cc=cardon_crochemore_colored(G)

colors = list(matplotlib.colors.CSS4_COLORS.values())
usedColors = 0

cc2fibresize = {}
cc2fibre = {}
ccnontrivial = {}
nontrivialclass2col = {}

fibres = []
node2fibre = {}
for v in set(cc.values()):
    fibre = [x for x in G.nodes() if cc[x] == v]
    fibres += [fibre]
    for x in fibre:
        node2fibre[x] = fibre
    cc2fibre[v] = fibre
    cc2fibresize[v] = len(fibre)
    if len(fibre) > 0:
        ccnontrivial[v] = cc[v]
        nontrivialclass2col[v] = colors[usedColors]
        usedColors = (usedColors + 1 ) % len(colors)
        if usedColors == 0:
            print("Wrap: more than", len(colors), "colors needed")
# Out:
# Building the relation graph
# - Edge (0,1) of type [('compound', 94)] for ['00010', '00010'] appears as [('compound', 93)] for 00010.
# ****Conflict! Rewriting as [('compound', 93)]
# - Edge (0,3) of type [('compound', 94)] for ['00010'] appears as [('compound', 93)] for 00010.
# ****Conflict! Rewriting as [('compound', 93)]
# - Edge (0,3) of type [('compound', 93)] for ['00010', '00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (22,30) of type [('compound', 90)] for ['00010'] appears as [('compound', 91)] for 00010.
# ****Conflict! Rewriting as [('compound', 91)]
# - Edge (30,0) of type [('compound', 93)] for ['00010', '00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (59,62) of type [('compound', 330)] for ['00230'] appears as [('compound', 392)] for 00230.
# ****Conflict! Rewriting as [('compound', 392)]
# - Edge (67,63) of type [('compound', 355)] for ['00230'] appears as [('compound', 343)] for 00230.
# ****Conflict! Rewriting as [('compound', 343)]
# - Edge (73,63) of type [('compound', 392)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (71,36) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (71,60) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (48,49) of type [('compound', 377)] for ['00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (59,63) of type [('compound', 392)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (62,63) of type [('compound', 392)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (67,72) of type [('compound', 343)] for ['00230', '00230', '00230', '00230'] appears as [('compound', 332)] for 00230.
# ****Conflict! Rewriting as [('compound', 332)]
# - Edge (67,63) of type [('compound', 343)] for ['00230', '00230'] appears as [('compound', 332)] for 00230.
# ****Conflict! Rewriting as [('compound', 332)]
# - Edge (42,36) of type [('compound', 330)] for ['00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (42,64) of type [('compound', 330)] for ['00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (36,64) of type [('compound', 330)] for ['00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (64,80) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (64,66) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (80,66) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (36,63) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (36,64) of type [('compound', 325)] for ['00230', '00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (60,63) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (60,64) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (63,64) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (64,66) of type [('compound', 326)] for ['00230', '00230'] appears as [('compound', 366)] for 00230.
# ****Conflict! Rewriting as [('compound', 366)]
# - Edge (66,63) of type [('compound', 332)] for ['00230'] appears as [('compound', 355)] for 00230.
# ****Conflict! Rewriting as [('compound', 355)]
# - Edge (67,65) of type [('compound', 343)] for ['00230'] appears as [('compound', 355)] for 00230.
# ****Conflict! Rewriting as [('compound', 355)]
# - Edge (35,64) of type [('compound', 365)] for ['00230'] appears as [('compound', 357)] for 00230.
# ****Conflict! Rewriting as [('compound', 357)]
# - Edge (35,38) of type [('compound', 362)] for ['00230'] appears as [('compound', 360)] for 00230.
# ****Conflict! Rewriting as [('compound', 360)]
# - Edge (40,38) of type [('compound', 362)] for ['00230'] appears as [('compound', 360)] for 00230.
# ****Conflict! Rewriting as [('compound', 360)]
# - Edge (36,83) of type [('compound', 380)] for ['00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (67,84) of type [('compound', 320)] for ['00230'] appears as [('compound', 356)] for 00230.
# ****Conflict! Rewriting as [('compound', 356)]
# - Edge (36,83) of type [('compound', 325)] for ['00230', '00230'] appears as [('compound', 390)] for 00230.
# ****Conflict! Rewriting as [('compound', 390)]
# - Edge (38,83) of type [('compound', 380)] for ['00230'] appears as [('compound', 390)] for 00230.
# ****Conflict! Rewriting as [('compound', 390)]
# - Edge (55,83) of type [('compound', 380)] for ['00230'] appears as [('compound', 390)] for 00230.
# ****Conflict! Rewriting as [('compound', 390)]
# - Edge (36,40) of type [('compound', 362)] for ['00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (36,38) of type [('compound', 362)] for ['00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (36,36) of type [('compound', 362)] for ['00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (40,38) of type [('compound', 360)] for ['00230', '00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (40,36) of type [('compound', 362)] for ['00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (40,38) of type [('compound', 324)] for ['00230', '00230', '00230'] appears as [('compound', 322)] for 00230.
# ****Conflict! Rewriting as [('compound', 322)]
# - Edge (68,64) of type [('compound', 325)] for ['00230'] appears as [('compound', 321)] for 00230.
# ****Conflict! Rewriting as [('compound', 321)]
# - Edge (67,64) of type [('compound', 367)] for ['00230'] appears as [('compound', 320)] for 00230.
# ****Conflict! Rewriting as [('compound', 320)]
# - Edge (59,36) of type [('compound', 330)] for ['00230'] appears as [('compound', 368)] for 00230.
# ****Conflict! Rewriting as [('compound', 368)]
# - Edge (38,36) of type [('compound', 324)] for ['00230'] appears as [('compound', 369)] for 00230.
# ****Conflict! Rewriting as [('compound', 369)]
# - Edge (36,36) of type [('compound', 324)] for ['00230', '00230'] appears as [('compound', 369)] for 00230.
# ****Conflict! Rewriting as [('compound', 369)]
# - Edge (71,63) of type [('compound', 365)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (71,64) of type [('compound', 365)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (38,36) of type [('compound', 369)] for ['00230', '00230'] appears as [('compound', 214)] for 00240.
# ****Conflict! Rewriting as [('compound', 214)]
# - Edge (36,40) of type [('compound', 324)] for ['00230', '00230'] appears as [('compound', 214)] for 00240.
# ****Conflict! Rewriting as [('compound', 214)]
# - Edge (36,64) of type [('compound', 365)] for ['00230', '00230', '00230'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (38,93) of type [('compound', 217)] for ['00240'] appears as [('compound', 194)] for 00240.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (36,91) of type [('compound', 191)] for ['00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (38,36) of type [('compound', 214)] for ['00230', '00230', '00240'] appears as [('compound', 194)] for 00240.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (90,91) of type [('compound', 191)] for ['00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (36,36) of type [('compound', 369)] for ['00230', '00230', '00230'] appears as [('compound', 194)] for 00240.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (38,91) of type [('compound', 191)] for ['00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (36,91) of type [('compound', 213)] for ['00240', '00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (94,95) of type [('compound', 212)] for ['00240'] appears as [('compound', 188)] for 00240.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (64,95) of type [('compound', 212)] for ['00240'] appears as [('compound', 188)] for 00240.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (36,91) of type [('compound', 185)] for ['00240', '00240', '00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (36,64) of type [('compound', 213)] for ['00230', '00230', '00230', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (92,91) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (94,91) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (64,91) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (100,102) of type [('compound', 210)] for ['00240'] appears as [('compound', 202)] for 00240.
# ****Conflict! Rewriting as [('compound', 202)]
# - Edge (92,64) of type [('compound', 213)] for ['00240'] appears as [('compound', 221)] for 00240.
# ****Conflict! Rewriting as [('compound', 221)]
# - Edge (102,103) of type [('compound', 209)] for ['00240'] appears as [('compound', 203)] for 00240.
# ****Conflict! Rewriting as [('compound', 203)]
# - Edge (36,91) of type [('compound', 187)] for ['00240', '00240', '00240', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (64,95) of type [('compound', 188)] for ['00240', '00240'] appears as [('compound', 220)] for 00240.
# ****Conflict! Rewriting as [('compound', 220)]
# - Edge (98,99) of type [('compound', 196)] for ['00240'] appears as [('compound', 219)] for 00240.
# ****Conflict! Rewriting as [('compound', 219)]
# - Edge (92,104) of type [('compound', 221)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (89,64) of type [('compound', 195)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (93,64) of type [('compound', 195)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (93,98) of type [('compound', 195)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (64,105) of type [('compound', 221)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (64,95) of type [('compound', 220)] for ['00240', '00240', '00240'] appears as [('compound', 219)] for 00240.
# ****Conflict! Rewriting as [('compound', 219)]
# - Edge (64,96) of type [('compound', 188)] for ['00240'] appears as [('compound', 219)] for 00240.
# ****Conflict! Rewriting as [('compound', 219)]
# - Edge (106,106) of type [('compound', 181)] for ['00240'] appears as [('compound', 180)] for 00240.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (64,99) of type [('compound', 196)] for ['00240'] appears as [('compound', 219)] for 00240.
# ****Conflict! Rewriting as [('compound', 219)]
# - Edge (95,84) of type [('compound', 220)] for ['00240'] appears as [('compound', 219)] for 00240.
# ****Conflict! Rewriting as [('compound', 219)]
# - Edge (105,84) of type [('compound', 221)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (36,94) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (89,84) of type [('compound', 218)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (92,94) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (93,84) of type [('compound', 218)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (64,83) of type [('compound', 365)] for ['00230'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (36,64) of type [('compound', 195)] for ['00230', '00230', '00230', '00240', '00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (99,84) of type [('compound', 219)] for ['00240'] appears as [('compound', 196)] for 00240.
# ****Conflict! Rewriting as [('compound', 196)]
# - Edge (60,64) of type [('compound', 365)] for ['00230', '00230'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (83,36) of type [('compound', 365)] for ['00230'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (92,64) of type [('compound', 221)] for ['00240', '00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (36,83) of type [('compound', 390)] for ['00230', '00230', '00230'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (38,83) of type [('compound', 390)] for ['00230', '00230'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (83,64) of type [('compound', 325)] for ['00230'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (83,36) of type [('compound', 191)] for ['00230', '00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (38,92) of type [('compound', 214)] for ['00240'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (38,40) of type [('compound', 217)] for ['00240'] appears as [('compound', 222)] for 00240.
# ****Conflict! Rewriting as [('compound', 222)]
# - Edge (36,60) of type [('compound', 369)] for ['00230'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (38,92) of type [('compound', 186)] for ['00240', '00240'] appears as [('compound', 222)] for 00240.
# ****Conflict! Rewriting as [('compound', 222)]
# - Edge (38,60) of type [('compound', 369)] for ['00230'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (36,36) of type [('compound', 194)] for ['00230', '00230', '00230', '00240'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (94,83) of type [('compound', 187)] for ['00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (38,36) of type [('compound', 194)] for ['00230', '00230', '00240', '00240'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (38,52) of type [('compound', 380)] for ['00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (36,52) of type [('compound', 380)] for ['00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (36,83) of type [('compound', 187)] for ['00230', '00230', '00230', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (83,52) of type [('compound', 380)] for ['00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (83,64) of type [('compound', 213)] for ['00230', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (38,83) of type [('compound', 191)] for ['00230', '00230', '00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (38,83) of type [('compound', 185)] for ['00230', '00230', '00240', '00240'] appears as [('compound', 193)] for 00240.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (36,83) of type [('compound', 195)] for ['00230', '00230', '00230', '00240', '00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (38,91) of type [('compound', 185)] for ['00240', '00240'] appears as [('compound', 193)] for 00240.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (36,83) of type [('compound', 185)] for ['00230', '00230', '00230', '00240', '00240', '00240'] appears as [('compound', 193)] for 00240.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (36,91) of type [('compound', 195)] for ['00240', '00240', '00240', '00240', '00240'] appears as [('compound', 193)] for 00240.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (90,36) of type [('compound', 185)] for ['00240'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (64,91) of type [('compound', 187)] for ['00240', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (36,36) of type [('compound', 186)] for ['00230', '00230', '00230', '00240', '00240'] appears as [('compound', 214)] for 00240.
# ****Conflict! Rewriting as [('compound', 214)]
# - Edge (38,40) of type [('compound', 222)] for ['00240', '00240'] appears as [('compound', 214)] for 00240.
# ****Conflict! Rewriting as [('compound', 214)]
# - Edge (487,489) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04062.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (487,177) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04062.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (129,161) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04062. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (161,204) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->')] for 04066.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (484,183) of type [('compound', 151), ('activation', '-->')] for ['04062'] appears as [('activation', '-->')] for 04066. Overwriting with type [('compound', 151), ('activation', '-->')]
# - Edge (569,573) of type [('compound', 48)] for ['04070'] appears as [('compound', 49)] for 04070.
# ****Conflict! Rewriting as [('compound', 49)]
# - Edge (579,576) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (573,576) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (569,576) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (590,591) of type [('compound', 52)] for ['04070'] appears as [('compound', 235)] for 04070.
# ****Conflict! Rewriting as [('compound', 235)]
# - Edge (591,590) of type [('compound', 234)] for ['04070'] appears as [('compound', 68)] for 04070.
# ****Conflict! Rewriting as [('compound', 68)]
# - Edge (569,573) of type [('compound', 49)] for ['04070', '04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (587,579) of type [('compound', 66)] for ['04070'] appears as [('compound', 73)] for 04070.
# ****Conflict! Rewriting as [('compound', 73)]
# - Edge (571,570) of type [('compound', 49)] for ['04070'] appears as [('compound', 66)] for 04070.
# ****Conflict! Rewriting as [('compound', 66)]
# - Edge (575,583) of type [('compound', 61)] for ['04070'] appears as [('compound', 56)] for 04070.
# ****Conflict! Rewriting as [('compound', 56)]
# - Edge (579,592) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (592,573) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (593,592) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (593,574) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (484,579) of type [('compound', 73)] for ['04070'] appears as [('compound', 66)] for 04070.
# ****Conflict! Rewriting as [('compound', 66)]
# - Edge (583,583) of type [('compound', 60)] for ['04070', '04070'] appears as [('compound', 231)] for 04070.
# ****Conflict! Rewriting as [('compound', 231)]
# - Edge (581,592) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (586,587) of type [('compound', 66)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (579,569) of type [('compound', 75)] for ['04070'] appears as [('compound', 72)] for 04070.
# ****Conflict! Rewriting as [('compound', 72)]
# - Edge (569,573) of type [('compound', 75)] for ['04070', '04070', '04070'] appears as [('compound', 72)] for 04070.
# ****Conflict! Rewriting as [('compound', 72)]
# - Edge (577,575) of type [('compound', 61)] for ['04070'] appears as [('compound', 56)] for 04070.
# ****Conflict! Rewriting as [('compound', 56)]
# - Edge (580,577) of type [('compound', 62)] for ['04070'] appears as [('compound', 55)] for 04070.
# ****Conflict! Rewriting as [('compound', 55)]
# - Edge (578,580) of type [('compound', 55)] for ['04070'] appears as [('compound', 63)] for 04070.
# ****Conflict! Rewriting as [('compound', 63)]
# - Edge (176,625) of type [('expression', '-->')] for ['04115'] appears as [('activation', '-->')] for 04115.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (496,499) of type [] for ['04062'] appears as [('activation', '-->')] for 04151. Overwriting with type [('activation', '-->')]
# - Edge (183,114) of type [('phosphorylation', '+p'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (149,150) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04151.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (150,505) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->')] for 04151. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (536,161) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (540,561) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (561,562) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (113,114) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04210. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (118,119) of type [] for ['04010'] appears as [('activation', '-->')] for 04210. Overwriting with type [('activation', '-->')]
# - Edge (540,552) of type [('inhibition', '--|')] for ['04066'] appears as [('inhibition', '--|'), ('phosphorylation', '+p')] for 04218. Overwriting with type [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (579,499) of type [('inhibition', '--|'), ('dephosphorylation', '-p')] for ['04151'] appears as [('inhibition', '--|')] for 04218. Overwriting with type [('inhibition', '--|'), ('dephosphorylation', '-p')]
# - Edge (728,488) of type [('activation', '-->')] for ['04213'] appears as [('inhibition', '--|')] for 04218.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (176,228) of type [('expression', '-->')] for ['04115', '04115'] appears as [('activation', '-->')] for 04218.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (214,600) of type [('expression', '-->'), ('indirect effect', '..>')] for ['04218'] appears as [('expression', '-->')] for 04218. Overwriting with type [('expression', '-->'), ('indirect effect', '..>')]
# - Edge (189,176) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04218. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (796,780) of type [('activation', '-->')] for ['04310'] appears as [('inhibition', '--|')] for 04310.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (176,634) of type [('expression', '-->')] for ['04115', '04115'] appears as [('indirect effect', '..>')] for 04310.
# ****Conflict! Rewriting as [('indirect effect', '..>')]
# - Edge (181,769) of type [('activation', '-->'), ('dephosphorylation', '-p')] for ['04218'] appears as [('dephosphorylation', '-p')] for 04310. Overwriting with type [('activation', '-->'), ('dephosphorylation', '-p')]
# - Edge (493,177) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04510.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (483,163) of type [('activation', '-->')] for ['04310'] appears as [('phosphorylation', '+p'), ('indirect effect', '..>')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (484,183) of type [('compound', 151), ('activation', '-->')] for ['04062', '04066'] appears as [('compound', 24)] for 04510.
# ****Conflict! Rewriting as [('compound', 24)]
# - Edge (511,149) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04510.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (649,183) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04210'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (494,493) of type [('binding/association', '---')] for ['04062'] appears as [('phosphorylation', '+p')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p')]
# - Edge (163,697) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04210'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (129,161) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04010', '04062'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (161,527) of type [('expression', '-->'), ('indirect effect', '..>')] for ['04210'] appears as [('phosphorylation', '+p')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p')]
# - Edge (856,709) of type [('binding/association', '---')] for ['04510'] appears as [('activation', '-->')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (484,183) of type [('compound', 24)] for ['04062', '04066', '04510'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (161,202) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (711,492) of type [('dissociation', '-+-')] for ['04210'] appears as [('inhibition', '--|')] for 04620.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (115,116) of type [('activation', '-->')] for ['04010'] appears as [('binding/association', '---')] for 04620.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (536,161) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151', '04210', '04218'] appears as [('phosphorylation', '+p')] for 04620. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (772,189) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04218'] appears as [('phosphorylation', '+p')] for 04620. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (183,540) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (561,562) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151'] appears as [('activation', '-->')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (484,649) of type [('compound', 24)] for ['04510'] appears as [('compound', 71), ('activation', '-->')] for 04910.
# ****Conflict! Rewriting as [('compound', 71), ('activation', '-->')]
# - Edge (150,505) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062', '04151'] appears as [('activation', '-->')] for 04910. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (161,204) of type [('activation', '-->')] for ['04010', '04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (161,154) of type [('phosphorylation', '+p')] for ['04010', '04510'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (204,553) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (741,726) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (711,492) of type [('inhibition', '--|')] for ['04210', '04620'] appears as [('dissociation', '-+-')] for 04931.
# ****Conflict! Rewriting as [('dissociation', '-+-')]
# - Edge (555,556) of type [('activation', '-->')] for ['04611'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04931. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (555,556) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04611', '04931'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (741,685) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (685,484) of type [('activation', '-->')] for ['04151', '04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (685,484) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04213', '04931'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (954,711) of type [('phosphorylation', '+p')] for ['04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (484,481) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (685,484) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04213', '04931', '04931'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (1024,685) of type [('inhibition', '--|')] for ['04931'] appears as [('inhibition', '--|'), ('indirect effect', '..>')] for 04931. Overwriting with type [('inhibition', '--|'), ('indirect effect', '..>')]
# - Edge (804,184) of type [('compound', 12)] for ['04310'] appears as [('compound', 277), ('activation', '-->')] for 05146.
# ****Conflict! Rewriting as [('compound', 277), ('activation', '-->')]
# - Edge (1089,161) of type [('activation', '-->'), ('indirect effect', '..>')] for ['05205'] appears as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (528,1116) of type [('activation', '-->')] for ['05205'] appears as [('inhibition', '--|')] for 05205.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (891,892) of type [('compound', 131)] for ['04512'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (516,517) of type [('activation', '-->')] for ['04062', '04510', '04611'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (484,183) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062', '04066', '04510', '04611', '04620'] appears as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (517,836) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['04510'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (596,734) of type [('activation', '-->')] for ['04213'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (161,154) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04010', '04510', '04910'] appears as [('phosphorylation', '+p')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (734,484) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (183,540) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (561,562) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151', '04910'] appears as [('activation', '-->')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (561,679) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151'] appears as [('activation', '-->')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (484,649) of type [('compound', 71), ('activation', '-->')] for ['04510', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (649,561) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (546,492) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04066'] appears as [('activation', '-->')] for 05321. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (555,556) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04611', '04931', '04931'] appears as [('activation', '-->')] for 05415. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (484,499) of type [('activation', '-->')] for ['04151', '04210', '04213', '04213', '04218', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (685,484) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04213', '04931', '04931', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (183,665) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['04151', '04510', '04910', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (116,114) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (1126,516) of type [('binding/association', '---')] for ['05205'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (956,163) of type [('phosphorylation', '+p')] for ['04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (484,499) of type [('missing interaction', '-/-')] for ['04151', '04210', '04213', '04213', '04218', '04931', '05415'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (124,115) of type [('binding/association', '---')] for ['04010'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (183,665) of type [('missing interaction', '-/-')] for ['04151', '04510', '04910', '04931', '05415'] appears as [('inhibition', '--|'), ('phosphorylation', '+p')] for 05417.
# ****Conflict! Rewriting as [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (513,773) of type [('activation', '-->')] for ['04218', '04970'] appears as [('binding/association', '---')] for 05417.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (492,555) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04931'] appears as [('repression', '--|')] for 05417.
# ****Conflict! Rewriting as [('repression', '--|')]
# - Edge (492,1194) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,1196) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,1197) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,1199) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,254) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,256) of type [('expression', '-->')] for ['04620', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (724,725) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04210'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (492,1200) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,145) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,353) of type [('expression', '-->')] for ['04620', '05417', '05417', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,402) of type [('expression', '-->')] for ['04620', '04931', '04931', '05417', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,142) of type [('expression', '-->')] for ['04620', '04931', '04931', '05321', '05417', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (649,183) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04210', '04510', '04910', '04931'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (163,171) of type [('phosphorylation', '+p')] for ['04010', '04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (252,606) of type [('indirect effect', '..>')] for ['04115'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed

# %%
# Build node2columns, mapping each node of G to the list of genes corresponding to it
# for which we know a value (in the genes dataframe), sorted
#

print("Mapping genes to columns")
namedGenes = set(name2gene.values())     
columns = set(genes.columns.values.tolist()[2:])
node2columns = {}
for node in G.nodes():
    nodeGenes = can2set(id2element[node])
    s = []
    for gene in nodeGenes & namedGenes:
        for k,v in name2gene.items():
            if v == gene:
                if k in columns:
                    s += [k]
    node2columns[node]=sorted(s)
# Out:
# Mapping genes to columns

# %%
if produceGraphsWithCCcoloring:
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
        canvas = KGMLCanvas(pathway)
        for k in pathway.entries:
            name = pathway.entries[k].name
            canonicalName = set2can(words2set(name))
            if canonicalName in element2id.keys():
                node = element2id[canonicalName]
                klass = cc[node]
                if klass in nontrivialclass2col:
                    pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                    pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                else:
                    pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                    pathway.enries[k].graphics[0].fgcolor = "#FFFFFF"
                s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"
        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway)).mkdir(parents=True, exist_ok=True)
        canvas.draw(os.path.join(outputDirectory, organism, safeSuperpathway, pdfName))
    with open(os.path.join(outputDirectory, organism, safeSuperpathway, "all.tsv"), "wt") as file:
        file.write(s)

# %%
def columns2nodes(columns, node2columns, ignoreEmpty = True):
    """
        Returns a map from columns to the nodes where the column appears.
    """
    res = {} 
    for c in columns:
        s = set([])
        for no, co in node2columns.items():
            if c in co:
                s |= set([no])
        if len(s) > 0 or not ignoreEmpty:
            res[c] = s
    return res

c2n = columns2nodes(columns, node2columns)
usableColumns = list(c2n.keys())

# %%
def corrForPair(genes, set1, set2, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Given a dataframe genes (i.e., a set of patients), and two sets of column names (set1, set2), 
        compute the correlation function
        for every pair of columns in set1 and set2 and return the average statistic and its std.
    """
    taus = []
    for gene1 in set1:
        for gene2 in set2:
            expr1 = genes.loc[:,gene1].values.tolist()
            expr2 = genes.loc[:,gene2].values.tolist()
            if len(set(expr1)) == 1 or len(set(expr2)) == 1:
                continue
            taus += [correlationFunction(expr1, expr2).statistic]
    if len(taus) < 2:
        return np.nan, np.nan
    return pd.DataFrame(taus).mean().values[0], pd.DataFrame(taus).std().values[0]

# %%
def sampleDeltaDist(genes, set1, set2, numberOfRows1, numberOfSamples = 500, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Repeatedly (for numberOfSamples times) do the following:
        - select numberOfRows1 rows of genes, and then compute tauForPair on those rows for set1 and set2
        - do the same for remaining rows
        - take the difference between the two resulting set of taus.
        Return the mean and std of differences.
    """
    diffs = []
    
    for i in range(numberOfSamples):
        genes1 = random.sample(range(len(genes)), numberOfRows1)
        genes2 = list(set(range(len(genes)))-set(genes1))
        mt1, mstd1 = corrForPair(genes.iloc[genes1], set1, set2, correlationFunction)
        if np.isnan(mp1):
            continue
        mt2, mstd2 = corrForPair(genes.iloc[genes2], set1, set2, correlationFunction)
        if np.isnan(mp2):
            continue
        diffs += [mt1-mt2]
    return diffs


def deltaForPair(genes1, genes2, set1, set2, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Compute corrForPair for set1 and set2 over the set of rows genes1 and genes2, and return
        the difference of taus.
    """
    mt1, mstd1 = corrForPair(genes1, set1, set2, correlationFunction)
    mt2, mstd2 = corrForPair(genes2, set1, set2, correlationFunction)
    return mt1-mt2

# %%
correlationFunction = lambda x,y:  scipy.stats.spearmanr(x,y).statistic
correlationFunctionName = "spearmanrho"
relAnomalies = os.path.join(inputDirectory, "anomalies-" + correlationFunctionName + ".csv")

if os.path.exists(relAnomalies):
    print("Reading anomalies")
    relcorrel = pd.read_csv(relAnomalies)
else:
    print("Producing anomalies")
    relcorrel = pd.DataFrame(columns=[
        "Source gene(s)",
        "Target gene(s)",
        "Pathway ID",
        "Relation type",
        "Correlation for healthy",
        "Correlation for diseased",
        "Correlation difference (H-D)",
        "Expected correlation difference",
        "P-value",
        "Comment"
        ])
    numberOfEdges = G.number_of_edges()
    doneEdges = 0
    for s,t,d in G.edges(data=True):
        if doneEdges % 10 == 0:
            print("{:.2f}% done".format(100 * doneEdges / numberOfEdges))
        doneEdges += 1
        subtypeName = [k for k,v in subtype2color.items() if d["color"]==v][0]
        sg = node2columns[s]
        tg = node2columns[t]
        if len(sg) == 0 or len(tg) == 0:
            continue
        avgh, stdh = corrForPair(genesHealthy, sg, tg, correlationFunction=correlationFunction)
        avgd, stdd = corrForPair(genesDiseased, sg, tg, correlationFunction=correlationFunction)
        taudiff = avgh - avgd
        ttn = sampleDeltaDist(genes, sg, tg, numHealthy, correlationFunction=correlationFunction)
        tt = [x for x in ttn if ~np.isnan(x)]
        if len(tt) == 0:
            continue
        ttmean = pd.DataFrame(tt).mean().values[0]
        ecdft = scipy.stats.ecdf(tt)  # Empirical CDF
        if taudiff < 0:
            pvalue = ecdft.cdf.evaluate(taudiff)
            comment = "More correlated than for healthy individuals"
        else:
            pvalue = 1 - ecdft.cdf.evaluate(taudiff)    
            comment = "Less correlated than for healthy individuals"
        if produceAnomaliesForNonsignificantPairs or produpvalue <= confidence:
            relcorrel.loc[len(relcorrel)] = [
                str(sg),
                str(tg),
                d["pathwayIDs"],
                subtypeName,
                avgh, 
                avgd,
                taudiff,
                ttmean,
                pvalue,
                comment
            ]
    relcorrel = relcorrel.sort_values(by=["P-value"], ascending=True)
    relcorrel.to_csv(relAnomalies)
# Out:
# Reading anomalies

# %%
print("Anomalies by type")
statisticallySignificant = relcorrel.loc[
    (relcorrel["P-value"]<confidence)   # Statistically significant
]

failingActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

failingInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

otherTypesOfRelations = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    ~(relcorrel["Relation type"].str.contains("activation")) & # No activation  
    ~(relcorrel["Relation type"].str.contains("inhibition"))   # No inhibition 
]

print("P-value < {:.2f}: ".format(100 * confidence / 100), len(statisticallySignificant))
print("Failing activations (green):", len(failingActivation))
print("Failing inhibitions (blue):", len(failingInhibition))
print("Excessive activations (red):", len(excessiveActivation))
print("Excessive inhibitions (orange):", len(excessiveInhibition))
print("Other types of relations (yellow):", len(otherTypesOfRelations))
print("Total:", len(failingActivation)+len(failingInhibition)+len(excessiveActivation)+len(excessiveInhibition)+len(otherTypesOfRelations))
# Out:
# Anomalies by type
# P-value < 0.05:  101
# Failing activations (green): 15
# Failing inhibitions (blue): 10
# Excessive activations (red): 17
# Excessive inhibitions (orange): 7
# Other types of relations (yellow): 52
# Total: 101

# %%
def elaborateArc(relation, sdrawing):
    source= str(node2columns[element2id[set2can(relation.source)]])
    for tg in relation.target:
        target = str(node2columns[element2id[set2can(tg)]])
        r = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
        if len(r) == 0:
            continue
        if len(r) > 1:
            pass
            #print(f"({source}, {target}) appearing more than once in relcorrel")
            #print(list(r.to_dict()["Correlation difference (H-D)"].values()))
        rd = r.to_dict()
        pvalue = list(rd["P-value"].values())[0]
        corrdiff = list(rd["Correlation difference (H-D)"].values())[0]
        relationType = list(rd["Relation type"].values())[0]
        if pvalue < confidence:        
            if "activation" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.green
                else:
                    col = reportlab.lib.colors.red
            elif "inhibition" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.orange
                else:
                    col = reportlab.lib.colors.blue
            else:
                col = reportlab.lib.colors.yellow
            if np.isnan(corrdiff):
                print(f"Correlation for {source} vs. {target} is {corrdiff}")
            else:
                sdrawing.setLineWidth(3*math.exp(abs(corrdiff)*3))
                sdrawing.setStrokeColor(col)
                sdrawing.line(relation.sourceg.x, relation.sourceg.y, relation.targetg.x, relation.targetg.y)

# %%
if produceGraphsWithAnomalies:
    print("Producing anomaly PDFs")
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)

        relations = []
        for relation in rel[pathwayID]:
            relations += [relation]

        canvas = KGMLCanvas(pathway)

        if useCCcoloringForAnomalies:
            for k in pathway.entries:
                name = pathway.entries[k].name
                canonicalName = set2can(words2set(name))
                if canonicalName in element2id.keys():
                    node = element2id[canonicalName]
                    klass = cc[node]
                    if klass in nontrivialclass2col:
                        pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                        pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                    else:
                        pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                        pathway.entries[k].graphics[0].fgcolor = "#FFFFFF"
                    s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"

        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway + "-anomalies")).mkdir(parents=True, exist_ok=True)
        canvas.new_draw(os.path.join(outputDirectory, organism, safeSuperpathway+ "-anomalies", pdfName), relations, elaborateArc)
# Out:
# Producing anomaly PDFs

# %%
print("Computing anomalies by pathway")
pathwayAnomalies = pd.DataFrame(columns=[
        "Pathway ID",
        "Pathway",
        "Average square difference",
        "Count",
        "Relative count"
        ])
for pair in superpathwayDict[superpathway]:
    pathwayID = pair[0]
    pathwayName= pair[1]
    ssqd = 0
    count = 0
    countSig = 0
    for relation in rel[pathwayID]:
        source = str(node2columns[element2id[set2can(relation.source)]])
        for targ in relation.target:
            target = str(node2columns[element2id[set2can(targ)]])
            tt = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
            if len(tt) == 1 and tt["P-value"].to_list()[0] <= confidence:
                cd = tt["Correlation difference (H-D)"].to_list()[0]
                ssqd += cd * cd
                countSig += 1
            count += 1
    if count > 0:
        pathwayAnomalies.loc[len(pathwayAnomalies)]=[pathwayID, pathwayName, ssqd, countSig, countSig / count]
# Out:
# Computing anomalies by pathway

# %%
print("Sorting pathways by number of anomalies and writing it out as a csv")
relPathwayAnomalies = os.path.join(inputDirectory, "pathway-anomalies-" + correlationFunctionName + ".csv")
pathwayAnomalies = pathwayAnomalies.sort_values(by=["Count"], ascending=False)
pathwayAnomalies.to_csv(relPathwayAnomalies)
# Out:
# Sorting pathways by number of anomalies and writing it out as a csv

# %%
print("Extracting genes involved in top-k anomalous pathways and appearing as columns")
nTopAnomPathway = len(pathwayAnomalies)
topAnomPathway = pathwayAnomalies.head(nTopAnomPathway)["Pathway ID"].to_list()
anomPathwayGenes = set([])
anomPathwayGenesByPathway = defaultdict(lambda: set([]))
for pathwayId in topAnomPathway:
    for relation in rel[pathwayId]:
        anomPathwayGenes |= relation.source 
        anomPathwayGenesByPathway[pathwayId] |= relation.source 
        for t in relation.target:
            anomPathwayGenes |= t
            anomPathwayGenesByPathway[pathwayId] |= t
anomPathwayGeneNames = [name for name,gene in name2gene.items() if gene in anomPathwayGenes and name in columns]
print(len(anomPathwayGeneNames), "genes involved")
anomPathwayGenesByPathwayNames = {}
print("Genes involved by pathway")
for pathwayId in topAnomPathway:
    anomPathwayGenesByPathwayNames[pathwayId] = [name for name,gene in name2gene.items() if gene in anomPathwayGenesByPathway[pathwayId] and name in columns]
    t = len(anomPathwayGenesByPathwayNames[pathwayId])
    print(f"\t{pathwayId}: {t}")
# Out:
# Extracting genes involved in top-k anomalous pathways and appearing as columns
# 1537 genes involved
# Genes involved by pathway
# 	00230: 102
# 	04070: 78
# 	00240: 49
# 	05205: 178
# 	04010: 252
# 	04062: 166
# 	04310: 144
# 	04910: 128
# 	04510: 185
# 	04218: 134
# 	04931: 88
# 	04611: 115
# 	04512: 70
# 	05417: 182
# 	04213: 59
# 	04210: 120
# 	05321: 37
# 	04151: 267
# 	04620: 84
# 	04115: 68
# 	04970: 48
# 	04060: 201
# 	00010: 62
# 	04066: 98
# 	04975: 10
# 	05415: 99
# 	04145: 15
# 	04974: 2
# 	04979: 31
# 	05146: 35

# %%
print("Computing correlations for anomalous-pathway genes in the two populations")
healthyMatrix = genesHealthy[anomPathwayGeneNames].to_numpy() #Rows are healthy patients, columns are genes appearing in anomalous pathways
diseasedMatrix = genesDiseased[anomPathwayGeneNames].to_numpy() #Rows are diseased patients, columns are genes appearing in anomalous pathways

healthyCorr = np.corrcoef(healthyMatrix, rowvar=False) #Correlation between anomalous genes in healthy individuals
diseasedCorr = np.corrcoef(diseasedMatrix, rowvar=False) #Correlation between anomalous genes in diseased individuals
healthyCorrByPathway = {}
diseasedCorrByPathway = {}
for pathwayId in topAnomPathway:
    healthyMatrix = genesHealthy[anomPathwayGenesByPathwayNames[pathwayId]].to_numpy() #Rows are healthy patients, columns are genes appearing in anomalous pathways
    diseasedMatrix = genesDiseased[anomPathwayGenesByPathwayNames[pathwayId]].to_numpy() #Rows are healthy patients, columns are genes appearing in anomalous pathways
    healthyCorrByPathway[pathwayId] = np.corrcoef(healthyMatrix, rowvar=False)
    diseasedCorrByPathway[pathwayId] = np.corrcoef(diseasedMatrix, rowvar=False)
# Out:
# Computing correlations for anomalous-pathway genes in the two populations

# %%
pd.DataFrame(data=healthyCorr, columns=anomPathwayGeneNames).to_csv("/tmp/matrices/healthy-all.csv")
pd.DataFrame(data=diseasedCorr, columns=anomPathwayGeneNames).to_csv("/tmp/matrices/diseased-all.csv")
for pathwayId in topAnomPathway:
    pd.DataFrame(data=healthyCorrByPathway[pathwayId], columns=anomPathwayGenesByPathwayNames[pathwayId]).to_csv("/tmp/matrices/healthy-" + pathwayId + ".csv")
    pd.DataFrame(data=diseasedCorrByPathway[pathwayId], columns=anomPathwayGenesByPathwayNames[pathwayId]).to_csv("/tmp/matrices/diseased-" + pathwayId + ".csv")
