# %%
from hypergraphs import *
from kegg import *
import pandas as pd
import os
import logging

from Bio.KEGG.KGML.KGML_parser import read
import Bio.KEGG.KGML.KGML_pathway
from ast import literal_eval
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
import requests
from Levenshtein import ratio
import scipy.stats
import pathlib
from qf.cc import cardon_crochemore_colored, cardon_crochemore
import random

from reportlab.lib.units import inch
import PIL.Image
from io import BytesIO
import reportlab.pdfgen.canvas
import reportlab.lib.colors

# %%
organismDict = {"hsa": "Homo sapiens (human)"}
outputDirectory = "/Users/boldi/Desktop/pw/"
inputDirectory = "../../LaTeX/Data/KEGG-Pathways/Jan2024/"
dataDirectory = "../../LaTeX/Data/KEGG-Pathways"

# %%
pathwaylistFilename = "KEGG-pathways.txt"  # In inputDirectory, csv: ID, type, name
superpathway = "All"                  # Name of the superpathway
organism = "hsa"
confidence = 0.05

produceGraphsWithCCcoloring = True
produceGraphsWithAnomalies = True
useCCcoloringForAnomalies = False
produceAnomaliesForNonsignificantPairs = True

# %%
safeSuperpathway = makesafe(superpathway)

# %%
pws = pd.read_csv(os.path.join(inputDirectory, "KEGG-pathways.txt"), 
            names=["Pathway ID", "Pathway type", "Pathway name"], dtype="string", keep_default_na=False)

# %%
superpathwayDict = {
    superpathway: [(x,y) for x,y in zip(pws["Pathway ID"], pws["Pathway name"])]
}

# %%
def words2set(words):
    """
        Given a space-separated list of words, returns it as a set of words
    """
    return set(words.split())

# %%
from typing import NamedTuple

class Relation(NamedTuple):
    """
        Represents a relation. It is characterized by:
        - a type (e.g. "PPRel") 
        - a list of subtypes (e.g. [('activation', '-->'), ('indirect effect', '..>')])
        - a set of components (source)
        - a list of sets of components (target)
    """
    relType: str
    relSubtypes: list
    source: set
    target: list
    sourceg: Bio.KEGG.KGML.KGML_pathway.Graphics
    targetg: Bio.KEGG.KGML.KGML_pathway.Graphics
        
    @classmethod
    def fromKEGG(cls, relation, pathway):
        """
            Constructor: builds a Relation from a KEGG relation
        """
        if relation.entry2.name == "undefined":
            s = []
            for component in relation.entry2.components:
                s += [words2set(pathway.entries[component.id].name)]
            targetg = pathway.entries[component.id].graphics[0]
        else:
            s = [words2set(relation.entry2.name)]
            targetg = relation.entry2.graphics[0]
        return cls(relation.type, relation.subtypes, words2set(relation.entry1.name), s, targetg, relation.entry1.graphics[0])

# %%
def relationsFromKEGGpathway(pathway):
    """
        Given a KEGG pathway, returns the list of relations it contains (represented as Relation).
    """
    return [Relation.fromKEGG(r, pathway) for r in pathway.relations]

# %%
def pathwayFromFile(dataDirectory, organism, pathwayID):
    """
        Load and return a KEGG pathway, given the data directory, the organism specifying the subdirectory,
        and the pathwayID (the filename should be organism+pathwayID+"xml".
    """
    return KGML_parser.read(open(os.path.join(dataDirectory, organism, organism+pathwayID+".xml"), "r"))

# %%
def relationsFromFile(dataDirectory, organism, pathwayID):
    """
        Given a pathway file (specified by a root dataDirectory, the name of the organism subdirectory, and the name
        of the file [organism+pathwayID.xml]), reads it and returns the list of its relations.
    """
    pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
    return relationsFromKEGGpathway(pathway)

# %%
def relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway):
    """
        Given a superpathDict (whose keys are superpathway names and whose values are list of
        pairs (pathwayID, pathwayName)), reads all the pathway file for a specific superpathway name
        and returns a dictionary whose keys are the pathwayID's and whose values are the list of relations.
    """
    rel = {}
    for k,v in superpathwayDict[superpathway]:
        #logging.info("Reading", k, v)
        rel[k] = relationsFromFile(dataDirectory, organism, k)
    return rel

# %%
def subtypes(rel):
    """
        Given a map whose values are relations, accumulate all subtypes appearing and assign them a number.
        The result is a map from subtype string to number.
    """
    all_subtypes = set([])
    for pathwayid, relations in rel.items():
        for relation in relations:
            all_subtypes |= set([str(relation.relSubtypes)])
        
    s = sorted(list(all_subtypes))
    subtype2color = {v:k for k,v in enumerate(s)}
    color2subtype = {k:v for k,v in enumerate(s)}

    return subtype2color, color2subtype

# %%
def set2can(s):
    """
        Convert a set to a string in a canonical way.
    """
    return str(sorted(list(s)))

def can2set(c):
    """
        Does the converse of set2can.
    """
    return set(literal_eval(c))

# %%
def indices(rel):
    """
        Given a map whose values are lists of relations, it considers all the relations one by one, and attributes a unique id 
        to each element (i.e., set of components appearing as source or in the target of some relation) and block (the set of
        element id appearing as target of some relation).
        This function returns the dictionaries to move from/to an element or block to the corresponding id.
        Elements are string representations of sorted lists of strings.
        Blocks are string representations of sorted lists of ints.
    """
    element2id = {}
    id2element = {}
    block2id = {}
    id2block = {}

    for relations in rel.values():
        for relation in relations:
            s = set2can(relation.source)
            if s not in element2id.keys():
                element2id[s] = len(element2id)
            targetset = set([])
            for targ in relation.target:
                t = set2can(targ)
                if t not in element2id.keys():
                    element2id[t] = len(element2id)
                targetset |= set([element2id[t]])
            ts = set2can(targetset)
            if ts not in block2id.keys():
                block2id[ts] = len(block2id)

    for k,v in element2id.items():
        id2element[v] = k
    for k,v in block2id.items():
        id2block[v] = k
    return element2id, id2element, block2id, id2block

# %%
def search_gene_KEGG(geneID):
    """
        Search for gene on KEGG. 
        
        Returns list of names.
    """
    url1 = "https://www.kegg.jp/entry/"+geneID
    response1 = requests.get(url1, allow_redirects=False)    
    soup = BeautifulSoup(response1.text, "html.parser")
    tds = [tds for tds in soup.find_all("td", {"class": "td11 defd"})]
    names = tds[0].getText().strip().split(", ")
    return names

# %%
def get_temp_imagefilename(url):
    """Return filename of temporary file containing downloaded image.

    Create a new temporary file to hold the image file at the passed URL
    and return the filename.
    """
    img = urlopen(url).read()
    im = PIL.Image.open(BytesIO(img))
    # im.transpose(Image.FLIP_TOP_BOTTOM)
    f = tempfile.NamedTemporaryFile(delete=False, suffix=".png")
    fname = f.name
    f.close()
    im.save(fname, "PNG")
    return fname


#def enhance_method(klass, method_name, replacement):
#    'replace a method with an enhanced version'
#    method = getattr(klass, method_name)
#    def enhanced(*args, **kwds): return replacement(*args, **kwds)
#    setattr(klass, method_name, enhanced)

def new_draw(self, filename, relations, elaborateArc = None):
        """Add the map elements to the drawing."""
        # Instantiate the drawing, first
        # size x_max, y_max for now - we can add margins, later
        if self.import_imagemap:
            # We're drawing directly on the image, so we set the canvas to the
            # same size as the image
            if os.path.isfile(self.pathway.image):
                imfilename = self.pathway.image
            else:
                imfilename = get_temp_imagefilename(self.pathway.image)
            im = PIL.Image.open(imfilename)
            cwidth, cheight = im.size
        else:
            # No image, so we set the canvas size to accommodate visible
            # elements
            cwidth, cheight = (self.pathway.bounds[1][0], self.pathway.bounds[1][1])
        # Instantiate canvas
        self.drawing = reportlab.pdfgen.canvas.Canvas(
            filename,
            bottomup=0,
            pagesize=(
                cwidth * (1 + 2 * self.margins[0]),
                cheight * (1 + 2 * self.margins[1]),
            ),
        )
        self.drawing.setFont(self.fontname, self.fontsize)
        # Transform the canvas to add the margins
        self.drawing.translate(
            self.margins[0] * self.pathway.bounds[1][0],
            self.margins[1] * self.pathway.bounds[1][1],
        )
        # Add the map image, if required
        if self.import_imagemap:
            self.drawing.saveState()
            self.drawing.scale(1, -1)
            self.drawing.translate(0, -cheight)
            self.drawing.drawImage(imfilename, 0, 0)
            self.drawing.restoreState()
        # Add the reactions, compounds and maps
        # Maps go on first, to be overlaid by more information.
        # By default, they're slightly transparent.
        if self.show_maps:
            self.__add_maps()
        if self.show_reaction_entries:
            KGMLCanvas._KGMLCanvas__add_reaction_entries(self)
        if self.show_orthologs:
            KGMLCanvas._KGMLCanvas__add_orthologs(self)
        if self.show_compounds:
            KGMLCanvas._KGMLCanvas__add_compounds(self)
        if self.show_genes:
            KGMLCanvas._KGMLCanvas__add_genes(self)
        # TODO: complete draw_relations code
        # if self.draw_relations:
        #    self.__add_relations()
        # Write the pathway map to PDF
        if elaborateArc is not None:
            for relation in relations:
                elaborateArc(relation, self.drawing)
        self.drawing.save()
        
#enhance_method(KGMLCanvas, 'draw',  new_draw)
setattr(KGMLCanvas, 'new_draw', new_draw)

# %%
# Build all data needed for the relations of the superpathway
rel = relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway)
element2id, id2element, block2id, id2block = indices(rel)
subtype2color, color2subtype = subtypes(rel)
elements = list(set.union(*[can2set(k) for k in element2id.keys()]))

# %%
# name2gene is a function mapping names to gene IDs (hsa:xxxx)
# e.g. KCNE3, BRGDA6 etc are all mapped to hsa:10008 (see https://www.kegg.jp/entry/hsa:10008)
# This map was produced by scraping kegg, but this has been done only once.
# After that, we just read a pkl file

name2keggFilename = os.path.join(inputDirectory, "name2kegg.pkl")

if os.path.exists(name2keggFilename):
    print("Reading gene names")
    with open(name2keggFilename, "rb") as handle:
        name2gene = pickle.load(handle)
else:
    print("Producing gene names")
    d = {}
    nelements = len(elements)
    for count,element in enumerate(elements):
        if count % 10 == 0:
            print(f"{count}/{nelements}")
        if element.startswith("hsa"):
            names = search_gene_KEGG(element)
            for name in names:
                d[name] = element
    with open(name2keggFilename, "wb") as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
    name2gene = d
# Out:
# Reading gene names

# %%
# Read patient data
print("Reading patient data")
genes = pd.read_csv(os.path.join(inputDirectory, "genes.csv"))
patients = genes["name"].values.tolist()
classification = pd.read_csv(os.path.join(inputDirectory, "classification.csv"))

patient2class = {patient: classification.loc[classification["name"]==patient]["classification"].values.flatten().tolist()[0] for patient in patients}
numHealthy = sum([x == 'healthy' for x in patient2class.values()])
numDiseased = sum([x == 'diseased' for x in patient2class.values()])
# Out:
# Reading patient data

# %%
# Dividing genes into two frames (one for healthy individuals and one for diseased individuals)
genesHealthy = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="healthy"]
genesDiseased = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="diseased"]

# %%
# Building the graph of all relations contained in rel values
# Nodes are IDs, and node x correspond to the set of genes (and/or compound) id2element[x]
print("Building the relation graph")
G = nx.DiGraph() 
for pathwayID, relations in rel.items():
    for relation in relations:
        source = element2id[set2can(relation.source)]
        for targ in relation.target:
            target = element2id[set2can(targ)]
            newType = str(relation.relSubtypes)
            color = subtype2color[newType]
            pl = []
            if G.has_edge(source, target):
                d = G.get_edge_data(source, target)
                if d["color"] != color:
                    oldType = color2subtype[d["color"]]
                    print("- Edge ({},{}) of type {} for {} appears as {} for {}. ".format(
                        source, target, color2subtype[d["color"]], d["pathwayIDs"], 
                        str(relation.relSubtypes), pathwayID
                    ), end="")
                    if oldType[1:-1] in newType[1:-1]:
                        print("Overwriting with type {}".format(newType))
                    elif newType[1:-1] in oldType[1:-1]:
                        print("Overwriting with type {}".format(oldType))
                        color = subtype2color[oldType]
                    else:
                        print("\n****Conflict! Rewriting as {}".format(newType))
                pl = d["pathwayIDs"]
            G.add_edge(source, target, color=color, pathwayIDs=pl + [pathwayID])
            

# Computing the minimum fibres
cc=cardon_crochemore_colored(G)

colors = list(matplotlib.colors.CSS4_COLORS.values())
usedColors = 0

cc2fibresize = {}
cc2fibre = {}
ccnontrivial = {}
nontrivialclass2col = {}

fibres = []
node2fibre = {}
for v in set(cc.values()):
    fibre = [x for x in G.nodes() if cc[x] == v]
    fibres += [fibre]
    for x in fibre:
        node2fibre[x] = fibre
    cc2fibre[v] = fibre
    cc2fibresize[v] = len(fibre)
    if len(fibre) > 0:
        ccnontrivial[v] = cc[v]
        nontrivialclass2col[v] = colors[usedColors]
        usedColors = (usedColors + 1 ) % len(colors)
        if usedColors == 0:
            print("Wrap: more than", len(colors), "colors needed")
# Out:
# Building the relation graph
# - Edge (6,10) of type [('compound', 93)] for ['00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (6,5) of type [('compound', 93)] for ['00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (4,31) of type [('compound', 90)] for ['00010'] appears as [('compound', 91)] for 00010.
# ****Conflict! Rewriting as [('compound', 91)]
# - Edge (31,6) of type [('compound', 93)] for ['00010', '00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (64,68) of type [('compound', 129)] for ['00030'] appears as [('compound', 127)] for 00030.
# ****Conflict! Rewriting as [('compound', 127)]
# - Edge (22,6) of type [('compound', 95)] for ['00010', '00010'] appears as [('compound', 137)] for 00030.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (21,6) of type [('compound', 95)] for ['00010', '00010'] appears as [('compound', 137)] for 00030.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (24,22) of type [('compound', 108)] for ['00010'] appears as [('compound', 133)] for 00030.
# ****Conflict! Rewriting as [('compound', 133)]
# - Edge (24,21) of type [('compound', 108)] for ['00010'] appears as [('compound', 133)] for 00030.
# ****Conflict! Rewriting as [('compound', 133)]
# - Edge (6,38) of type [('compound', 112)] for ['00030', '00030'] appears as [('compound', 134)] for 00030.
# ****Conflict! Rewriting as [('compound', 134)]
# - Edge (75,64) of type [('compound', 127)] for ['00030'] appears as [('compound', 123)] for 00030.
# ****Conflict! Rewriting as [('compound', 123)]
# - Edge (64,68) of type [('compound', 127)] for ['00030', '00030'] appears as [('compound', 137)] for 00030.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (64,68) of type [('compound', 137)] for ['00030', '00030', '00030'] appears as [('compound', 132)] for 00030.
# ****Conflict! Rewriting as [('compound', 132)]
# - Edge (30,51) of type [('compound', 217)] for ['00040'] appears as [('compound', 138)] for 00040.
# ****Conflict! Rewriting as [('compound', 138)]
# - Edge (77,51) of type [('compound', 162)] for ['00040'] appears as [('compound', 217)] for 00040.
# ****Conflict! Rewriting as [('compound', 217)]
# - Edge (77,10) of type [('compound', 161)] for ['00051'] appears as [('compound', 128)] for 00051.
# ****Conflict! Rewriting as [('compound', 128)]
# - Edge (24,21) of type [('compound', 133)] for ['00010', '00030'] appears as [('compound', 164)] for 00051.
# ****Conflict! Rewriting as [('compound', 164)]
# - Edge (10,91) of type [('compound', 149)] for ['00051'] appears as [('compound', 129)] for 00051.
# ****Conflict! Rewriting as [('compound', 129)]
# - Edge (80,88) of type [('compound', 144)] for ['00040'] appears as [('compound', 162)] for 00051.
# ****Conflict! Rewriting as [('compound', 162)]
# - Edge (23,24) of type [('compound', 92)] for ['00010'] appears as [('compound', 175)] for 00051.
# ****Conflict! Rewriting as [('compound', 175)]
# - Edge (23,24) of type [('compound', 175)] for ['00010', '00051'] appears as [('compound', 147)] for 00051.
# ****Conflict! Rewriting as [('compound', 147)]
# - Edge (83,105) of type [('compound', 127)] for ['00052'] appears as [('compound', 128)] for 00052.
# ****Conflict! Rewriting as [('compound', 128)]
# - Edge (102,105) of type [('compound', 126)] for ['00052'] appears as [('compound', 128)] for 00052.
# ****Conflict! Rewriting as [('compound', 128)]
# - Edge (10,38) of type [('compound', 149)] for ['00051'] appears as [('compound', 161)] for 00052.
# ****Conflict! Rewriting as [('compound', 161)]
# - Edge (103,111) of type [('compound', 133)] for ['00052'] appears as [('compound', 144)] for 00052.
# ****Conflict! Rewriting as [('compound', 144)]
# - Edge (103,104) of type [('compound', 133)] for ['00052'] appears as [('compound', 144)] for 00052.
# ****Conflict! Rewriting as [('compound', 144)]
# - Edge (103,111) of type [('compound', 144)] for ['00052', '00052'] appears as [('compound', 133)] for 00052.
# ****Conflict! Rewriting as [('compound', 133)]
# - Edge (103,103) of type [('compound', 134)] for ['00052'] appears as [('compound', 133)] for 00052.
# ****Conflict! Rewriting as [('compound', 133)]
# - Edge (103,104) of type [('compound', 144)] for ['00052', '00052'] appears as [('compound', 133)] for 00052.
# ****Conflict! Rewriting as [('compound', 133)]
# - Edge (79,78) of type [('compound', 61)] for ['00053'] appears as [('compound', 194)] for 00053.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (70,77) of type [('compound', 114)] for ['00053'] appears as [('compound', 43)] for 00053.
# ****Conflict! Rewriting as [('compound', 43)]
# - Edge (115,114) of type [('compound', 191)] for ['00061'] appears as [('compound', 193)] for 00061.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (115,116) of type [('compound', 191)] for ['00061'] appears as [('compound', 193)] for 00061.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (119,121) of type [('compound', 301)] for ['00061'] appears as [('compound', 193)] for 00061.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (113,114) of type [('compound', 192)] for ['00061'] appears as [('compound', 400)] for 00061.
# ****Conflict! Rewriting as [('compound', 400)]
# - Edge (123,124) of type [('compound', 386)] for ['00061'] appears as [('compound', 365)] for 00061.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (125,124) of type [('compound', 164)] for ['00061'] appears as [('compound', 365)] for 00061.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (124,116) of type [('compound', 387)] for ['00061'] appears as [('compound', 366)] for 00061.
# ****Conflict! Rewriting as [('compound', 366)]
# - Edge (116,118) of type [('compound', 196)] for ['00061'] appears as [('compound', 367)] for 00061.
# ****Conflict! Rewriting as [('compound', 367)]
# - Edge (116,117) of type [('compound', 196)] for ['00061'] appears as [('compound', 367)] for 00061.
# ****Conflict! Rewriting as [('compound', 367)]
# - Edge (122,114) of type [('compound', 195)] for ['00061'] appears as [('compound', 167)] for 00061.
# ****Conflict! Rewriting as [('compound', 167)]
# - Edge (122,114) of type [('compound', 167)] for ['00061', '00061'] appears as [('compound', 168)] for 00061.
# ****Conflict! Rewriting as [('compound', 168)]
# - Edge (122,120) of type [('compound', 195)] for ['00061'] appears as [('compound', 168)] for 00061.
# ****Conflict! Rewriting as [('compound', 168)]
# - Edge (120,114) of type [('compound', 194)] for ['00061'] appears as [('compound', 168)] for 00061.
# ****Conflict! Rewriting as [('compound', 168)]
# - Edge (114,115) of type [('compound', 194)] for ['00061'] appears as [('compound', 169)] for 00061.
# ****Conflict! Rewriting as [('compound', 169)]
# - Edge (120,115) of type [('compound', 194)] for ['00061'] appears as [('compound', 369)] for 00061.
# ****Conflict! Rewriting as [('compound', 369)]
# - Edge (120,114) of type [('compound', 168)] for ['00061', '00061'] appears as [('compound', 169)] for 00061.
# ****Conflict! Rewriting as [('compound', 169)]
# - Edge (120,115) of type [('compound', 369)] for ['00061', '00061'] appears as [('compound', 169)] for 00061.
# ****Conflict! Rewriting as [('compound', 169)]
# - Edge (115,114) of type [('compound', 193)] for ['00061', '00061'] appears as [('compound', 170)] for 00061.
# ****Conflict! Rewriting as [('compound', 170)]
# - Edge (115,116) of type [('compound', 193)] for ['00061', '00061'] appears as [('compound', 170)] for 00061.
# ****Conflict! Rewriting as [('compound', 170)]
# - Edge (122,114) of type [('compound', 168)] for ['00061', '00061', '00061'] appears as [('compound', 172)] for 00061.
# ****Conflict! Rewriting as [('compound', 172)]
# - Edge (122,116) of type [('compound', 167)] for ['00061'] appears as [('compound', 172)] for 00061.
# ****Conflict! Rewriting as [('compound', 172)]
# - Edge (114,120) of type [('compound', 195)] for ['00061'] appears as [('compound', 173)] for 00061.
# ****Conflict! Rewriting as [('compound', 173)]
# - Edge (122,114) of type [('compound', 172)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 173)] for 00061.
# ****Conflict! Rewriting as [('compound', 173)]
# - Edge (122,120) of type [('compound', 168)] for ['00061', '00061'] appears as [('compound', 173)] for 00061.
# ****Conflict! Rewriting as [('compound', 173)]
# - Edge (114,115) of type [('compound', 169)] for ['00061', '00061'] appears as [('compound', 174)] for 00061.
# ****Conflict! Rewriting as [('compound', 174)]
# - Edge (120,114) of type [('compound', 169)] for ['00061', '00061', '00061'] appears as [('compound', 174)] for 00061.
# ****Conflict! Rewriting as [('compound', 174)]
# - Edge (120,115) of type [('compound', 169)] for ['00061', '00061', '00061'] appears as [('compound', 174)] for 00061.
# ****Conflict! Rewriting as [('compound', 174)]
# - Edge (114,115) of type [('compound', 174)] for ['00061', '00061', '00061'] appears as [('compound', 175)] for 00061.
# ****Conflict! Rewriting as [('compound', 175)]
# - Edge (114,118) of type [('compound', 196)] for ['00061'] appears as [('compound', 179)] for 00061.
# ****Conflict! Rewriting as [('compound', 179)]
# - Edge (114,117) of type [('compound', 196)] for ['00061'] appears as [('compound', 179)] for 00061.
# ****Conflict! Rewriting as [('compound', 179)]
# - Edge (116,118) of type [('compound', 367)] for ['00061', '00061', '00061'] appears as [('compound', 179)] for 00061.
# ****Conflict! Rewriting as [('compound', 179)]
# - Edge (116,117) of type [('compound', 367)] for ['00061', '00061', '00061'] appears as [('compound', 179)] for 00061.
# ****Conflict! Rewriting as [('compound', 179)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061'] appears as [('compound', 176)] for 00061.
# ****Conflict! Rewriting as [('compound', 176)]
# - Edge (114,120) of type [('compound', 173)] for ['00061', '00061'] appears as [('compound', 178)] for 00061.
# ****Conflict! Rewriting as [('compound', 178)]
# - Edge (116,114) of type [('compound', 176)] for ['00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (122,114) of type [('compound', 173)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 178)] for 00061.
# ****Conflict! Rewriting as [('compound', 178)]
# - Edge (122,120) of type [('compound', 173)] for ['00061', '00061', '00061'] appears as [('compound', 178)] for 00061.
# ****Conflict! Rewriting as [('compound', 178)]
# - Edge (129,114) of type [('compound', 176)] for ['00061', '00061'] appears as [('compound', 183)] for 00061.
# ****Conflict! Rewriting as [('compound', 183)]
# - Edge (114,115) of type [('compound', 175)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 177)] for 00061.
# ****Conflict! Rewriting as [('compound', 177)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 183)] for 00061.
# ****Conflict! Rewriting as [('compound', 183)]
# - Edge (120,115) of type [('compound', 174)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 177)] for 00061.
# ****Conflict! Rewriting as [('compound', 177)]
# - Edge (116,114) of type [('compound', 183)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (120,114) of type [('compound', 174)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 177)] for 00061.
# ****Conflict! Rewriting as [('compound', 177)]
# - Edge (129,116) of type [('compound', 176)] for ['00061'] appears as [('compound', 183)] for 00061.
# ****Conflict! Rewriting as [('compound', 183)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 187)] for 00061.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (116,114) of type [('compound', 187)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (129,114) of type [('compound', 183)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 184)] for 00061.
# ****Conflict! Rewriting as [('compound', 184)]
# - Edge (115,114) of type [('compound', 170)] for ['00061', '00061', '00061'] appears as [('compound', 176)] for 00061.
# ****Conflict! Rewriting as [('compound', 176)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 184)] for 00061.
# ****Conflict! Rewriting as [('compound', 184)]
# - Edge (115,116) of type [('compound', 170)] for ['00061', '00061', '00061'] appears as [('compound', 176)] for 00061.
# ****Conflict! Rewriting as [('compound', 176)]
# - Edge (116,114) of type [('compound', 184)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (114,118) of type [('compound', 179)] for ['00061', '00061'] appears as [('compound', 180)] for 00061.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (114,117) of type [('compound', 179)] for ['00061', '00061'] appears as [('compound', 180)] for 00061.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (129,116) of type [('compound', 183)] for ['00061', '00061'] appears as [('compound', 184)] for 00061.
# ****Conflict! Rewriting as [('compound', 184)]
# - Edge (116,118) of type [('compound', 179)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 180)] for 00061.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (116,117) of type [('compound', 179)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 180)] for 00061.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (114,126) of type [('compound', 163)] for ['00061'] appears as [('compound', 164)] for 00061.
# ****Conflict! Rewriting as [('compound', 164)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 188)] for 00061.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (114,120) of type [('compound', 178)] for ['00061', '00061', '00061'] appears as [('compound', 181)] for 00061.
# ****Conflict! Rewriting as [('compound', 181)]
# - Edge (116,114) of type [('compound', 188)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 191)] for 00061.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (122,114) of type [('compound', 178)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 181)] for 00061.
# ****Conflict! Rewriting as [('compound', 181)]
# - Edge (116,114) of type [('compound', 191)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 170)] for 00061.
# ****Conflict! Rewriting as [('compound', 170)]
# - Edge (116,114) of type [('compound', 170)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (122,120) of type [('compound', 178)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 181)] for 00061.
# ****Conflict! Rewriting as [('compound', 181)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 196)] for 00061.
# ****Conflict! Rewriting as [('compound', 196)]
# - Edge (120,114) of type [('compound', 177)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 182)] for 00061.
# ****Conflict! Rewriting as [('compound', 182)]
# - Edge (116,114) of type [('compound', 196)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 193)] for 00061.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (120,115) of type [('compound', 177)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 182)] for 00061.
# ****Conflict! Rewriting as [('compound', 182)]
# - Edge (116,114) of type [('compound', 193)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 193)] for 00061.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (114,115) of type [('compound', 177)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 182)] for 00061.
# ****Conflict! Rewriting as [('compound', 182)]
# - Edge (116,114) of type [('compound', 193)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (115,114) of type [('compound', 176)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 183)] for 00061.
# ****Conflict! Rewriting as [('compound', 183)]
# - Edge (115,116) of type [('compound', 176)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 183)] for 00061.
# ****Conflict! Rewriting as [('compound', 183)]
# - Edge (114,117) of type [('compound', 180)] for ['00061', '00061', '00061'] appears as [('compound', 187)] for 00061.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (114,118) of type [('compound', 180)] for ['00061', '00061', '00061'] appears as [('compound', 187)] for 00061.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (116,117) of type [('compound', 180)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 187)] for 00061.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (116,118) of type [('compound', 180)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 187)] for 00061.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (114,120) of type [('compound', 181)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 186)] for 00061.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (122,114) of type [('compound', 181)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 186)] for 00061.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (122,120) of type [('compound', 181)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 186)] for 00061.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (120,115) of type [('compound', 182)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 190)] for 00061.
# ****Conflict! Rewriting as [('compound', 190)]
# - Edge (120,114) of type [('compound', 182)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 185)] for 00061.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (114,116) of type [('compound', 191)] for ['00061'] appears as [('compound', 166)] for 00061.
# ****Conflict! Rewriting as [('compound', 166)]
# - Edge (120,115) of type [('compound', 190)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 185)] for 00061.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 167)] for 00061.
# ****Conflict! Rewriting as [('compound', 167)]
# - Edge (114,115) of type [('compound', 182)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 185)] for 00061.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (116,114) of type [('compound', 167)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (114,116) of type [('compound', 166)] for ['00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (115,129) of type [('compound', 183)] for ['00061'] appears as [('compound', 184)] for 00061.
# ****Conflict! Rewriting as [('compound', 184)]
# - Edge (124,116) of type [('compound', 366)] for ['00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (115,114) of type [('compound', 183)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 184)] for 00061.
# ****Conflict! Rewriting as [('compound', 184)]
# - Edge (115,114) of type [('compound', 184)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 191)] for 00061.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (115,116) of type [('compound', 183)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 184)] for 00061.
# ****Conflict! Rewriting as [('compound', 184)]
# - Edge (114,117) of type [('compound', 187)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 188)] for 00061.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (114,118) of type [('compound', 187)] for ['00061', '00061', '00061', '00061'] appears as [('compound', 188)] for 00061.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (116,117) of type [('compound', 187)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 188)] for 00061.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (116,118) of type [('compound', 187)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 188)] for 00061.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (114,120) of type [('compound', 186)] for ['00061', '00061', '00061', '00061', '00061'] appears as [('compound', 189)] for 00061.
# ****Conflict! Rewriting as [('compound', 189)]
# - Edge (122,114) of type [('compound', 186)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 189)] for 00061.
# ****Conflict! Rewriting as [('compound', 189)]
# - Edge (122,120) of type [('compound', 186)] for ['00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 189)] for 00061.
# ****Conflict! Rewriting as [('compound', 189)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 172)] for 00061.
# ****Conflict! Rewriting as [('compound', 172)]
# - Edge (114,115) of type [('compound', 185)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 190)] for 00061.
# ****Conflict! Rewriting as [('compound', 190)]
# - Edge (116,114) of type [('compound', 172)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 165)] for 00061.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (116,114) of type [('compound', 165)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 175)] for 00061.
# ****Conflict! Rewriting as [('compound', 175)]
# - Edge (120,114) of type [('compound', 185)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 190)] for 00061.
# ****Conflict! Rewriting as [('compound', 190)]
# - Edge (116,114) of type [('compound', 175)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 179)] for 00061.
# ****Conflict! Rewriting as [('compound', 179)]
# - Edge (116,114) of type [('compound', 179)] for ['00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061', '00061'] appears as [('compound', 180)] for 00061.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (132,133) of type [('compound', 74)] for ['00062'] appears as [('compound', 79)] for 00062.
# ****Conflict! Rewriting as [('compound', 79)]
# - Edge (115,132) of type [('compound', 75)] for ['00062'] appears as [('compound', 78)] for 00062.
# ****Conflict! Rewriting as [('compound', 78)]
# - Edge (137,115) of type [('compound', 76)] for ['00062'] appears as [('compound', 77)] for 00062.
# ****Conflict! Rewriting as [('compound', 77)]
# - Edge (133,137) of type [('compound', 80)] for ['00062'] appears as [('compound', 68)] for 00062.
# ****Conflict! Rewriting as [('compound', 68)]
# - Edge (133,137) of type [('compound', 68)] for ['00062', '00062'] appears as [('compound', 84)] for 00062.
# ****Conflict! Rewriting as [('compound', 84)]
# - Edge (132,133) of type [('compound', 79)] for ['00062', '00062'] appears as [('compound', 83)] for 00062.
# ****Conflict! Rewriting as [('compound', 83)]
# - Edge (132,133) of type [('compound', 83)] for ['00062', '00062', '00062'] appears as [('compound', 67)] for 00062.
# ****Conflict! Rewriting as [('compound', 67)]
# - Edge (115,132) of type [('compound', 78)] for ['00062', '00062'] appears as [('compound', 82)] for 00062.
# ****Conflict! Rewriting as [('compound', 82)]
# - Edge (115,132) of type [('compound', 82)] for ['00062', '00062', '00062'] appears as [('compound', 66)] for 00062.
# ****Conflict! Rewriting as [('compound', 66)]
# - Edge (137,115) of type [('compound', 77)] for ['00062', '00062'] appears as [('compound', 81)] for 00062.
# ****Conflict! Rewriting as [('compound', 81)]
# - Edge (137,115) of type [('compound', 81)] for ['00062', '00062', '00062'] appears as [('compound', 65)] for 00062.
# ****Conflict! Rewriting as [('compound', 65)]
# - Edge (133,137) of type [('compound', 84)] for ['00062', '00062', '00062'] appears as [('compound', 85)] for 00062.
# ****Conflict! Rewriting as [('compound', 85)]
# - Edge (140,137) of type [('compound', 68)] for ['00062'] appears as [('compound', 72)] for 00062.
# ****Conflict! Rewriting as [('compound', 72)]
# - Edge (132,133) of type [('compound', 67)] for ['00062', '00062', '00062', '00062'] appears as [('compound', 86)] for 00062.
# ****Conflict! Rewriting as [('compound', 86)]
# - Edge (133,137) of type [('compound', 85)] for ['00062', '00062', '00062', '00062'] appears as [('compound', 72)] for 00062.
# ****Conflict! Rewriting as [('compound', 72)]
# - Edge (115,132) of type [('compound', 66)] for ['00062', '00062', '00062', '00062'] appears as [('compound', 87)] for 00062.
# ****Conflict! Rewriting as [('compound', 87)]
# - Edge (132,140) of type [('compound', 67)] for ['00062'] appears as [('compound', 71)] for 00062.
# ****Conflict! Rewriting as [('compound', 71)]
# - Edge (132,133) of type [('compound', 86)] for ['00062', '00062', '00062', '00062', '00062'] appears as [('compound', 71)] for 00062.
# ****Conflict! Rewriting as [('compound', 71)]
# - Edge (115,132) of type [('compound', 87)] for ['00062', '00062', '00062', '00062', '00062'] appears as [('compound', 70)] for 00062.
# ****Conflict! Rewriting as [('compound', 70)]
# - Edge (137,115) of type [('compound', 65)] for ['00062', '00062', '00062', '00062'] appears as [('compound', 69)] for 00062.
# ****Conflict! Rewriting as [('compound', 69)]
# - Edge (140,137) of type [('compound', 72)] for ['00062', '00062'] appears as [('compound', 73)] for 00062.
# ****Conflict! Rewriting as [('compound', 73)]
# - Edge (133,137) of type [('compound', 72)] for ['00062', '00062', '00062', '00062', '00062'] appears as [('compound', 73)] for 00062.
# ****Conflict! Rewriting as [('compound', 73)]
# - Edge (132,140) of type [('compound', 71)] for ['00062', '00062'] appears as [('compound', 74)] for 00062.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (142,146) of type [('compound', 129)] for ['00071'] appears as [('compound', 134)] for 00071.
# ****Conflict! Rewriting as [('compound', 134)]
# - Edge (142,146) of type [('compound', 134)] for ['00071', '00071'] appears as [('compound', 144)] for 00071.
# ****Conflict! Rewriting as [('compound', 144)]
# - Edge (149,146) of type [('compound', 131)] for ['00071'] appears as [('compound', 137)] for 00071.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (149,146) of type [('compound', 137)] for ['00071', '00071'] appears as [('compound', 145)] for 00071.
# ****Conflict! Rewriting as [('compound', 145)]
# - Edge (142,146) of type [('compound', 144)] for ['00071', '00071', '00071'] appears as [('compound', 148)] for 00071.
# ****Conflict! Rewriting as [('compound', 148)]
# - Edge (149,146) of type [('compound', 145)] for ['00071', '00071', '00071'] appears as [('compound', 149)] for 00071.
# ****Conflict! Rewriting as [('compound', 149)]
# - Edge (142,146) of type [('compound', 148)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 159)] for 00071.
# ****Conflict! Rewriting as [('compound', 159)]
# - Edge (149,146) of type [('compound', 149)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 156)] for 00071.
# ****Conflict! Rewriting as [('compound', 156)]
# - Edge (149,146) of type [('compound', 156)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 163)] for 00071.
# ****Conflict! Rewriting as [('compound', 163)]
# - Edge (142,146) of type [('compound', 159)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 165)] for 00071.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (142,146) of type [('compound', 165)] for ['00071', '00071', '00071', '00071', '00071', '00071'] appears as [('compound', 171)] for 00071.
# ****Conflict! Rewriting as [('compound', 171)]
# - Edge (41,42) of type [('compound', 65)] for ['00020'] appears as [('compound', 173)] for 00071.
# ****Conflict! Rewriting as [('compound', 173)]
# - Edge (143,142) of type [('compound', 170)] for ['00071'] appears as [('compound', 128)] for 00071.
# ****Conflict! Rewriting as [('compound', 128)]
# - Edge (42,121) of type [('compound', 301)] for ['00061'] appears as [('compound', 173)] for 00071.
# ****Conflict! Rewriting as [('compound', 173)]
# - Edge (142,144) of type [('compound', 171)] for ['00071'] appears as [('compound', 129)] for 00071.
# ****Conflict! Rewriting as [('compound', 129)]
# - Edge (148,143) of type [('compound', 130)] for ['00071'] appears as [('compound', 133)] for 00071.
# ****Conflict! Rewriting as [('compound', 133)]
# - Edge (143,142) of type [('compound', 128)] for ['00071', '00071'] appears as [('compound', 136)] for 00071.
# ****Conflict! Rewriting as [('compound', 136)]
# - Edge (142,133) of type [('compound', 170)] for ['00071'] appears as [('compound', 136)] for 00071.
# ****Conflict! Rewriting as [('compound', 136)]
# - Edge (142,145) of type [('compound', 171)] for ['00071'] appears as [('compound', 134)] for 00071.
# ****Conflict! Rewriting as [('compound', 134)]
# - Edge (142,144) of type [('compound', 129)] for ['00071', '00071'] appears as [('compound', 134)] for 00071.
# ****Conflict! Rewriting as [('compound', 134)]
# - Edge (151,149) of type [('compound', 131)] for ['00071'] appears as [('compound', 137)] for 00071.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (144,149) of type [('compound', 131)] for ['00071'] appears as [('compound', 137)] for 00071.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (149,143) of type [('compound', 133)] for ['00071'] appears as [('compound', 142)] for 00071.
# ****Conflict! Rewriting as [('compound', 142)]
# - Edge (149,133) of type [('compound', 133)] for ['00071'] appears as [('compound', 142)] for 00071.
# ****Conflict! Rewriting as [('compound', 142)]
# - Edge (142,133) of type [('compound', 136)] for ['00071', '00071'] appears as [('compound', 143)] for 00071.
# ****Conflict! Rewriting as [('compound', 143)]
# - Edge (143,142) of type [('compound', 136)] for ['00071', '00071', '00071'] appears as [('compound', 143)] for 00071.
# ****Conflict! Rewriting as [('compound', 143)]
# - Edge (142,144) of type [('compound', 134)] for ['00071', '00071', '00071'] appears as [('compound', 144)] for 00071.
# ****Conflict! Rewriting as [('compound', 144)]
# - Edge (142,145) of type [('compound', 134)] for ['00071', '00071'] appears as [('compound', 144)] for 00071.
# ****Conflict! Rewriting as [('compound', 144)]
# - Edge (145,149) of type [('compound', 137)] for ['00071'] appears as [('compound', 145)] for 00071.
# ****Conflict! Rewriting as [('compound', 145)]
# - Edge (144,149) of type [('compound', 137)] for ['00071', '00071'] appears as [('compound', 145)] for 00071.
# ****Conflict! Rewriting as [('compound', 145)]
# - Edge (149,143) of type [('compound', 142)] for ['00071', '00071'] appears as [('compound', 152)] for 00071.
# ****Conflict! Rewriting as [('compound', 152)]
# - Edge (149,133) of type [('compound', 142)] for ['00071', '00071'] appears as [('compound', 152)] for 00071.
# ****Conflict! Rewriting as [('compound', 152)]
# - Edge (142,133) of type [('compound', 143)] for ['00071', '00071', '00071'] appears as [('compound', 150)] for 00071.
# ****Conflict! Rewriting as [('compound', 150)]
# - Edge (143,142) of type [('compound', 143)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 150)] for 00071.
# ****Conflict! Rewriting as [('compound', 150)]
# - Edge (142,144) of type [('compound', 144)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 148)] for 00071.
# ****Conflict! Rewriting as [('compound', 148)]
# - Edge (142,145) of type [('compound', 144)] for ['00071', '00071', '00071'] appears as [('compound', 148)] for 00071.
# ****Conflict! Rewriting as [('compound', 148)]
# - Edge (145,149) of type [('compound', 145)] for ['00071', '00071'] appears as [('compound', 149)] for 00071.
# ****Conflict! Rewriting as [('compound', 149)]
# - Edge (144,149) of type [('compound', 145)] for ['00071', '00071', '00071'] appears as [('compound', 149)] for 00071.
# ****Conflict! Rewriting as [('compound', 149)]
# - Edge (149,143) of type [('compound', 152)] for ['00071', '00071', '00071'] appears as [('compound', 158)] for 00071.
# ****Conflict! Rewriting as [('compound', 158)]
# - Edge (149,133) of type [('compound', 152)] for ['00071', '00071', '00071'] appears as [('compound', 158)] for 00071.
# ****Conflict! Rewriting as [('compound', 158)]
# - Edge (142,133) of type [('compound', 150)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 155)] for 00071.
# ****Conflict! Rewriting as [('compound', 155)]
# - Edge (143,142) of type [('compound', 150)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 155)] for 00071.
# ****Conflict! Rewriting as [('compound', 155)]
# - Edge (142,144) of type [('compound', 148)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 159)] for 00071.
# ****Conflict! Rewriting as [('compound', 159)]
# - Edge (149,143) of type [('compound', 158)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 130)] for 00071.
# ****Conflict! Rewriting as [('compound', 130)]
# - Edge (142,145) of type [('compound', 148)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 159)] for 00071.
# ****Conflict! Rewriting as [('compound', 159)]
# - Edge (145,149) of type [('compound', 149)] for ['00071', '00071', '00071'] appears as [('compound', 156)] for 00071.
# ****Conflict! Rewriting as [('compound', 156)]
# - Edge (144,149) of type [('compound', 149)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 156)] for 00071.
# ****Conflict! Rewriting as [('compound', 156)]
# - Edge (149,143) of type [('compound', 130)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 164)] for 00071.
# ****Conflict! Rewriting as [('compound', 164)]
# - Edge (149,133) of type [('compound', 158)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 164)] for 00071.
# ****Conflict! Rewriting as [('compound', 164)]
# - Edge (142,133) of type [('compound', 155)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 162)] for 00071.
# ****Conflict! Rewriting as [('compound', 162)]
# - Edge (142,144) of type [('compound', 159)] for ['00071', '00071', '00071', '00071', '00071', '00071'] appears as [('compound', 165)] for 00071.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (142,145) of type [('compound', 159)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 165)] for 00071.
# ****Conflict! Rewriting as [('compound', 165)]
# - Edge (145,149) of type [('compound', 156)] for ['00071', '00071', '00071', '00071'] appears as [('compound', 163)] for 00071.
# ****Conflict! Rewriting as [('compound', 163)]
# - Edge (144,149) of type [('compound', 156)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 163)] for 00071.
# ****Conflict! Rewriting as [('compound', 163)]
# - Edge (149,143) of type [('compound', 164)] for ['00071', '00071', '00071', '00071', '00071', '00071'] appears as [('compound', 169)] for 00071.
# ****Conflict! Rewriting as [('compound', 169)]
# - Edge (149,133) of type [('compound', 164)] for ['00071', '00071', '00071', '00071', '00071'] appears as [('compound', 169)] for 00071.
# ****Conflict! Rewriting as [('compound', 169)]
# - Edge (159,160) of type [('compound', 117)] for ['00100'] appears as [('compound', 123)] for 00100.
# ****Conflict! Rewriting as [('compound', 123)]
# - Edge (159,160) of type [('compound', 123)] for ['00100', '00100'] appears as [('compound', 120)] for 00100.
# ****Conflict! Rewriting as [('compound', 120)]
# - Edge (159,160) of type [('compound', 120)] for ['00100', '00100', '00100'] appears as [('compound', 113)] for 00100.
# ****Conflict! Rewriting as [('compound', 113)]
# - Edge (165,166) of type [('compound', 54)] for ['00100'] appears as [('compound', 55)] for 00100.
# ****Conflict! Rewriting as [('compound', 55)]
# - Edge (164,160) of type [('compound', 113)] for ['00100'] appears as [('compound', 114)] for 00100.
# ****Conflict! Rewriting as [('compound', 114)]
# - Edge (163,164) of type [('compound', 114)] for ['00100'] appears as [('compound', 80)] for 00100.
# ****Conflict! Rewriting as [('compound', 80)]
# - Edge (160,163) of type [('compound', 84)] for ['00100'] appears as [('compound', 78)] for 00100.
# ****Conflict! Rewriting as [('compound', 78)]
# - Edge (163,160) of type [('compound', 114)] for ['00100'] appears as [('compound', 140)] for 00100.
# ****Conflict! Rewriting as [('compound', 140)]
# - Edge (179,161) of type [('compound', 112)] for ['00100'] appears as [('compound', 194)] for 00100.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (186,187) of type [('compound', 144)] for ['00120'] appears as [('compound', 134)] for 00120.
# ****Conflict! Rewriting as [('compound', 134)]
# - Edge (184,191) of type [('compound', 168)] for ['00120'] appears as [('compound', 126)] for 00120.
# ****Conflict! Rewriting as [('compound', 126)]
# - Edge (182,193) of type [('compound', 137)] for ['00120', '00120'] appears as [('compound', 136)] for 00120.
# ****Conflict! Rewriting as [('compound', 136)]
# - Edge (181,182) of type [('compound', 137)] for ['00120'] appears as [('compound', 136)] for 00120.
# ****Conflict! Rewriting as [('compound', 136)]
# - Edge (180,181) of type [('compound', 141)] for ['00120'] appears as [('compound', 148)] for 00120.
# ****Conflict! Rewriting as [('compound', 148)]
# - Edge (181,185) of type [('compound', 135)] for ['00120'] appears as [('compound', 149)] for 00120.
# ****Conflict! Rewriting as [('compound', 149)]
# - Edge (185,188) of type [('compound', 142)] for ['00120'] appears as [('compound', 150)] for 00120.
# ****Conflict! Rewriting as [('compound', 150)]
# - Edge (182,197) of type [('compound', 158)] for ['00120'] appears as [('compound', 161)] for 00120.
# ****Conflict! Rewriting as [('compound', 161)]
# - Edge (186,186) of type [('compound', 165)] for ['00120'] appears as [('compound', 166)] for 00120.
# ****Conflict! Rewriting as [('compound', 166)]
# - Edge (188,186) of type [('compound', 143)] for ['00120'] appears as [('compound', 151)] for 00120.
# ****Conflict! Rewriting as [('compound', 151)]
# - Edge (184,191) of type [('compound', 126)] for ['00120', '00120'] appears as [('compound', 138)] for 00120.
# ****Conflict! Rewriting as [('compound', 138)]
# - Edge (187,182) of type [('compound', 136)] for ['00120', '00120'] appears as [('compound', 137)] for 00120.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (192,191) of type [('compound', 138)] for ['00120'] appears as [('compound', 119)] for 00120.
# ****Conflict! Rewriting as [('compound', 119)]
# - Edge (182,197) of type [('compound', 161)] for ['00120', '00120'] appears as [('compound', 153)] for 00120.
# ****Conflict! Rewriting as [('compound', 153)]
# - Edge (187,181) of type [('compound', 136)] for ['00120'] appears as [('compound', 137)] for 00120.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (182,197) of type [('compound', 153)] for ['00120', '00120', '00120'] appears as [('compound', 156)] for 00120.
# ****Conflict! Rewriting as [('compound', 156)]
# - Edge (196,198) of type [('compound', 131)] for ['00120'] appears as [('compound', 132)] for 00120.
# ****Conflict! Rewriting as [('compound', 132)]
# - Edge (182,181) of type [('compound', 136)] for ['00120'] appears as [('compound', 137)] for 00120.
# ****Conflict! Rewriting as [('compound', 137)]
# - Edge (198,180) of type [('compound', 145)] for ['00120'] appears as [('compound', 133)] for 00120.
# ****Conflict! Rewriting as [('compound', 133)]
# - Edge (199,202) of type [('compound', 182)] for ['00130'] appears as [('compound', 180)] for 00130.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (199,200) of type [('compound', 121)] for ['00130'] appears as [('compound', 123)] for 00130.
# ****Conflict! Rewriting as [('compound', 123)]
# - Edge (196,198) of type [('compound', 132)] for ['00120', '00120'] appears as [('compound', 86)] for 00140.
# ****Conflict! Rewriting as [('compound', 86)]
# - Edge (198,79) of type [('compound', 88)] for ['00140'] appears as [('compound', 90)] for 00140.
# ****Conflict! Rewriting as [('compound', 90)]
# - Edge (217,219) of type [('compound', 336)] for ['00140'] appears as [('compound', 334)] for 00140.
# ****Conflict! Rewriting as [('compound', 334)]
# - Edge (217,211) of type [('compound', 334)] for ['00140'] appears as [('compound', 336)] for 00140.
# ****Conflict! Rewriting as [('compound', 336)]
# ...
# - Edge (4091,1385) of type [('binding/association', '---')] for ['05130', '05205'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (122,3179) of type [('expression', '-->')] for ['04620', '04622', '05167', '05169', '05169'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (1047,1050) of type [('missing interaction', '-/-')] for ['01521', '04014', '04068', '04071', '04071', '04072', '04140', '04150', '04151', '04152', '04210', '04211', '04213', '04213', '04218', '04613', '04666', '04917', '04917', '04919', '04926', '04931', '04960', '04973', '05010', '05131', '05135', '05160', '05162', '05163', '05163', '05164', '05165', '05166', '05167', '05168', '05169', '05169', '05170', '05200', '05207', '05207', '05207', '05207', '05207', '05207', '05208', '05210', '05212', '05214', '05223', '05224', '05224', '05224', '05225', '05225', '05226', '05226', '05231', '05235', '05235', '05235', '05415'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (122,1110) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04936', '04936', '05162', '05163', '05168', '05169', '05170', '05170', '05235'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (1050,1051) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['01521', '04014', '04072', '04151', '04211', '04213', '04213', '04213', '04218', '04510', '04611', '04613', '04666', '04917', '04917', '04919', '04926', '04973', '05010', '05131', '05135', '05160', '05162', '05163', '05163', '05164', '05165', '05166', '05167', '05168', '05169', '05169', '05170', '05200', '05207', '05207', '05207', '05207', '05207', '05207', '05208', '05210', '05212', '05212', '05214', '05223', '05223', '05224', '05224', '05224', '05225', '05225', '05226', '05226', '05235', '05235', '05235', '05415'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (1578,1111) of type [('activation', '-->'), ('dissociation', '-+-')] for ['04210', '04380', '04620', '04668', '04668', '04926', '04926', '04931', '04931', '04936', '05120', '05134', '05135', '05142', '05142', '05161', '05163', '05163', '05166', '05167', '05222'] appears as [('dissociation', '-+-')] for 05417. Overwriting with type [('activation', '-->'), ('dissociation', '-+-')]
# - Edge (1036,1369) of type [('indirect effect', '..>')] for ['04360', '04912'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1036,1027) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04912', '04915', '05207'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1027,1029) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04360', '04933'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1027,1097) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04722', '04933', '05208'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (2582,2583) of type [('activation', '-->')] for ['04217', '04621', '04623', '04625', '05130', '05131', '05132', '05135'] appears as [('binding/association', '---')] for 05417.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (1051,1066) of type [('missing interaction', '-/-')] for ['01521', '04012', '04151', '04510', '04660', '04662', '04722', '04910', '04917', '04919', '04931', '04935', '04936', '05135', '05160', '05162', '05163', '05165', '05200', '05210', '05215', '05226', '05415'] appears as [('inhibition', '--|'), ('phosphorylation', '+p')] for 05417.
# ****Conflict! Rewriting as [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (2562,2562) of type [('activation', '-->'), ('indirect effect', '..>')] for ['05132'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (2562,1114) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04217', '04621', '04623', '05130', '05131', '05132', '05134', '05164', '05171'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (2562,1790) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04621', '04623', '05130', '05131', '05132', '05134', '05164'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1401,1402) of type [('activation', '-->'), ('binding/association', '---')] for ['04014', '04015', '04022', '04024', '04218', '04261', '04270', '04371', '04625', '04625', '04728', '04740', '04744', '04750', '04915', '04921', '04924', '04925', '04925', '04970', '04971', '05010', '05012', '05022', '05022', '05031', '05031', '05152', '05163', '05167', '05170', '05200', '05214', '05214'] appears as [('binding/association', '---')] for 05417. Overwriting with type [('activation', '-->'), ('binding/association', '---')]
# - Edge (1390,1401) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04613', '04926', '05225', '05235'] appears as [('inhibition', '--|'), ('indirect effect', '..>')] for 05417.
# ****Conflict! Rewriting as [('inhibition', '--|'), ('indirect effect', '..>')]
# - Edge (1111,1508) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04931'] appears as [('repression', '--|')] for 05417.
# ****Conflict! Rewriting as [('repression', '--|')]
# - Edge (1111,1037) of type [('expression', '-->')] for ['05161', '05169', '05215'] appears as [('repression', '--|')] for 05417.
# ****Conflict! Rewriting as [('repression', '--|')]
# - Edge (1111,3825) of type [('expression', '-->')] for ['04933', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,3149) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,1892) of type [('expression', '-->')] for ['04933', '05164', '05164', '05169', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,1889) of type [('expression', '-->')] for ['04933', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,1771) of type [('expression', '-->')] for ['04621', '04657', '04933', '05163', '05163', '05164', '05164', '05168', '05168', '05171', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1401,1357) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04066', '04360', '04911', '04911', '04911', '04922', '04934', '05152'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1111,1775) of type [('expression', '-->')] for ['04620', '04621', '04622', '04657', '04933', '04936', '04936', '05120', '05135', '05163', '05163', '05164', '05164', '05167', '05171', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (2330,2347) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04140', '04210', '04932', '05010', '05012', '05014', '05020', '05022'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (1111,4551) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,1129) of type [('expression', '-->')] for ['05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,1114) of type [('expression', '-->')] for ['01523', '04620', '04621', '04621', '04657', '04657', '04936', '05135', '05140', '05142', '05168', '05171', '05171', '05417', '05417', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,1065) of type [('expression', '-->')] for ['01523', '04620', '04621', '04623', '04623', '04657', '04657', '04931', '04931', '04932', '04932', '04933', '04936', '05010', '05022', '05135', '05152', '05161', '05162', '05163', '05163', '05164', '05164', '05166', '05167', '05168', '05169', '05171', '05171', '05171', '05417', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1111,1113) of type [('expression', '-->')] for ['01523', '04620', '04621', '04622', '04657', '04657', '04657', '04660', '04931', '04931', '04932', '04933', '04936', '05010', '05022', '05135', '05140', '05145', '05152', '05160', '05161', '05164', '05164', '05168', '05169', '05170', '05171', '05171', '05321', '05417', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (3969,3962) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['05012', '05014', '05022'] appears as [('inhibition', '--|')] for 05417. Overwriting with type [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (3969,2330) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['05012', '05014', '05020', '05022'] appears as [('inhibition', '--|')] for 05417. Overwriting with type [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (1050,1051) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['01521', '04014', '04072', '04151', '04211', '04213', '04213', '04213', '04218', '04510', '04611', '04613', '04666', '04917', '04917', '04919', '04926', '04973', '05010', '05131', '05135', '05160', '05162', '05163', '05163', '05164', '05165', '05166', '05167', '05168', '05169', '05169', '05170', '05200', '05207', '05207', '05207', '05207', '05207', '05207', '05208', '05210', '05212', '05212', '05214', '05223', '05223', '05224', '05224', '05224', '05225', '05225', '05226', '05226', '05235', '05235', '05235', '05415', '05417'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (3969,2374) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['05012', '05014', '05022'] appears as [('inhibition', '--|')] for 05417. Overwriting with type [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (1126,1051) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['01524', '04068', '04071', '04140', '04150', '04151', '04152', '04210', '04510', '04660', '04664', '04722', '04910', '04919', '04931', '05145', '05208', '05213', '05215', '05223', '05223', '05231'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (1402,1318) of type [('binding/association', '---')] for ['04114', '04218', '04625', '04625', '04720', '04921', '04924', '05010', '05022', '05031', '05152', '05163', '05167', '05170'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1133,1129) of type [('activation', '-->'), ('binding/association', '---')] for ['01524', '04010', '04060', '04210', '04217', '04650', '04932', '04936', '04940', '05022', '05130', '05142', '05142', '05143', '05160', '05161', '05162', '05163', '05164', '05165', '05168', '05170', '05170', '05170', '05200', '05205', '05320', '05330', '05332', '05332'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('binding/association', '---')]
# - Edge (1727,1119) of type [('indirect effect', '..>')] for ['04115'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1111,1771) of type [('activation', '-->')] for ['04621', '04657', '04933', '05163', '05163', '05164', '05164', '05168', '05168', '05171', '05417', '05417'] appears as [('expression', '-->')] for 05418.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (1111,1889) of type [('activation', '-->')] for ['04933', '05417', '05417'] appears as [('expression', '-->')] for 05418.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (1111,1892) of type [('activation', '-->')] for ['04933', '05164', '05164', '05169', '05417', '05417'] appears as [('expression', '-->')] for 05418.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (1111,3825) of type [('activation', '-->')] for ['04933', '05417', '05417'] appears as [('expression', '-->')] for 05418.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (1111,1113) of type [('activation', '-->')] for ['01523', '04620', '04621', '04622', '04657', '04657', '04657', '04660', '04931', '04931', '04932', '04933', '04936', '05010', '05022', '05135', '05140', '05145', '05152', '05160', '05161', '05164', '05164', '05168', '05169', '05170', '05171', '05171', '05321', '05417', '05417', '05417'] appears as [('expression', '-->')] for 05418.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (122,1928) of type [('activation', '-->')] for ['05208', '05208'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05418. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1090,1037) of type [('inhibition', '--|')] for ['05131', '05226'] appears as [('inhibition', '--|'), ('indirect effect', '..>')] for 05418. Overwriting with type [('inhibition', '--|'), ('indirect effect', '..>')]
# - Edge (3982,2404) of type [('inhibition', '--|')] for ['05012', '05200', '05208', '05225'] appears as [('dissociation', '-+-')] for 05418.
# ****Conflict! Rewriting as [('dissociation', '-+-')]
# - Edge (1385,1406) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04015', '04520', '05100', '05130'] appears as [('activation', '-->')] for 05418. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (122,2370) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04150'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05418.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1508,1499) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04022', '04071', '04611', '04915', '04921', '04926', '04931', '04931', '05415'] appears as [('activation', '-->')] for 05418. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1508,1499) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04022', '04071', '04611', '04915', '04921', '04926', '04931', '04931', '05415', '05418'] appears as [('activation', '-->')] for 05418. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1127,1351) of type [('activation', '-->')] for ['04668', '04936', '05208'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05418. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed

# %%
# Build node2columns, mapping each node of G to the list of genes corresponding to it
# for which we know a value (in the genes dataframe), sorted
#

print("Mapping genes to columns")
namedGenes = set(name2gene.values())     
columns = set(genes.columns.values.tolist()[2:])
node2columns = {}
for node in G.nodes():
    nodeGenes = can2set(id2element[node])
    s = []
    for gene in nodeGenes & namedGenes:
        for k,v in name2gene.items():
            if v == gene:
                if k in columns:
                    s += [k]
    node2columns[node]=sorted(s)
# Out:
# Mapping genes to columns

# %%
if produceGraphsWithCCcoloring:
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
        canvas = KGMLCanvas(pathway)
        for k in pathway.entries:
            name = pathway.entries[k].name
            canonicalName = set2can(words2set(name))
            if canonicalName in element2id.keys():
                node = element2id[canonicalName]
                klass = cc[node]
                if klass in nontrivialclass2col:
                    pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                    pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                else:
                    pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                    pathway.enries[k].graphics[0].fgcolor = "#FFFFFF"
                s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"
        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway)).mkdir(parents=True, exist_ok=True)
        canvas.draw(os.path.join(outputDirectory, organism, safeSuperpathway, pdfName))
    with open(os.path.join(outputDirectory, organism, safeSuperpathway, "all.tsv"), "wt") as file:
        file.write(s)

# %%
def columns2nodes(columns, node2columns, ignoreEmpty = True):
    """
        Returns a map from columns to the nodes where the column appears.
    """
    res = {} 
    for c in columns:
        s = set([])
        for no, co in node2columns.items():
            if c in co:
                s |= set([no])
        if len(s) > 0 or not ignoreEmpty:
            res[c] = s
    return res

c2n = columns2nodes(columns, node2columns)
usableColumns = list(c2n.keys())

# %%
def corrForPair(genes, set1, set2, correlationFunction = lambda x: scipy.stats.kendalltau(x).statistic):
    """
        Given a dataframe genes (i.e., a set of patients), and two sets of column names (set1, set2), 
        compute the correlation function
        for every pair of columns in set1 and set2 and return the average statistic and its std.
    """
    taus = []
    for gene1 in set1:
        for gene2 in set2:
            expr1 = genes.loc[:,gene1].values.tolist()
            expr2 = genes.loc[:,gene2].values.tolist()
            taus += [scipy.stats.kendalltau(expr1, expr2).statistic]
    return pd.DataFrame(taus).mean().values[0], pd.DataFrame(taus).std().values[0]

# %%
def sampleDeltaDist(genes, set1, set2, numberOfRows1, numberOfSamples = 500, correlationFunction = lambda x: scipy.stats.kendalltau(x).statistic):
    """
        Repeatedly (for numberOfSamples times) do the following:
        - select numberOfRows1 rows of genes, and then compute tauForPair on those rows for set1 and set2
        - do the same for remaining rows
        - take the difference between the two resulting set of taus.
        Return the mean and std of differences.
    """
    diffs = []
    
    for i in range(numberOfSamples):
        genes1 = random.sample(range(len(genes)), numberOfRows1)
        genes2 = list(set(range(len(genes)))-set(genes1))
        mt1, mstd1 = corrForPair(genes.iloc[genes1], set1, set2, correlationFunction)
        mt2, mstd2 = corrForPair(genes.iloc[genes2], set1, set2, correlationFunction)
        diffs += [mt1-mt2]
    return diffs


def deltaForPair(genes1, genes2, set1, set2, correlationFunction = lambda x: scipy.stats.kendalltau(x).statistic):
    """
        Compute corrForPair for set1 and set2 over the set of rows genes1 and genes2, and return
        the difference of taus.
    """
    mt1, mstd1 = corrForPair(genes1, set1, set2, correlationFunction)
    mt2, mstd2 = corrForPair(genes2, set1, set2, correlationFunction)
    return mt1-mt2

# %%
correlationFunction = lambda x:  scipy.stats.spearmanr(x).statistic
correlationFunctionName = "spearmanrho"
relAnomalies = os.path.join(inputDirectory, "anomalies-" + correlationFunctionName + ".csv")

if os.path.exists(relAnomalies):
    print("Reading anomalies")
    relcorrel = pd.read_csv(relAnomalies)
else:
    print("Producing anomalies")
    relcorrel = pd.DataFrame(columns=[
        "Source gene(s)",
        "Target gene(s)",
        "Pathway ID",
        "Relation type",
        "Correlation for healthy",
        "Correlation for diseased",
        "Correlation difference (H-D)",
        "Expected correlation difference",
        "P-value",
        "Comment"
        ])
    numberOfEdges = G.number_of_edges()
    doneEdges = 0
    for s,t,d in G.edges(data=True):
        if doneEdges % 10 == 0:
            print("{:.2f}% done".format(100 * doneEdges / numberOfEdges))
        doneEdges += 1
        subtypeName = [k for k,v in subtype2color.items() if d["color"]==v][0]
        sg = node2columns[s]
        tg = node2columns[t]
        if len(sg) == 0 or len(tg) == 0:
            continue
        avgh, stdh = corrForPair(genesHealthy, sg, tg, correlationFunction=correlationFunction)
        avgd, stdd = corrForPair(genesDiseased, sg, tg, correlationFunction=correlationFunction)
        taudiff = avgh - avgd
        tt = sampleDeltaDist(genes, sg, tg, numHealthy, correlationFunction=correlationFunction)
        ttmean = pd.DataFrame(tt).mean().values[0]
        ecdft = scipy.stats.ecdf(tt)  # Empirical CDF
        if taudiff < 0:
            pvalue = ecdft.cdf.evaluate(taudiff)
            comment = "More correlated than for healthy individuals"
        else:
            pvalue = 1 - ecdft.cdf.evaluate(taudiff)    
            comment = "Less correlated than for healthy individuals"
        if produceAnomaliesForNonsignificantPairs or produpvalue <= confidence:
            relcorrel.loc[len(relcorrel)] = [
                str(sg),
                str(tg),
                d["pathwayIDs"],
                subtypeName,
                avgh, 
                avgd,
                taudiff,
                ttmean,
                pvalue,
                comment
            ]
    relcorrel = relcorrel.sort_values(by=["P-value"], ascending=True)
    relcorrel.to_csv(relAnomalies)
# Out:
# Producing anomalies
# 0.00% done
# 0.07% done
# 0.15% done
# 0.22% done
# 0.30% done
# 0.37% done
# 0.45% done
# 0.52% done
# 0.60% done
# 0.67% done
# 0.74% done
# 0.82% done
# 0.89% done
# 0.97% done
# 1.04% done
# 1.12% done
# 1.19% done
# 1.27% done
# 1.34% done
# 1.42% done
# 1.49% done
# 1.56% done
# 1.64% done
# 1.71% done
# 1.79% done
# 1.86% done
# 1.94% done
# 2.01% done
# 2.09% done
# 2.16% done
# 2.23% done
# 2.31% done
# 2.38% done
# 2.46% done
# 2.53% done
# 2.61% done
# 2.68% done
# 2.76% done
# 2.83% done
# 2.91% done
# 2.98% done
# 3.05% done
# 3.13% done
# 3.20% done
# 3.28% done
# 3.35% done
# 3.43% done
# 3.50% done
# 3.58% done
# 3.65% done
# 3.72% done
# 3.80% done
# 3.87% done
# 3.95% done
# 4.02% done
# 4.10% done
# 4.17% done
# 4.25% done
# 4.32% done
# 4.40% done
# 4.47% done
# 4.54% done
# 4.62% done
# 4.69% done
# 4.77% done
# 4.84% done
# 4.92% done
# 4.99% done
# 5.07% done
# 5.14% done
# 5.21% done
# 5.29% done
# 5.36% done
# 5.44% done
# 5.51% done
# 5.59% done
# 5.66% done
# 5.74% done
# 5.81% done
# 5.89% done
# 5.96% done
# 6.03% done
# 6.11% done
# 6.18% done
# 6.26% done
# 6.33% done
# 6.41% done
# 6.48% done
# 6.56% done
# 6.63% done
# 6.70% done
# 6.78% done
# 6.85% done
# 6.93% done
# 7.00% done
# 7.08% done
# 7.15% done
# 7.23% done
# 7.30% done
# 7.38% done
# 7.45% done
# 7.52% done
# 7.60% done
# 7.67% done
# 7.75% done
# 7.82% done
# 7.90% done
# 7.97% done
# 8.05% done
# 8.12% done
# 8.19% done
# 8.27% done
# 8.34% done
# 8.42% done
# 8.49% done
# 8.57% done
# 8.64% done
# 8.72% done
# 8.79% done
# 8.87% done
# 8.94% done
# 9.01% done
# 9.09% done
# 9.16% done
# 9.24% done
# 9.31% done
# 9.39% done
# 9.46% done
# 9.54% done
# 9.61% done
# 9.68% done
# 9.76% done
# 9.83% done
# 9.91% done
# 9.98% done
# 10.06% done
# 10.13% done
# 10.21% done
# 10.28% done
# 10.36% done
# 10.43% done
# 10.50% done
# 10.58% done
# 10.65% done
# 10.73% done
# 10.80% done
# 10.88% done
# 10.95% done
# 11.03% done
# 11.10% done
# 11.17% done
# 11.25% done
# 11.32% done
# 11.40% done
# 11.47% done
# 11.55% done
# 11.62% done
# 11.70% done
# 11.77% done
# 11.85% done
# 11.92% done
# 11.99% done
# 12.07% done
# 12.14% done
# 12.22% done
# 12.29% done
# 12.37% done
# 12.44% done
# 12.52% done
# 12.59% done
# 12.66% done
# 12.74% done
# 12.81% done
# 12.89% done
# 12.96% done
# 13.04% done
# 13.11% done
# 13.19% done
# 13.26% done
# 13.34% done
# 13.41% done
# 13.48% done
# 13.56% done
# 13.63% done
# 13.71% done
# 13.78% done
# 13.86% done
# 13.93% done
# 14.01% done
# 14.08% done
# 14.15% done
# 14.23% done
# 14.30% done
# 14.38% done
# 14.45% done
# 14.53% done
# 14.60% done
# 14.68% done
# 14.75% done
# 14.83% done
# 14.90% done
# 14.97% done
# 15.05% done
# 15.12% done
# 15.20% done
# 15.27% done
# 15.35% done
# 15.42% done
# 15.50% done
# 15.57% done
# 15.64% done
# 15.72% done
# 15.79% done
# 15.87% done
# 15.94% done
# 16.02% done
# 16.09% done
# 16.17% done
# 16.24% done
# 16.32% done
# 16.39% done
# 16.46% done
# 16.54% done
# 16.61% done
# 16.69% done
# 16.76% done
# 16.84% done
# 16.91% done
# 16.99% done
# 17.06% done
# 17.13% done
# 17.21% done
# 17.28% done
# 17.36% done
# 17.43% done
# 17.51% done
# 17.58% done
# 17.66% done
# 17.73% done
# 17.81% done
# 17.88% done
# 17.95% done
# 18.03% done
# 18.10% done
# 18.18% done
# 18.25% done
# 18.33% done
# 18.40% done
# 18.48% done
# 18.55% done
# 18.62% done
# 18.70% done
# 18.77% done
# 18.85% done
# 18.92% done
# 19.00% done
# 19.07% done
# 19.15% done
# 19.22% done
# 19.30% done
# 19.37% done
# 19.44% done
# 19.52% done
# 19.59% done
# 19.67% done
# 19.74% done
# 19.82% done
# 19.89% done
# 19.97% done
# 20.04% done
# 20.11% done
# 20.19% done
# 20.26% done
# 20.34% done
# 20.41% done
# 20.49% done
# 20.56% done
# 20.64% done
# 20.71% done
# 20.79% done
# 20.86% done
# 20.93% done
# 21.01% done
# 21.08% done
# 21.16% done
# 21.23% done
# 21.31% done
# 21.38% done
# 21.46% done
# 21.53% done
# 21.60% done
# 21.68% done
# 21.75% done
# 21.83% done
# 21.90% done
# 21.98% done
# 22.05% done
# 22.13% done
# 22.20% done
# 22.28% done
# 22.35% done
# 22.42% done
# 22.50% done
# 22.57% done
# 22.65% done
# 22.72% done
# 22.80% done
# 22.87% done
# 22.95% done
# 23.02% done
# 23.09% done
# 23.17% done
# 23.24% done
# 23.32% done
# 23.39% done
# 23.47% done
# 23.54% done
# 23.62% done
# 23.69% done
# 23.77% done
# 23.84% done
# 23.91% done
# 23.99% done
# 24.06% done
# 24.14% done
# 24.21% done
# 24.29% done
# 24.36% done
# 24.44% done
# 24.51% done
# 24.58% done
# 24.66% done
# 24.73% done
# 24.81% done
# 24.88% done
# 24.96% done
# 25.03% done
# 25.11% done
# 25.18% done
# 25.26% done
# 25.33% done
# 25.40% done
# 25.48% done
# 25.55% done
# 25.63% done
# 25.70% done
# 25.78% done
# 25.85% done
# 25.93% done
# 26.00% done
# 26.07% done
# 26.15% done
# 26.22% done
# 26.30% done
# 26.37% done
# 26.45% done
# 26.52% done
# 26.60% done
# 26.67% done
# 26.75% done
# 26.82% done
# 26.89% done
# 26.97% done
# 27.04% done
# 27.12% done
# 27.19% done
# 27.27% done
# 27.34% done
# 27.42% done
# 27.49% done
# 27.56% done
# 27.64% done
# 27.71% done
# 27.79% done
# 27.86% done
# 27.94% done
# 28.01% done
# 28.09% done
# 28.16% done
# 28.24% done
# 28.31% done
# 28.38% done
# 28.46% done
# 28.53% done
# 28.61% done
# 28.68% done
# 28.76% done
# 28.83% done
# 28.91% done
# 28.98% done
# 29.05% done
# 29.13% done
# 29.20% done
# 29.28% done
# 29.35% done
# 29.43% done
# 29.50% done
# 29.58% done
# 29.65% done
# 29.73% done
# 29.80% done
# 29.87% done
# 29.95% done
# 30.02% done
# 30.10% done
# 30.17% done
# 30.25% done
# 30.32% done
# 30.40% done
# 30.47% done
# 30.54% done
# 30.62% done
# 30.69% done
# 30.77% done
# 30.84% done
# 30.92% done
# 30.99% done
# 31.07% done
# 31.14% done
# 31.22% done
# 31.29% done
# 31.36% done
# 31.44% done
# 31.51% done
# 31.59% done
# 31.66% done
# 31.74% done
# 31.81% done
# 31.89% done
# 31.96% done
# 32.03% done
# 32.11% done
# 32.18% done
# 32.26% done
# 32.33% done
# 32.41% done
# 32.48% done
# 32.56% done
# 32.63% done
# 32.71% done
# 32.78% done
# 32.85% done
# 32.93% done
# 33.00% done
# 33.08% done
# 33.15% done
# 33.23% done
# 33.30% done
# 33.38% done
# 33.45% done
# 33.52% done
# 33.60% done
# 33.67% done
# 33.75% done
# 33.82% done
# 33.90% done
# 33.97% done
# 34.05% done
# 34.12% done
# 34.20% done
# 34.27% done
# 34.34% done
# 34.42% done
# 34.49% done
# 34.57% done
# 34.64% done
# 34.72% done
# 34.79% done
# 34.87% done
# 34.94% done
# 35.01% done
# 35.09% done
# 35.16% done
# 35.24% done
# 35.31% done
# 35.39% done
# 35.46% done
# 35.54% done
# 35.61% done
# 35.69% done
# 35.76% done
# 35.83% done
# 35.91% done
# 35.98% done
# 36.06% done
# 36.13% done
# 36.21% done
# 36.28% done
# 36.36% done
# 36.43% done
# 36.50% done
# 36.58% done
# 36.65% done
# 36.73% done
# 36.80% done
# 36.88% done
# 36.95% done
# 37.03% done
# 37.10% done
# 37.17% done
# 37.25% done

# %%
statisticallySignificant = relcorrel.loc[
    (relcorrel["P-value"]<confidence)   # Statistically significant
]

failingActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

failingInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

otherTypesOfRelations = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    ~(relcorrel["Relation type"].str.contains("activation")) & # No activation  
    ~(relcorrel["Relation type"].str.contains("inhibition"))   # No inhibition 
]

print("P-value < {:.2f}: ".format(100 * confidence / 100), len(statisticallySignificant))
print("Failing activations (green):", len(failingActivation))
print("Failing inhibitions (blue):", len(failingInhibition))
print("Excessive activations (red):", len(excessiveActivation))
print("Excessive inhibitions (orange):", len(excessiveInhibition))
print("Other types of relations (yellow):", len(otherTypesOfRelations))
print("Total:", len(failingActivation)+len(failingInhibition)+len(excessiveActivation)+len(excessiveInhibition)+len(otherTypesOfRelations))

# %%
def elaborateArc(relation, sdrawing):
    source= str(node2columns[element2id[set2can(relation.source)]])
    for tg in relation.target:
        target = str(node2columns[element2id[set2can(tg)]])
        r = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
        if len(r) == 0:
            continue
        if len(r) > 1:
            pass
            #print(f"({source}, {target}) appearing more than once in relcorrel")
            #print(list(r.to_dict()["Correlation difference (H-D)"].values()))
        rd = r.to_dict()
        pvalue = list(rd["P-value"].values())[0]
        corrdiff = list(rd["Correlation difference (H-D)"].values())[0]
        relationType = list(rd["Relation type"].values())[0]
        if pvalue < confidence:        
            if "activation" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.green
                else:
                    col = reportlab.lib.colors.red
            elif "inhibition" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.orange
                else:
                    col = reportlab.lib.colors.blue
            else:
                col = reportlab.lib.colors.yellow
            sdrawing.setLineWidth(3*math.exp(abs(corrdiff)*3))
            sdrawing.setStrokeColor(col)
            sdrawing.line(relation.sourceg.x, relation.sourceg.y, relation.targetg.x, relation.targetg.y)

# %%
if produceGraphsWithAnomalies:
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)

        relations = []
        for relation in rel[pathwayID]:
            relations += [relation]

        canvas = KGMLCanvas(pathway)

        if useCCcoloringForAnomalies:
            for k in pathway.entries:
                name = pathway.entries[k].name
                canonicalName = set2can(words2set(name))
                if canonicalName in element2id.keys():
                    node = element2id[canonicalName]
                    klass = cc[node]
                    if klass in nontrivialclass2col:
                        pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                        pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                    else:
                        pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                        pathway.entries[k].graphics[0].fgcolor = "#FFFFFF"
                    s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"

        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway + "-anomalies")).mkdir(parents=True, exist_ok=True)
        canvas.new_draw(os.path.join(outputDirectory, organism, safeSuperpathway+ "-anomalies", pdfName), relations, elaborateArc)

# %%
pathwayAnomalies = pd.DataFrame(columns=[
        "Pathway ID",
        "Pathway",
        "Average square difference",
        ])
for pair in superpathwayDict[superpathway]:
    pathwayID = pair[0]
    pathwayName= pair[1]
    ssqd = 0
    count = 0
    for relation in rel[pathwayID]:
        source = str(node2columns[element2id[set2can(relation.source)]])
        for targ in relation.target:
            target = str(node2columns[element2id[set2can(targ)]])
            tt = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
            if len(tt) == 1 and tt["P-value"].to_list()[0] <= confidence:
                cd = tt["Correlation difference (H-D)"].to_list()[0]
                ssqd += cd * cd
            count += 1
    if count > 0:
        pathwayAnomalies.loc[len(pathwayAnomalies)]=[pathwayID, pathwayName, ssqd]

# %%
relPathwayAnomalies = os.path.join(inputDirectory, "pathway-anomalies-" + correlationFunctionName + ".csv")
pathwayAnomalies = pathwayAnomalies.sort_values(by=["Average square difference"], ascending=False)
pathwayAnomalies.to_csv(relPathwayAnomalies)

# %%
superpathwayDict

# %%
relcorrel
