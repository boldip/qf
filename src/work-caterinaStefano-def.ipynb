# %%
from hypergraphs import *
from kegg import *
import pandas as pd
import os
import logging

from Bio.KEGG.KGML.KGML_parser import read
import Bio.KEGG.KGML.KGML_pathway
from ast import literal_eval
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
import requests
from Levenshtein import ratio
import scipy.stats
import pathlib
from qf.cc import cardon_crochemore_colored, cardon_crochemore
import random

from reportlab.lib.units import inch
import PIL.Image
from io import BytesIO
import reportlab.pdfgen.canvas
import reportlab.lib.colors

# %%
organismDict = {"hsa": "Homo sapiens (human)"}
outputDirectory = "/Users/boldi/Desktop/pw/"
inputDirectory = "../../LaTeX/Data/KEGG-Pathways/Mar2024/"
dataDirectory = "../../LaTeX/Data/KEGG-Pathways"

# %%
pathwaylistFilename = "KEGG-pathways.txt"  # In inputDirectory, csv: ID, type, name
superpathway = "All"                  # Name of the superpathway
organism = "hsa"
confidence = 0.05

produceGraphsWithCCcoloring = False
produceGraphsWithAnomalies = True
useCCcoloringForAnomalies = False
produceAnomaliesForNonsignificantPairs = True

# %%
safeSuperpathway = makesafe(superpathway)

# %%
pws = pd.read_csv(os.path.join(inputDirectory, "KEGG-pathways.txt"), 
            names=["Pathway ID", "Pathway type", "Pathway name"], dtype="string", keep_default_na=False)

# %%
superpathwayDict = {
    superpathway: [(x,y) for x,y in zip(pws["Pathway ID"], pws["Pathway name"])]
}

# %%
def words2set(words):
    """
        Given a space-separated list of words, returns it as a set of words
    """
    return set(words.split())

# %%
from typing import NamedTuple

class Relation(NamedTuple):
    """
        Represents a relation. It is characterized by:
        - a type (e.g. "PPRel") 
        - a list of subtypes (e.g. [('activation', '-->'), ('indirect effect', '..>')])
        - a set of components (source)
        - a list of sets of components (target)
    """
    relType: str
    relSubtypes: list
    source: set
    target: list
    sourceg: Bio.KEGG.KGML.KGML_pathway.Graphics
    targetg: Bio.KEGG.KGML.KGML_pathway.Graphics
        
    @classmethod
    def fromKEGG(cls, relation, pathway):
        """
            Constructor: builds a Relation from a KEGG relation
        """
        if relation.entry2.name == "undefined":
            s = []
            for component in relation.entry2.components:
                s += [words2set(pathway.entries[component.id].name)]
            targetg = pathway.entries[component.id].graphics[0]
        else:
            s = [words2set(relation.entry2.name)]
            targetg = relation.entry2.graphics[0]
        return cls(relation.type, relation.subtypes, words2set(relation.entry1.name), s, targetg, relation.entry1.graphics[0])

# %%
def relationsFromKEGGpathway(pathway):
    """
        Given a KEGG pathway, returns the list of relations it contains (represented as Relation).
    """
    return [Relation.fromKEGG(r, pathway) for r in pathway.relations]

# %%
def pathwayFromFile(dataDirectory, organism, pathwayID):
    """
        Load and return a KEGG pathway, given the data directory, the organism specifying the subdirectory,
        and the pathwayID (the filename should be organism+pathwayID+"xml".
    """
    return KGML_parser.read(open(os.path.join(dataDirectory, organism, organism+pathwayID+".xml"), "r"))

# %%
def relationsFromFile(dataDirectory, organism, pathwayID):
    """
        Given a pathway file (specified by a root dataDirectory, the name of the organism subdirectory, and the name
        of the file [organism+pathwayID.xml]), reads it and returns the list of its relations.
    """
    pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
    return relationsFromKEGGpathway(pathway)

# %%
def relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway):
    """
        Given a superpathDict (whose keys are superpathway names and whose values are list of
        pairs (pathwayID, pathwayName)), reads all the pathway file for a specific superpathway name
        and returns a dictionary whose keys are the pathwayID's and whose values are the list of relations.
    """
    rel = {}
    for k,v in superpathwayDict[superpathway]:
        #logging.info("Reading", k, v)
        rel[k] = relationsFromFile(dataDirectory, organism, k)
    return rel

# %%
def subtypes(rel):
    """
        Given a map whose values are relations, accumulate all subtypes appearing and assign them a number.
        The result is a map from subtype string to number.
    """
    all_subtypes = set([])
    for pathwayid, relations in rel.items():
        for relation in relations:
            all_subtypes |= set([str(relation.relSubtypes)])
        
    s = sorted(list(all_subtypes))
    subtype2color = {v:k for k,v in enumerate(s)}
    color2subtype = {k:v for k,v in enumerate(s)}

    return subtype2color, color2subtype

# %%
def set2can(s):
    """
        Convert a set to a string in a canonical way.
    """
    return str(sorted(list(s)))

def can2set(c):
    """
        Does the converse of set2can.
    """
    return set(literal_eval(c))

# %%
def indices(rel):
    """
        Given a map whose values are lists of relations, it considers all the relations one by one, and attributes a unique id 
        to each element (i.e., set of components appearing as source or in the target of some relation) and block (the set of
        element id appearing as target of some relation).
        This function returns the dictionaries to move from/to an element or block to the corresponding id.
        Elements are string representations of sorted lists of strings.
        Blocks are string representations of sorted lists of ints.
    """
    element2id = {}
    id2element = {}
    block2id = {}
    id2block = {}

    for relations in rel.values():
        for relation in relations:
            s = set2can(relation.source)
            if s not in element2id.keys():
                element2id[s] = len(element2id)
            targetset = set([])
            for targ in relation.target:
                t = set2can(targ)
                if t not in element2id.keys():
                    element2id[t] = len(element2id)
                targetset |= set([element2id[t]])
            ts = set2can(targetset)
            if ts not in block2id.keys():
                block2id[ts] = len(block2id)

    for k,v in element2id.items():
        id2element[v] = k
    for k,v in block2id.items():
        id2block[v] = k
    return element2id, id2element, block2id, id2block

# %%
def search_gene_KEGG(geneID):
    """
        Search for gene on KEGG. 
        
        Returns list of names.
    """
    url1 = "https://www.kegg.jp/entry/"+geneID
    response1 = requests.get(url1, allow_redirects=False)    
    soup = BeautifulSoup(response1.text, "html.parser")
    tds = [tds for tds in soup.find_all("td", {"class": "td11 defd"})]
    names = tds[0].getText().strip().split(", ")
    return names

# %%
def get_temp_imagefilename(url):
    """Return filename of temporary file containing downloaded image.

    Create a new temporary file to hold the image file at the passed URL
    and return the filename.
    """
    img = urlopen(url).read()
    im = PIL.Image.open(BytesIO(img))
    # im.transpose(Image.FLIP_TOP_BOTTOM)
    f = tempfile.NamedTemporaryFile(delete=False, suffix=".png")
    fname = f.name
    f.close()
    im.save(fname, "PNG")
    return fname


#def enhance_method(klass, method_name, replacement):
#    'replace a method with an enhanced version'
#    method = getattr(klass, method_name)
#    def enhanced(*args, **kwds): return replacement(*args, **kwds)
#    setattr(klass, method_name, enhanced)

def new_draw(self, filename, relations, elaborateArc = None):
        """Add the map elements to the drawing."""
        # Instantiate the drawing, first
        # size x_max, y_max for now - we can add margins, later
        if self.import_imagemap:
            # We're drawing directly on the image, so we set the canvas to the
            # same size as the image
            if os.path.isfile(self.pathway.image):
                imfilename = self.pathway.image
            else:
                imfilename = get_temp_imagefilename(self.pathway.image)
            im = PIL.Image.open(imfilename)
            cwidth, cheight = im.size
        else:
            # No image, so we set the canvas size to accommodate visible
            # elements
            cwidth, cheight = (self.pathway.bounds[1][0], self.pathway.bounds[1][1])
        # Instantiate canvas
        self.drawing = reportlab.pdfgen.canvas.Canvas(
            filename,
            bottomup=0,
            pagesize=(
                cwidth * (1 + 2 * self.margins[0]),
                cheight * (1 + 2 * self.margins[1]),
            ),
        )
        self.drawing.setFont(self.fontname, self.fontsize)
        # Transform the canvas to add the margins
        self.drawing.translate(
            self.margins[0] * self.pathway.bounds[1][0],
            self.margins[1] * self.pathway.bounds[1][1],
        )
        # Add the map image, if required
        if self.import_imagemap:
            self.drawing.saveState()
            self.drawing.scale(1, -1)
            self.drawing.translate(0, -cheight)
            self.drawing.drawImage(imfilename, 0, 0)
            self.drawing.restoreState()
        # Add the reactions, compounds and maps
        # Maps go on first, to be overlaid by more information.
        # By default, they're slightly transparent.
        if self.show_maps:
            self.__add_maps()
        if self.show_reaction_entries:
            KGMLCanvas._KGMLCanvas__add_reaction_entries(self)
        if self.show_orthologs:
            KGMLCanvas._KGMLCanvas__add_orthologs(self)
        if self.show_compounds:
            KGMLCanvas._KGMLCanvas__add_compounds(self)
        if self.show_genes:
            KGMLCanvas._KGMLCanvas__add_genes(self)
        # TODO: complete draw_relations code
        # if self.draw_relations:
        #    self.__add_relations()
        # Write the pathway map to PDF
        if elaborateArc is not None:
            for relation in relations:
                elaborateArc(relation, self.drawing)
        self.drawing.save()
        
#enhance_method(KGMLCanvas, 'draw',  new_draw)
setattr(KGMLCanvas, 'new_draw', new_draw)

# %%
# Build all data needed for the relations of the superpathway
rel = relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway)
element2id, id2element, block2id, id2block = indices(rel)
subtype2color, color2subtype = subtypes(rel)
elements = list(set.union(*[can2set(k) for k in element2id.keys()]))

# %%
# name2gene is a function mapping names to gene IDs (hsa:xxxx)
# e.g. KCNE3, BRGDA6 etc are all mapped to hsa:10008 (see https://www.kegg.jp/entry/hsa:10008)
# This map was produced by scraping kegg, but this has been done only once.
# After that, we just read a pkl file

name2keggFilename = os.path.join(inputDirectory, "name2kegg.pkl")

if os.path.exists(name2keggFilename):
    print("Reading gene names")
    with open(name2keggFilename, "rb") as handle:
        name2gene = pickle.load(handle)
else:
    print("Producing gene names")
    d = {}
    nelements = len(elements)
    for count,element in enumerate(elements):
        if count % 10 == 0:
            print(f"{count}/{nelements}")
        if element.startswith("hsa"):
            names = search_gene_KEGG(element)
            for name in names:
                d[name] = element
    with open(name2keggFilename, "wb") as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
    name2gene = d
# Out:
# Reading gene names

# %%
# Read patient data
print("Reading patient data")
genes = pd.read_csv(os.path.join(inputDirectory, "genes.csv"), dtype={"name": str})
patients = genes["name"].values.tolist()
classification = pd.read_csv(os.path.join(inputDirectory, "classification.csv"), dtype={"name": str})

patient2class = {patient: classification.loc[classification["name"]==patient]["classification"].values.flatten().tolist()[0] for patient in patients}
numHealthy = sum([x == 'healthy' for x in patient2class.values()])
numDiseased = sum([x == 'diseased' for x in patient2class.values()])
# Out:
# Reading patient data

# %%
# Dividing genes into two frames (one for healthy individuals and one for diseased individuals)
genesHealthy = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="healthy"]
genesDiseased = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="diseased"]

# %%
# Building the graph of all relations contained in rel values
# Nodes are IDs, and node x correspond to the set of genes (and/or compound) id2element[x]
print("Building the relation graph")
G = nx.DiGraph() 
for pathwayID, relations in rel.items():
    for relation in relations:
        source = element2id[set2can(relation.source)]
        for targ in relation.target:
            target = element2id[set2can(targ)]
            newType = str(relation.relSubtypes)
            color = subtype2color[newType]
            pl = []
            if G.has_edge(source, target):
                d = G.get_edge_data(source, target)
                if d["color"] != color:
                    oldType = color2subtype[d["color"]]
                    print("- Edge ({},{}) of type {} for {} appears as {} for {}. ".format(
                        source, target, color2subtype[d["color"]], d["pathwayIDs"], 
                        str(relation.relSubtypes), pathwayID
                    ), end="")
                    if oldType[1:-1] in newType[1:-1]:
                        print("Overwriting with type {}".format(newType))
                    elif newType[1:-1] in oldType[1:-1]:
                        print("Overwriting with type {}".format(oldType))
                        color = subtype2color[oldType]
                    else:
                        print("\n****Conflict! Rewriting as {}".format(newType))
                pl = d["pathwayIDs"]
            G.add_edge(source, target, color=color, pathwayIDs=pl + [pathwayID])
            

# Computing the minimum fibres
cc=cardon_crochemore_colored(G)

colors = list(matplotlib.colors.CSS4_COLORS.values())
usedColors = 0

cc2fibresize = {}
cc2fibre = {}
ccnontrivial = {}
nontrivialclass2col = {}

fibres = []
node2fibre = {}
for v in set(cc.values()):
    fibre = [x for x in G.nodes() if cc[x] == v]
    fibres += [fibre]
    for x in fibre:
        node2fibre[x] = fibre
    cc2fibre[v] = fibre
    cc2fibresize[v] = len(fibre)
    if len(fibre) > 0:
        ccnontrivial[v] = cc[v]
        nontrivialclass2col[v] = colors[usedColors]
        usedColors = (usedColors + 1 ) % len(colors)
        if usedColors == 0:
            print("Wrap: more than", len(colors), "colors needed")
# Out:
# Building the relation graph
# - Edge (9,26) of type [('compound', 90)] for ['00010'] appears as [('compound', 91)] for 00010.
# ****Conflict! Rewriting as [('compound', 91)]
# - Edge (26,4) of type [('compound', 93)] for ['00010', '00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (4,1) of type [('compound', 94)] for ['00010'] appears as [('compound', 93)] for 00010.
# ****Conflict! Rewriting as [('compound', 93)]
# - Edge (4,6) of type [('compound', 94)] for ['00010', '00010'] appears as [('compound', 93)] for 00010.
# ****Conflict! Rewriting as [('compound', 93)]
# - Edge (4,1) of type [('compound', 93)] for ['00010', '00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (33,39) of type [('compound', 330)] for ['00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (39,46) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (39,48) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (46,48) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (33,37) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (33,39) of type [('compound', 325)] for ['00230', '00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (37,39) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (39,48) of type [('compound', 326)] for ['00230', '00230'] appears as [('compound', 366)] for 00230.
# ****Conflict! Rewriting as [('compound', 366)]
# - Edge (48,37) of type [('compound', 332)] for ['00230'] appears as [('compound', 355)] for 00230.
# ****Conflict! Rewriting as [('compound', 355)]
# - Edge (40,39) of type [('compound', 365)] for ['00230'] appears as [('compound', 357)] for 00230.
# ****Conflict! Rewriting as [('compound', 357)]
# - Edge (33,58) of type [('compound', 324)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (33,33) of type [('compound', 324)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (33,35) of type [('compound', 324)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (40,35) of type [('compound', 360)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (58,35) of type [('compound', 360)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge
240'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (35,58) of type [('compound', 214)] for ['00240', '00240'] appears as [('compound', 217)] for 00240.
# ****Conflict! Rewriting as [('compound', 217)]
# - Edge (39,93) of type [('compound', 195)] for ['00240', '00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (159,165) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04062. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (483,485) of type [('activation', '-->')] for ['04062'] appears as [('binding/association', '---')] for 04062.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (483,131) of type [('activation', '-->')] for ['04062'] appears as [('binding/association', '---')] for 04062.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (165,187) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->')] for 04066.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,144) of type [('compound', 151), ('activation', '-->')] for ['04062'] appears as [('activation', '-->')] for 04066. Overwriting with type [('compound', 151), ('activation', '-->')]
# - Edge (568,569) of type [('compound', 49)] for ['04070'] appears as [('compound', 48)] for 04070.
# ****Conflict! Rewriting as [('compound', 48)]
# - Edge (573,571) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (569,571) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (568,571) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (584,585) of type [('compound', 52)] for ['04070'] appears as [('compound', 235)] for 04070.
# ****Conflict! Rewriting as [('compound', 235)]
# - Edge (585,584) of type [('compound', 234)] for ['04070'] appears as [('compound', 68)] for 04070.
# ****Conflict! Rewriting as [('compound', 68)]
# - Edge (579,578) of type [('compound', 61)] for ['04070'] appears as [('compound', 56)] for 04070.
# ****Conflict! Rewriting as [('compound', 56)]
# - Edge (588,587) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (588,575) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (492,573) of type [('compound', 73)] for ['04070'] appears as [('compound', 66)] for 04070.
# ****Conflict! Rewriting as [('compound', 66)]
# - Edge (578,578) of type [('compound', 60)] for ['04070', '04070'] appears as [('compound', 231)] for 04070.
# ****Conflict! Rewriting as [('compound', 231)]
# - Edge (590,586) of type [('compound', 66)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (586,573) of type [('compound', 73)] for ['04070'] appears as [('compound', 66)] for 04070.
# ****Conflict! Rewriting as [('compound', 66)]
# - Edge (568,569) of type [('compound', 48)] for ['04070', '04070'] appears as [('compound', 72)] for 04070.
# ****Conflict! Rewriting as [('compound', 72)]
# - Edge (574,587) of type [('compound', 74)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (573,568) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (568,569) of type [('compound', 72)] for ['04070', '04070', '04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (577,579) of type [('compound', 61)] for ['04070'] appears as [('compound', 56)] for 04070.
# ****Conflict! Rewriting as [('compound', 56)]
# - Edge (581,577) of type [('compound', 62)] for ['04070'] appears as [('compound', 55)] for 04070.
# ****Conflict! Rewriting as [('compound', 55)]
# - Edge (573,587) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (572,581) of type [('compound', 55)] for ['04070'] appears as [('compound', 63)] for 04070.
# ****Conflict! Rewriting as [('compound', 63)]
# - Edge (587,569) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (570,594) of type [('compound', 66)] for ['04070'] appears as [('compound', 49)] for 04070.
# ****Conflict! Rewriting as [('compound', 49)]
# - Edge (129,613) of type [('expression', '-->')] for ['04115'] appears as [('activation', '-->')] for 04115.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (489,494) of type [] for ['04062'] appears as [('activation', '-->')] for 04151. Overwriting with type [('activation', '-->')]
# - Edge (144,140) of type [('phosphorylation', '+p'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (204,157) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04151.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (157,500) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->')] for 04151. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (528,165) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (533,553) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (553,554) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (120,121) of type [] for ['04010'] appears as [('activation', '-->')] for 04210. Overwriting with type [('activation', '-->')]
# - Edge (136,140) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04210. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (533,544) of type [('inhibition', '--|')] for ['04066'] appears as [('inhibition', '--|'), ('phosphorylation', '+p')] for 04218. Overwriting with type [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (573,494) of type [('inhibition', '--|'), ('dephosphorylation', '-p')] for ['04151'] appears as [('inhibition', '--|')] for 04218. Overwriting with type [('inhibition', '--|'), ('dephosphorylation', '-p')]
# - Edge (739,524) of type [('activation', '-->')] for ['04213'] appears as [('inhibition', '--|')] for 04218.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (129,224) of type [('expression', '-->')] for ['04115', '04115'] appears as [('activation', '-->')] for 04218.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (161,129) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04218. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (202,626) of type [('expression', '-->'), ('indirect effect', '..>')] for ['04218'] appears as [('expression', '-->')] for 04218. Overwriting with type [('expression', '-->'), ('indirect effect', '..>')]
# - Edge (792,780) of type [('activation', '-->')] for ['04310'] appears as [('inhibition', '--|')] for 04310.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (129,623) of type [('expression', '-->')] for ['04115', '04115'] appears as [('indirect effect', '..>')] for 04310.
# ****Conflict! Rewriting as [('indirect effect', '..>')]
# - Edge (141,758) of type [('activation', '-->'), ('dephosphorylation', '-p')] for ['04218'] appears as [('dephosphorylation', '-p')] for 04310. Overwriting with type [('activation', '-->'), ('dephosphorylation', '-p')]
# - Edge (499,114) of type [('activation', '-->')] for ['04310'] appears as [('phosphorylation', '+p'), ('indirect effect', '..>')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (492,144) of type [('compound', 151), ('activation', '-->')] for ['04062', '04066'] appears as [('compound', 24)] for 04510.
# ****Conflict! Rewriting as [('compound', 24)]
# - Edge (507,204) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04510.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (663,144) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04210'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (484,486) of type [('binding/association', '---')] for ['04062'] appears as [('phosphorylation', '+p')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p')]
# - Edge (114,706) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04210'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (159,165) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04010', '04062'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (165,563) of type [('expression', '-->'), ('indirect effect', '..>')] for ['04210'] appears as [('phosphorylation', '+p')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p')]
# - Edge (486,131) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04510.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (852,714) of type [('binding/association', '---')] for ['04510'] appears as [('activation', '-->')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,144) of type [('compound', 24)] for ['04062', '04066', '04510'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (165,184) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (716,482) of type [('dissociation', '-+-')] for ['04210'] appears as [('inhibition', '--|')] for 04620.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (142,117) of type [('activation', '-->')] for ['04010'] appears as [('binding/association', '---')] for 04620.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (528,165) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151', '04210', '04218'] appears as [('phosphorylation', '+p')] for 04620. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (770,161) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04218'] appears as [('phosphorylation', '+p')] for 04620. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (144,533) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (553,554) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151'] appears as [('activation', '-->')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (492,663) of type [('compound', 24)] for ['04510'] appears as [('compound', 71), ('activation', '-->')] for 04910.
# ****Conflict! Rewriting as [('compound', 71), ('activation', '-->')]
# - Edge (157,500) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062', '04151'] appears as [('activation', '-->')] for 04910. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (165,187) of type [('activation', '-->')] for ['04010', '04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (165,124) of type [('phosphorylation', '+p')] for ['04010', '04510'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (187,545) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (736,742) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (736,649) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (649,492) of type [('activation', '-->')] for ['04151', '04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (961,716) of type [('phosphorylation', '+p')] for ['04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (716,482) of type [('inhibition', '--|')] for ['04210', '04620'] appears as [('dissociation', '-+-')] for 04931.
# ****Conflict! Rewriting as [('dissociation', '-+-')]
# - Edge (649,492) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04213', '04931'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (649,492) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04213', '04931', '04931'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (492,503) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1012,649) of type [('inhibition', '--|')] for ['04931'] appears as [('inhibition', '--|'), ('indirect effect', '..>')] for 04931. Overwriting with type [('inhibition', '--|'), ('indirect effect', '..>')]
# - Edge (547,548) of type [('activation', '-->')] for ['04611', '04931'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04931. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (800,148) of type [('compound', 12)] for ['04310'] appears as [('compound', 277), ('activation', '-->')] for 05146.
# ****Conflict! Rewriting as [('compound', 277), ('activation', '-->')]
# - Edge (513,859) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['04510'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (492,144) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062', '04066', '04510', '04611', '04620'] appears as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (893,897) of type [('compound', 131)] for ['04512'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (639,728) of type [('activation', '-->')] for ['04213'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (165,124) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04010', '04510', '04910'] appears as [('phosphorylation', '+p')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (728,492) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (144,533) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (553,554) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151', '04910'] appears as [('activation', '-->')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (553,670) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151'] appears as [('activation', '-->')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (492,663) of type [('compound', 71), ('activation', '-->')] for ['04510', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (663,553) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (512,513) of type [('activation', '-->')] for ['04062', '04510', '04611'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (1129,165) of type [('activation', '-->'), ('indirect effect', '..>')] for ['05205'] appears as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (561,1123) of type [('inhibition', '--|')] for ['05205'] appears as [('activation', '-->')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (539,482) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04066'] appears as [('activation', '-->')] for 05321. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (649,492) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04213', '04931', '04931', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (144,659) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['04151', '04510', '04910', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (547,548) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04611', '04931', '04931'] appears as [('activation', '-->')] for 05415. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (492,494) of type [('activation', '-->')] for ['04151', '04210', '04213', '04213', '04218', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (145,142) of type [('binding/association', '---')] for ['04010'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (144,659) of type [('missing interaction', '-/-')] for ['04151', '04510', '04910', '04931', '05415'] appears as [('inhibition', '--|'), ('phosphorylation', '+p')] for 05417.
# ****Conflict! Rewriting as [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (509,764) of type [('activation', '-->')] for ['04218', '04970'] appears as [('binding/association', '---')] for 05417.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (482,547) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04931'] appears as [('repression', '--|')] for 05417.
# ****Conflict! Rewriting as [('repression', '--|')]
# - Edge (482,402) of type [('expression', '-->')] for ['04620'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (699,700) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04210'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (482,1209) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,1210) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,1212) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,390) of type [('expression', '-->')] for ['04620', '05417', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (482,1213) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,300) of type [('expression', '-->')] for ['04620', '04931', '04931', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1136,512) of type [('binding/association', '---')] for ['05205'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (482,271) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,183) of type [('expression', '-->')] for ['04620', '04931', '04931', '05321', '05417'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (482,402) of type [('activation', '-->')] for ['04620', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,1215) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (492,494) of type [('missing interaction', '-/-')] for ['04151', '04210', '04213', '04213', '04218', '04931', '05415'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (482,191) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,390) of type [('activation', '-->')] for ['04620', '05417', '05417', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (482,300) of type [('activation', '-->')] for ['04620', '04931', '04931', '05417', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (663,144) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04210', '04510', '04910', '04931'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (482,183) of type [('activation', '-->')] for ['04620', '04931', '04931', '05321', '05417', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (114,115) of type [('phosphorylation', '+p')] for ['04010', '04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (468,595) of type [('indirect effect', '..>')] for ['04115'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (963,114) of type [('phosphorylation', '+p')] for ['04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (117,140) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed

# %%
# Build node2columns, mapping each node of G to the list of genes corresponding to it
# for which we know a value (in the genes dataframe), sorted
#

print("Mapping genes to columns")
namedGenes = set(name2gene.values())     
columns = set(genes.columns.values.tolist()[2:])
node2columns = {}
for node in G.nodes():
    nodeGenes = can2set(id2element[node])
    s = []
    for gene in nodeGenes & namedGenes:
        for k,v in name2gene.items():
            if v == gene:
                if k in columns:
                    s += [k]
    node2columns[node]=sorted(s)
# Out:
# Mapping genes to columns

# %%
if produceGraphsWithCCcoloring:
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
        canvas = KGMLCanvas(pathway)
        for k in pathway.entries:
            name = pathway.entries[k].name
            canonicalName = set2can(words2set(name))
            if canonicalName in element2id.keys():
                node = element2id[canonicalName]
                klass = cc[node]
                if klass in nontrivialclass2col:
                    pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                    pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                else:
                    pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                    pathway.enries[k].graphics[0].fgcolor = "#FFFFFF"
                s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"
        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway)).mkdir(parents=True, exist_ok=True)
        canvas.draw(os.path.join(outputDirectory, organism, safeSuperpathway, pdfName))
    with open(os.path.join(outputDirectory, organism, safeSuperpathway, "all.tsv"), "wt") as file:
        file.write(s)

# %%
def columns2nodes(columns, node2columns, ignoreEmpty = True):
    """
        Returns a map from columns to the nodes where the column appears.
    """
    res = {} 
    for c in columns:
        s = set([])
        for no, co in node2columns.items():
            if c in co:
                s |= set([no])
        if len(s) > 0 or not ignoreEmpty:
            res[c] = s
    return res

c2n = columns2nodes(columns, node2columns)
usableColumns = list(c2n.keys())

# %%
def corrForPair(genes, set1, set2, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Given a dataframe genes (i.e., a set of patients), and two sets of column names (set1, set2), 
        compute the correlation function
        for every pair of columns in set1 and set2 and return the average statistic and its std.
    """
    taus = []
    for gene1 in set1:
        for gene2 in set2:
            expr1 = genes.loc[:,gene1].values.tolist()
            expr2 = genes.loc[:,gene2].values.tolist()
            if len(set(expr1)) == 1 or len(set(expr2)) == 1:
                continue
            taus += [correlationFunction(expr1, expr2).statistic]
    if len(taus) < 2:
        return np.nan, np.nan
    return pd.DataFrame(taus).mean().values[0], pd.DataFrame(taus).std().values[0]

# %%
def sampleDeltaDist(genes, set1, set2, numberOfRows1, numberOfSamples = 500, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Repeatedly (for numberOfSamples times) do the following:
        - select numberOfRows1 rows of genes, and then compute tauForPair on those rows for set1 and set2
        - do the same for remaining rows
        - take the difference between the two resulting set of taus.
        Return the mean and std of differences.
    """
    diffs = []
    
    for i in range(numberOfSamples):
        genes1 = random.sample(range(len(genes)), numberOfRows1)
        genes2 = list(set(range(len(genes)))-set(genes1))
        mt1, mstd1 = corrForPair(genes.iloc[genes1], set1, set2, correlationFunction)
        if np.isnan(mp1):
            continue
        mt2, mstd2 = corrForPair(genes.iloc[genes2], set1, set2, correlationFunction)
        if np.isnan(mp2):
            continue
        diffs += [mt1-mt2]
    return diffs


def deltaForPair(genes1, genes2, set1, set2, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Compute corrForPair for set1 and set2 over the set of rows genes1 and genes2, and return
        the difference of taus.
    """
    mt1, mstd1 = corrForPair(genes1, set1, set2, correlationFunction)
    mt2, mstd2 = corrForPair(genes2, set1, set2, correlationFunction)
    return mt1-mt2

# %%
correlationFunction = lambda x,y:  scipy.stats.spearmanr(x,y).statistic
correlationFunctionName = "spearmanrho"
relAnomalies = os.path.join(inputDirectory, "anomalies-" + correlationFunctionName + ".csv")

if os.path.exists(relAnomalies):
    print("Reading anomalies")
    relcorrel = pd.read_csv(relAnomalies)
else:
    print("Producing anomalies")
    relcorrel = pd.DataFrame(columns=[
        "Source gene(s)",
        "Target gene(s)",
        "Pathway ID",
        "Relation type",
        "Correlation for healthy",
        "Correlation for diseased",
        "Correlation difference (H-D)",
        "Expected correlation difference",
        "P-value",
        "Comment"
        ])
    numberOfEdges = G.number_of_edges()
    doneEdges = 0
    for s,t,d in G.edges(data=True):
        if doneEdges % 10 == 0:
            print("{:.2f}% done".format(100 * doneEdges / numberOfEdges))
        doneEdges += 1
        subtypeName = [k for k,v in subtype2color.items() if d["color"]==v][0]
        sg = node2columns[s]
        tg = node2columns[t]
        if len(sg) == 0 or len(tg) == 0:
            continue
        avgh, stdh = corrForPair(genesHealthy, sg, tg, correlationFunction=correlationFunction)
        avgd, stdd = corrForPair(genesDiseased, sg, tg, correlationFunction=correlationFunction)
        taudiff = avgh - avgd
        ttn = sampleDeltaDist(genes, sg, tg, numHealthy, correlationFunction=correlationFunction)
        tt = [x for x in ttn if ~np.isnan(x)]
        if len(tt) == 0:
            continue
        ttmean = pd.DataFrame(tt).mean().values[0]
        ecdft = scipy.stats.ecdf(tt)  # Empirical CDF
        if taudiff < 0:
            pvalue = ecdft.cdf.evaluate(taudiff)
            comment = "More correlated than for healthy individuals"
        else:
            pvalue = 1 - ecdft.cdf.evaluate(taudiff)    
            comment = "Less correlated than for healthy individuals"
        if produceAnomaliesForNonsignificantPairs or produpvalue <= confidence:
            relcorrel.loc[len(relcorrel)] = [
                str(sg),
                str(tg),
                d["pathwayIDs"],
                subtypeName,
                avgh, 
                avgd,
                taudiff,
                ttmean,
                pvalue,
                comment
            ]
    relcorrel = relcorrel.sort_values(by=["P-value"], ascending=True)
    relcorrel.to_csv(relAnomalies)
# Out:
# Producing anomalies
# 0.00% done
# 0.39% done
# KeyboardInterrupt

# %%
print("Anomalies by type")
statisticallySignificant = relcorrel.loc[
    (relcorrel["P-value"]<confidence)   # Statistically significant
]

failingActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

failingInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

otherTypesOfRelations = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    ~(relcorrel["Relation type"].str.contains("activation")) & # No activation  
    ~(relcorrel["Relation type"].str.contains("inhibition"))   # No inhibition 
]

print("P-value < {:.2f}: ".format(100 * confidence / 100), len(statisticallySignificant))
print("Failing activations (green):", len(failingActivation))
print("Failing inhibitions (blue):", len(failingInhibition))
print("Excessive activations (red):", len(excessiveActivation))
print("Excessive inhibitions (orange):", len(excessiveInhibition))
print("Other types of relations (yellow):", len(otherTypesOfRelations))
print("Total:", len(failingActivation)+len(failingInhibition)+len(excessiveActivation)+len(excessiveInhibition)+len(otherTypesOfRelations))

# %%
# Out:
# [-0.1605292450249678,
#  0.14975082186964828,
#  0.09727994462633172,
#  0.3240312421286076,
#  -0.23044038108235876,
#  0.03338489304447943,
#  -0.39402541652159706,
#  -0.3803968261327082,
#  0.17535109153211897,
#  -0.21385777820094493,
#  0.17246375480913334,
#  -0.20765279980064555,
#  0.1728306382170895,
#  -0.39349967894042276,
#  -0.06217319945594946,
#  0.17466758767501955,
#  -0.0417330913850789,
#  0.15049138327449013,
#  0.1665258681779001,
#  0.11953482074568816,
#  -0.0903156133346941,
#  0.25039908477145645,
#  0.3089560699986381,
#  -0.2502289246118846,
#  -0.3588843569873766,
#  -0.13212019277210216,
#  -0.17154204335931805,
#  -0.3222983194616919,
#  -0.10614653891251623,
#  0.11945020713924845,
#  -0.18653689268923299,
#  0.2893566110885536,
#  0.18039519493853723,
#  0.2452029888164201,
#  0.2203007924728525,
#  -0.22830511991482544,
#  0.2749774376060589,
#  0.10755516413213503,
#  0.11096337230000869,
#  -0.14230572022148047,
#  0.18420458516531654,
#  -0.42655951750321275,
#  -0.11763015745769988,
#  -0.46131396717082096,
#  0.04989822006626043,
#  -0.3696995507106915,
#  -0.005461241283324271,
#  0.08046576385780255,
#  0.41694800436546664,
#  -0.15812799492176818,
#  -0.2437899926848096]

# %%
def elaborateArc(relation, sdrawing):
    source= str(node2columns[element2id[set2can(relation.source)]])
    for tg in relation.target:
        target = str(node2columns[element2id[set2can(tg)]])
        r = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
        if len(r) == 0:
            continue
        if len(r) > 1:
            pass
            #print(f"({source}, {target}) appearing more than once in relcorrel")
            #print(list(r.to_dict()["Correlation difference (H-D)"].values()))
        rd = r.to_dict()
        pvalue = list(rd["P-value"].values())[0]
        corrdiff = list(rd["Correlation difference (H-D)"].values())[0]
        relationType = list(rd["Relation type"].values())[0]
        if pvalue < confidence:        
            if "activation" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.green
                else:
                    col = reportlab.lib.colors.red
            elif "inhibition" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.orange
                else:
                    col = reportlab.lib.colors.blue
            else:
                col = reportlab.lib.colors.yellow
            if np.isnan(corrdif):
                print(f"Correlation for {source} vs. {target} is {corrdiff}")
            else:
                sdrawing.setLineWidth(3*math.exp(abs(corrdiff)*3))
                sdrawing.setStrokeColor(col)
                sdrawing.line(relation.sourceg.x, relation.sourceg.y, relation.targetg.x, relation.targetg.y)

# %%
if produceGraphsWithAnomalies:
    print("Producing anomaly PDFs")
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)

        relations = []
        for relation in rel[pathwayID]:
            relations += [relation]

        canvas = KGMLCanvas(pathway)

        if useCCcoloringForAnomalies:
            for k in pathway.entries:
                name = pathway.entries[k].name
                canonicalName = set2can(words2set(name))
                if canonicalName in element2id.keys():
                    node = element2id[canonicalName]
                    klass = cc[node]
                    if klass in nontrivialclass2col:
                        pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                        pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                    else:
                        pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                        pathway.entries[k].graphics[0].fgcolor = "#FFFFFF"
                    s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"

        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway + "-anomalies")).mkdir(parents=True, exist_ok=True)
        canvas.new_draw(os.path.join(outputDirectory, organism, safeSuperpathway+ "-anomalies", pdfName), relations, elaborateArc)

# %%
print("Computing anomalies by pathway")
pathwayAnomalies = pd.DataFrame(columns=[
        "Pathway ID",
        "Pathway",
        "Average square difference",
        "Count",
        "Relative count"
        ])
for pair in superpathwayDict[superpathway]:
    pathwayID = pair[0]
    pathwayName= pair[1]
    ssqd = 0
    count = 0
    countSig = 0
    for relation in rel[pathwayID]:
        source = str(node2columns[element2id[set2can(relation.source)]])
        for targ in relation.target:
            target = str(node2columns[element2id[set2can(targ)]])
            tt = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
            if len(tt) == 1 and tt["P-value"].to_list()[0] <= confidence:
                cd = tt["Correlation difference (H-D)"].to_list()[0]
                ssqd += cd * cd
                countSig += 1
            count += 1
    if count > 0:
        pathwayAnomalies.loc[len(pathwayAnomalies)]=[pathwayID, pathwayName, ssqd, countSig, countSig / count]

# %%
print("Sorting pathways by number of anomalies and writing it out as a csv")
relPathwayAnomalies = os.path.join(inputDirectory, "pathway-anomalies-" + correlationFunctionName + ".csv")
pathwayAnomalies = pathwayAnomalies.sort_values(by=["Count"], ascending=False)
pathwayAnomalies.to_csv(relPathwayAnomalies)

# %%
print("Extracting genes involved in top-k anomalous pathways and appearing as columns")
nTopAnomPathway = 7
topAnomPathway = pathwayAnomalies.head(nTopAnomPathway)["Pathway ID"].to_list()
anomPathwayGenes = set([])
for pathwayId in topAnomPathway:
    for relation in rel[pathwayId]:
        anomPathwayGenes |= relation.source 
        for t in relation.target:
            anomPathwayGenes |= t
anomPathwayGeneNames = [name for name,gene in name2gene.items() if gene in anomPathwayGenes and name in columns]
print(len(anomPathwayGeneNames), "genes involved")

# %%
print("Computing correlations for anomalous-pathway genes in the two populations")
healthyMatrix = genesHealthy[anomPathwayGeneNames].to_numpy() #Rows are healthy patients, columns are genes appearing in anomalous pathways
diseasedMatrix = genesDiseased[anomPathwayGeneNames].to_numpy() #Rows are diseased patients, columns are genes appearing in anomalous pathways

healthyCorr = np.corrcoef(healthyMatrix, rowvar=False) #Correlation between anomalous genes in healthy individuals
diseasedCorr = np.corrcoef(diseasedMatrix, rowvar=False) #Correlation between anomalous genes in diseased individuals

# %%
import sklearn.cluster
bh = sklearn.cluster.k_means(np.square(healthyCorr), n_clusters=9)[1]
bd = sklearn.cluster.k_means(np.square(diseasedCorr), n_clusters=9)[1]

# %%
import sklearn.cluster
import operator

gene2fr = defaultdict(lambda: 0)

for k in range(10, 11):
    bh = sklearn.cluster.k_means(np.square(healthyCorr), n_clusters=k)[1]
    bd = sklearn.cluster.k_means(np.square(diseasedCorr), n_clusters=k)[1]

    t = 0
    tc = 0
    for i1,g1 in enumerate(anomPathwayGeneNames):
        for i2,g2 in enumerate(anomPathwayGeneNames):
            if i1<i2:
                if (bh[i1]==bh[i2]) != (bd[i1]==bd[i2]):
                    t += 1
                    #print(t, g1, g2)
                    gene2fr[g1] += 1
                    gene2fr[g2] += 1
                else:
                    tc += 1
sorted_dict = dict(sorted(gene2fr.items(), key=operator.itemgetter(1)))
print(sorted_dict.values())
# Out:
# dict_values([28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 59, 59, 59, 60, 60, 60, 60, 60, 60, 60, 60, 60, 61, 61, 61, 61, 61, 61, 61, 61, 61, 62, 62, 62, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 65, 65, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 67, 70, 70, 70, 70, 70, 70, 71, 71, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 78, 78, 78, 78, 78, 78, 78, 78, 79, 79, 79, 80, 80, 80, 80, 82, 82, 82, 82, 82, 90, 90, 90, 93, 94, 97, 99, 100, 100, 100, 101, 101, 101, 101, 101, 101, 101, 101, 101, 102, 102, 102, 103, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 112, 112, 112, 112, 113, 113, 113, 113, 113, 113, 113, 113, 113, 113, 113, 113, 114, 117, 117, 117, 117, 117, 117, 117, 117, 117, 117, 117, 117, 117, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 121, 121, 122, 122, 122, 122, 122, 122, 122, 122, 122, 122, 122, 125, 125, 126, 126, 126, 126, 126, 126, 126, 126, 126, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 130, 130, 130, 130, 130, 130, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 142, 142, 142, 142, 142, 142, 142, 145, 151, 151, 151, 151, 154, 154, 154, 154, 154, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 156, 157, 157, 161, 161, 161, 161, 161, 177, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 251, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 301, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 331, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 334, 335, 335, 336, 336, 336, 336, 336, 336, 336, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 344, 353, 353, 353, 353, 353, 353, 365, 365, 365, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 371, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 384, 384,  ...

# %%
dbhcs, dbhlabels = dbscan(np.square(healthyCorr), metric="precomputed", eps=0.8)
len(set(dbhlabels))
# Out:
# 1

# %%
genesHealthy[names].to_numpy()
# Out:
# array([[6.067391 , 8.8757504, 5.6641085, ..., 6.707134 , 5.450995 ,
#         5.850196 ],
#        [5.795969 , 9.0911432, 5.3878315, ..., 7.09882  , 5.382501 ,
#         5.92895  ],
#        [5.91032  , 8.6722996, 5.9592795, ..., 6.446724 , 5.665595 ,
#         6.42348  ],
#        ...,
#        [5.95303  , 8.1330288, 5.5837515, ..., 6.263437 , 5.730636 ,
#         6.453225 ],
#        [5.912833 , 8.9221486, 5.6921765, ..., 6.278591 , 5.583134 ,
#         6.19882  ],
#        [6.087491 , 8.7737798, 5.7816135, ..., 5.899442 , 5.98729  ,
#         6.231638 ]])

# %%
columns
# Out:
# {'MAP3K19',
#  'CCDC115',
#  '649030',
#  'POP7',
#  'POLD3',
#  'SNTN',
#  'MICAL1',
#  'MATN3',
#  '646804',
#  'PIGL',
#  '729046',
#  '400752',
#  'KCNG1',
#  'KLC2',
#  'NUDT16L1',
#  'METTL21C',
#  '100128260',
#  '440928',
#  '730060',
#  '653242',
#  'PRKAR2A',
#  'TACC3',
#  'ZNF98',
#  '389033',
#  'ZNF699',
#  'ABHD3',
#  'TMEM231',
#  '646769',
#  '389286',
#  '100128098',
#  'RDH11',
#  'RAB3B',
#  'PIEZO1',
#  'SCX',
#  'MYSM1',
#  'PARP12',
#  'ZUFSP',
#  'NAALADL1',
#  '653111',
#  'SIRT1',
#  'HACD1',
#  'CSMD1',
#  'TANC2',
#  'PCM1',
#  'TARDBP',
#  'GEMIN8',
#  'SELE',
#  'MYF6',
#  'DCN',
#  'NOS1AP',
#  '644105',
#  '652483',
#  'MRE11A',
#  '730358',
#  'DYDC2',
#  'TMEM161B',
#  'PEG10',
#  'SP140',
#  'ACTN1',
#  'AGAP3',
#  'VCX2',
#  'POLH',
#  'SIN3B',
#  '284185',
#  '645635',
#  '100131726',
#  'EPAS1',
#  'SYT9',
#  '653080',
#  'PADI1',
#  'AMBN',
#  '727759',
#  'POPDC2',
#  '647009',
#  '650114',
#  'PARP14',
#  'SPX',
#  '647389',
#  'ENPEP',
#  'TMEM190',
#  'STEAP1',
#  'NPR1',
#  'PPP2R3A',
#  '594838',
#  'MED27',
#  'PPIE',
#  '100129396',
#  'ACTR2',
#  '8123',
#  '645968',
#  'ADH1A',
#  'WIZ',
#  '653401',
#  'RFXAP',
#  '728476',
#  'ATF5',
#  'KIAA0895',
#  'ZNF79',
#  'FAM83F',
#  'CAV2',
#  '100129063',
#  'CCT8',
#  'CLN3',
#  'COX11',
#  'ZFP64',
#  '11213',
#  'TMEM55A',
#  'TFAP2E',
#  'HMGCLL1',
#  'C1orf106',
#  'POLR2J2',
#  '100131960',
#  'AADACL4',
#  'BTC',
#  'NR1D1',
#  '652966',
#  'CENPBD1',
#  'CDCA4',
#  'TMEM140',
#  '441737',
#  'PDHB',
#  'SLC25A48',
#  'CNTNAP1',
#  'ZP3',
#  'MORF4L2',
#  'MIER1',
#  '100129667',
#  'CTSK',
#  'TMEM74',
#  'UMOD',
#  'FASTKD3',
#  '440313',
#  'MMGT1',
#  'ZNF250',
#  'RPL28',
#  '1268',
#  'PKHD1L1',
#  '651361',
#  'HLA-DRB1',
#  'PIK3C3',
#  'TMOD1',
#  'ZNF333',
#  'FOXG1',
#  'KIRREL',
#  '80307',
#  'RCAN2',
#  'CXorf57',
#  '6085',
#  'SOX15',
#  'CEP83',
#  '727935',
#  'CLTA',
#  'COMMD7',
#  '441120',
#  'OCM2',
#  '645722',
#  '646942',
#  'PRKRA',
#  'VHL',
#  '442366',
#  'NOD2',
#  '56664',
#  '729433',
#  '647995',
#  'NKX2-8',
#  '441763',
#  'KLKB1',
#  'RNPEPL1',
#  'C6orf136',
#  'DCAF13',
#  'METTL1',
#  'KIFAP3',
#  'WIPF2',
#  '652456',
#  '654056',
#  'CDK8',
#  'FAM209A',
#  '728790',
#  '100130079',
#  '440704',
#  'PPM1D',
#  'PLSCR3',
#  'TTR',
#  'TFIP11',
#  'LSR',
#  '648659',
#  '100129002',
#  '643152',
#  '644000',
#  'CA2',
#  'SPP1',
#  'HP',
#  '728014',
#  'PEX11B',
#  '114796',
#  'GTF3C5',
#  'GLB1L',
#  'PPFIBP1',
#  'ZWILCH',
#  '400389',
#  '388153',
#  '653113',
#  'ST8SIA3',
#  'GNA14',
#  'PANX2',
#  'PTPN1',
#  'OR1J2',
#  '644640',
#  '100127922',
#  'HLA-DRA',
#  'DYNC2LI1',
#  'TEX2',
#  'CCDC58',
#  'MDP1',
#  'CCHCR1',
#  '644280',
#  'STRN',
#  'RIC3',
#  'IL12RB2',
#  '442442',
#  '646057',
#  '643797',
#  'SLC9A3R1',
#  'NT5M',
#  '100134868',
#  'MTRF1',
#  'PITX2',
#  'SPACA9',
#  '285444',
#  'SMARCA1',
#  '642443',
#  'IFNG',
#  'AOX1',
#  '574480',
#  'SPOPL',
#  'EDEM1',
#  '54577',
#  'A4GNT',
#  '100132763',
#  '650339',
#  'GRXCR2',
#  'OAZ2',
#  '692057',
#  'ZNF124',
#  '728693',
#  'SIGLEC14',
#  'PDE4B',
#  '641959',
#  'FAM102A',
#  '642655',
#  'F10',
#  'POLR3H',
#  'HECTD3',
#  'PHLDA1',
#  '388759',
#  'ABCC8',
#  '100128304',
#  'GALNT15',
#  'ABCF1',
#  'COG3',
#  'GPHB5',
#  'MRPL11',
#  'KLHL34',
#  'PCDH1',
#  '10778',
#  '728368',
#  'ZNF160',
#  'OR51T1',
#  'THY1',
#  'JUNB',
#  '653994',
#  'MAN2C1',
#  'IFI44L',
#  'CTAGE5',
#  'RAB11FIP4',
#  'RAD17',
#  'NAT10',
#  'PRNP',
#  'AGPAT1',
#  'TMEM131',
#  'FTH1',
#  'RTN4RL2',
#  'TMPRSS13',
#  'KCTD6',
#  'UTP14C',
#  '389599',
#  'ZNF385D',
#  'SOCS2',
#  '2681',
#  'KIAA0930',
#  'PLCH1',
#  'TLCD2',
#  'ATAD2',
#  '26783',
#  'TMEM19',
#  'BCAS2',
#  'MIF4GD',
#  '646515',
#  'FBXO32',
#  'TCF15',
#  'OPRD1',
#  'CHST12',
#  'SEC23A',
#  'INO80B',
#  '646774',
#  'TMCO3',
#  'FBN2',
#  'SDC1',
#  'ATRNL1',
#  '647210',
#  'KCNH4',
#  '643313',
#  'TUBA8',
#  'RPSA',
#  'VAPA',
#  'F5',
#  'JUN',
#  'UBE2E2',
#  'ZNF207',
#  'NAPRT',
#  'TP53INP2',
#  '641844',
#  'PLXNB1',
#  '100129878',
#  'DOCK8',
#  'SPTLC3',
#  '400145',
#  '100192420',
#  'CD70',
#  'RGL4',
#  '649752',
#  'CHORDC1',
#  '100129566',
#  'WNT10B',
#  '677807',
#  'FAM192A',
#  '283970',
#  'NRIP1',
#  '728831',
#  'FBP2',
#  'RSRP1',
#  'MSS51',
#  'CPXCR1',
#  '649702',
#  'B2M',
#  'ZNF317',
#  '648342',
#  'EGFR',
#  'PDE9A',
#  '729269',
#  'GPR42',
#  'TMEM233',
#  '648130',
#  'KCTD7',
#  '399959',
#  'HOXA13',
#  'AMMECR1L',
#  '645460',
#  '644224',
#  '440482',
#  'NLE1',
#  'TBC1D22A',
#  'RPS18',
#  '652743',
#  '652226',
#  'C10orf11',
#  'C1orf50',
#  'KEAP1',
#  '647797',
#  'ABCD1',
#  'TMEM67',
#  'C9orf66',
#  'IGFN1',
#  'PRRG1',
#  'ACYP1',
#  'CHMP4A',
#  'TYRP1',
#  'USP1',
#  'RPL32',
#  'CCL28',
#  'CTSV',
#  'TSSC4',
#  '100132119',
#  'CNGA3',
#  'PZP',
#  'MAP2K5',
#  'PDE3B',
#  'KCNK18',
#  'CTNNB1',
#  'SOD1',
#  'CADPS',
#  'MYOF',
#  'NGLY1',
#  '651524',
#  'IMPACT',
#  'TMEM45A',
#  '652479',
#  'RALGPS1',
#  'HCN3',
#  '727773',
#  'MRPL16',
#  'KYAT1',
#  'ITGA7',
#  'HNMT',
#  'POLRMT',
#  '339760',
#  '79804',
#  'MZT2A',
#  'INO80E',
#  '728673',
#  '730077',
#  'NFRKB',
#  'HERC4',
#  'SAMD9',
#  'ZNF442',
#  'UBR5',
#  '652624',
#  'GDF15',
#  'PALMD',
#  '79970',
#  '730357',
#  '100128016',
#  '100131138',
#  'USH2A',
#  'EMC9',
#  'ANKRD27',
#  'PRICKLE2',
#  'AZIN2',
#  'SHISA3',
#  'PTPN11',
#  'FAM217B',
#  'TTL',
#  'GMCL1',
#  'CIAO1',
#  'NKAP',
#  'TRAPPC13',
#  'SCN4A',
#  '100129977',
#  '100132973',
#  'RPS20',
#  'GGA3',
#  'MED17',
#  '100132485',
#  '646372',
#  'MAEA',
#  'MRPL12',
#  'ZDHHC11',
#  'SLC38A6',
#  'MED4',
#  'CDC26',
#  'GALT',
#  'SSX3',
#  'DNAJB1',
#  'ANKRD13D',
#  'HNRNPU',
#  'HIC1',
#  'RBL2',
#  '388654',
#  '2576',
#  'RHOU',
#  '401375',
#  'CEBPA',
#  'AKAP9',
#  'ADNP2',
#  'ICOS',
#  'RHOT1',
#  '285941',
#  '152667',
#  '650517',
#  'FNBP4',
#  'POR',
#  'TMEM138',
#  '729954',
#  'PIP4K2C',
#  'HSFX2',
#  'AKR1B1',
#  'LYL1',
#  '647585',
#  '100133854',
#  'LPAR3',
#  'MYC',
#  '645146',
#  '85009',
#  'BMS1',
#  '388182',
#  'DENND1A',
#  '649813',
#  'TMEM39B',
#  'CYP4F3',
#  'ASB15',
#  'PLEKHG3',
#  '729960',
#  '642456',
#  'MNDA',
#  'C1orf158',
#  'TAGLN',
#  '729208',
#  '100129484',
#  'PRELID3A',
#  '100132319',
#  'FLOT1',
#  'OR5F1',
#  '400214',
#  '400955',
#  '574442',
#  'DPAGT1',
#  'PID1',
#  'VPS53',
#  'KDM4B',
#  'DNAJC4',
#  'FGFR1OP',
#  'KIF26B',
#  '441520',
#  '1292',
#  'F13A1',
#  'DPP7',
#  '80154',
#  'VTA1',
#  'NAV2',
#  '441007',
#  '645730',
#  '642097',
#  'FAM47C',
#  '645662',
#  'ST6GALNAC3',
#  'ENKUR',
#  'SP9',
#  '730183',
#  'GRPEL1',
#  'CPA5',
#  'SMAD6',
#  'CGRRF1',
#  'JAKMIP1',
#  'CD3D',
#  'PRKCD',
#  'MPZL1',
#  '100132499',
#  '401011',
#  'ARRDC5',
#  '100131335',
#  'YIPF3',
#  'MAPK8IP3',
#  '649422',
#  '401002',
#  'MBLAC2',
#  'YEATS4',
#  'MFSD9',
#  '664618',
#  'PRICKLE4',
#  '319139',
#  '644590',
#  'HRC',
#  '648638',
#  'KLHL41',
#  'SLC35A3',
#  '650098',
#  'RAB3A',
#  'RASSF6',
#  'FBXW5',
#  'SGPL1',
#  'SLC10A3',
#  'MFSD1',
#  'PSMA2',
#  'DEFB104B',
#  '652534',
#  'SLC33A1',
#  'GUCA1B',
#  'KNTC1',
#  '51275',
#  'C2orf42',
#  'ZMYM4',
#  '286094',
#  '100131372',
#  '5786',
#  '728779',
#  '647987',
#  'IL10RB',
#  'ASB10',
#  'ATP5SL',
#  'GPR137B',
#  'PLEKHG5',
#  '441212',
#  '220115',
#  '51306',
#  'TUBB',
#  'SMIM4',
#  'TTLL7',
#  'NEK6',
#  'SMC4',
#  'POLR3E',
#  '653147',
#  '2282',
#  'WNT6',
#  'KREMEN2',
#  'TJP3',
#  'AKR1C3',
#  '388438',
#  'MRPL23',
#  'TRMT61B',
#  'SERPINB6',
#  'UTP4',
#  'GGCT',
#  'KIT',
#  '100134098',
#  'CD8A',
#  'ELP2',
#  'RAD51B',
#  'KIAA0586',
#  'LUZP2',
#  '100128562',
#  'LARS',
#  'EXOC8',
#  '100133585',
#  'KCNH8',
#  '100134584',
#  '100129637',
#  'TRMT1',
#  'DPY19L1',
#  '653450',
#  'RNF146',
#  'JOSD1',
#  '84809',
#  '100130812',
#  'SUZ12',
#  '152302',
#  'AGR3',
#  '729668',
#  'PSMF1',
#  'SLC35B2',
#  'HAMP',
#  'TCAF1',
#  'RPS15',
#  'ZNF511',
#  'NXN',
#  'ARL17A',
#  'NLRX1',
#  'NUTM2F',
#  'TRAF6',
#  '642381',
#  'RPL7',
#  'DMRTC1B',
#  'DENND6A',
#  'RHCE',
#  'FAM98B',
#  '400446',
#  'ERP44',
#  '729143',
#  'PBX4',
#  'SCNM1',
#  '730284',
#  'C18orf21',
#  'CD93',
#  'GPAM',
#  'CD101',
#  'P2RX3',
#  'CPPED1',
#  '100132205',
#  '653506',
#  'BCL2',
#  'CLIC1',
#  '388289',
#  '26172',
#  '648622',
#  'ZNF77',
#  'ZNF718',
#  '652408',
#  '401224',
#  'PYGL',
#  '728263',
#  'FGD2',
#  'SGSM2',
#  'PDGFD',
#  '121906',
#  'SNRPN',
#  'DOHH',
#  '89837',
#  'MGAT2',
#  '151457',
#  'KLRC3',
#  'ORC1',
#  '650921',
#  'FAM134A',
#  'BCAP31',
#  '401242',
#  '440013',
#  'CLPS',
#  'TSKU',
#  'PDSS2',
#  '2497',
#  '652606',
#  'TIMM8A',
#  '645636',
#  '731186',
#  'HIC2',
#  'NKX1-1',
#  '647086',
#  'HMGN5',
#  'RERE',
#  'KDM2B',
#  'CD5',
#  'SPON1',
#  'KDM1A',
#  'CCL23',
#  '100132717',
#  'ORC4',
#  'MAGEA9B',
#  '441124',
#  'ACSF3',
#  '390226',
#  'NDUFA6',
#  'PRR15L',
#  '441013',
#  'STPG2',
#  'SLX4',
#  '100190939',
#  'NUDT21',
#  'POLR2D',
#  'CEACAM3',
#  'C1GALT1C1',
#  'RBSN',
#  '139046',
#  '644171',
#  'DUSP14',
#  'ECHDC3',
#  'THADA',
#  'METTL21B',
#  'ATP23',
#  'CENPT',
#  'DIABLO',
#  '401288',
#  '440366',
#  '100132354',
#  'F8A3',
#  'FAF1',
#  'WAC',
#  '651450',
#  'GLI1',
#  'CMSS1',
#  '646509',
#  'OR52E6',
#  '649618',
#  'IQCK',
#  'NCKIPSD',
#  '644929',
#  'CRTAP',
#  'MFSD7',
#  '651952',
#  'RTCA',
#  'BLCAP',
#  'LRMP',
#  'PREPL',
#  'TESPA1',
#  'MTIF3',
#  'FZD10',
#  '100129424',
#  '441843',
#  'TOLLIP',
#  'TFPI2',
#  'MFAP3L',
#  'USH1G',
#  'BNIP1',
#  'CLEC4G',
#  'BAX',
#  'CXCR5',
#  'ZNF860',
#  'TXNRD3NB',
#  'FIS1',
#  'GNG8',
#  'EVI2A',
#  '651398',
#  'ZKSCAN3',
#  '729751',
#  'GSG1',
#  'SAMD4A',
#  'NEK4',
#  'MSI1',
#  '644044',
#  'C8orf86',
#  '84054',
#  '642398',
#  'CAPRIN2',
#  '260341',
#  'C5orf51',
#  '100124537',
#  'SMUG1',
#  'MFSD11',
#  '55147',
#  'ZDHHC8',
#  'ZNF556',
#  'MRPS18B',
#  'SRCAP',
#  'GPR3',
#  'IFI30',
#  'USP35',
#  'FHL2',
#  'SIRPD',
#  'ANKRD9',
#  'RRM1',
#  'ZNF781',
#  'TTC17',
#  'TYK2',
#  '283521',
#  '388339',
#  '644076',
#  '389105',
#  'FXR2',
#  'PRB1',
#  'RALY',
#  'CNIH1',
#  'CHMP7',
#  'C8orf58',
#  'SLC39A9',
#  '100132091',
#  'LUC7L2',
#  '8193',
#  'RPL10L',
#  '650463',
#  'RGMA',
#  'SIRT3',
#  '649248',
#  '441958',
#  'ELF3',
#  'C2CD4C',
#  '727987',
#  'HEXA',
#  '55370',
#  'TRUB1',
#  'EMX2',
#  'RPL35',
#  'CLDND2',
#  'REEP4',
#  'PPP1R14C',
#  'PEX2',
#  'TM2D3',
#  'WDR91',
#  'ALCAM',
#  'HLTF',
#  'PBLD',
#  '650930',
#  'CBX7',
#  'FUNDC2',
#  'ASH2L',
#  'FAM13C',
#  'PCDH18',
#  'SCRN1',
#  'NCOA1',
#  '645904',
#  'ANXA11',
#  '645848',
#  'MAP1LC3C',
#  'NIT1',
#  '341965',
#  '100131094',
#  'TSPAN13',
#  '100132632',
#  'TRIM21',
#  'NCOR2',
#  'PTGFRN',
#  'C16orf92',
#  'CASZ1',
#  'RGS6',
#  'RNF145',
#  'ZC3HAV1',
#  'POLR3D',
#  'TNNI1',
#  'PLPP2',
#  'RPS29',
#  '645058',
#  'C1S',
#  '400946',
#  'MYOC',
#  'CABP2',
#  'SPATA3',
#  '55025',
#  '442572',
#  'DNAJC5',
#  '645153',
#  'BYSL',
#  '648600',
#  'ENY2',
#  'METTL6',
#  'NIPAL3',
#  'ZNF408',
#  '729950',
#  'NCCRP1',
#  'BCL9',
#  'SKIV2L',
#  'TPMT',
#  'OTUB1',
#  'RGS18',
#  'FTSJ1',
#  '100129191',
#  'RPLP0',
#  'GREM2',
#  'PDS5A',
#  '646626',
#  '100127899',
#  '90925',
#  'GLO1',
#  'STK11',
#  'ZNF296',
#  'MNAT1',
#  '388007',
#  'YAE1D1',
#  'PDLIM3',
#  'GCLM',
#  'C19orf52',
#  '163720',
#  'EDEM2',
#  '100190986',
#  '401537',
#  'PRSS57',
#  'TRIB2',
#  'RPS27A',
#  'GSR',
#  'HMGA2',
#  'FGFBP2',
#  'CCDC69',
#  'CCDC93',
#  '730415',
#  'MBD3',
#  'BPNT1',
#  '646836',
#  '730092',
#  'MED11',
#  'RPS3A',
#  'SLC16A7',
#  'TRMT61A',
#  '440030',
#  'PRR14L',
#  'MAP3K7CL',
#  'RGS2',
#  'CDK1',
#  'ANK2',
#  'CSRNP3',
#  '728701',
#  'HSD17B14',
#  'TNIP1',
#  '649076',
#  'ZNF775',
#  '121952',
#  'MATK',
#  'LMO7',
#  '340206',
#  'PLCL1',
#  'SDCCAG3',
#  'PPT2',
#  '85287',
#  'ADGRE1',
#  'PLCB3',
#  'ZNF22',
#  'NSFL1C',
#  'CENPH',
#  'RNF214',
#  'IL18R1',
#  '283547',
#  '554203',
#  'OGG1',
#  '652427',
#  'HIBCH',
#  'PHKA1',
#  'MTFMT',
#  '652900',
#  'ARG2',
#  '642678',
#  'LMNB1',
#  '51214',
#  'ESAM',
#  'OR10AD1',
#  '646103',
#  '147172',
#  'C1orf116',
#  'CEP44',
#  '390735',
#  '729677',
#  '727735',
#  'PIGV',
#  'GTPBP8',
#  '100129203',
#  'OR1N1',
#  'UNC13A',
#  'LSM2',
#  '402066',
#  'BRIP1',
#  '90024',
#  '692099',
#  '100302280',
#  'SH2D1A',
#  'COLGALT2',
#  'SLC25A44',
#  'CIB2',
#  'NT5C',
#  'TRAPPC9',
#  'METTL8',
#  '402251',
#  '644345',
#  '728127',
#  'AGAP6',
#  'RRP15',
#  '645648',
#  ...}
