# %%
from hypergraphs import *
from kegg import *
import pandas as pd
import os
import logging

from Bio.KEGG.KGML.KGML_parser import read
import Bio.KEGG.KGML.KGML_pathway
from ast import literal_eval
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
import requests
from Levenshtein import ratio
import scipy.stats
import pathlib
from qf.cc import cardon_crochemore_colored, cardon_crochemore
import random

from reportlab.lib.units import inch
import PIL.Image
from io import BytesIO
import reportlab.pdfgen.canvas
import reportlab.lib.colors

# %%
organismDict = {"hsa": "Homo sapiens (human)"}
outputDirectory = "/Users/boldi/Desktop/pw/"
inputDirectory = "../../LaTeX/Data/KEGG-Pathways/Mar2024/"
dataDirectory = "../../LaTeX/Data/KEGG-Pathways"

# %%
pathwaylistFilename = "KEGG-pathways.txt"  # In inputDirectory, csv: ID, type, name
superpathway = "All"                  # Name of the superpathway
organism = "hsa"
confidence = 0.05

produceGraphsWithCCcoloring = False
produceGraphsWithAnomalies = True
useCCcoloringForAnomalies = False
produceAnomaliesForNonsignificantPairs = True

# %%
safeSuperpathway = makesafe(superpathway)

# %%
pws = pd.read_csv(os.path.join(inputDirectory, "KEGG-pathways.txt"), 
            names=["Pathway ID", "Pathway type", "Pathway name"], dtype="string", keep_default_na=False)

# %%
superpathwayDict = {
    superpathway: [(x,y) for x,y in zip(pws["Pathway ID"], pws["Pathway name"])]
}

# %%
def words2set(words):
    """
        Given a space-separated list of words, returns it as a set of words
    """
    return set(words.split())

# %%
from typing import NamedTuple

class Relation(NamedTuple):
    """
        Represents a relation. It is characterized by:
        - a type (e.g. "PPRel") 
        - a list of subtypes (e.g. [('activation', '-->'), ('indirect effect', '..>')])
        - a set of components (source)
        - a list of sets of components (target)
    """
    relType: str
    relSubtypes: list
    source: set
    target: list
    sourceg: Bio.KEGG.KGML.KGML_pathway.Graphics
    targetg: Bio.KEGG.KGML.KGML_pathway.Graphics
        
    @classmethod
    def fromKEGG(cls, relation, pathway):
        """
            Constructor: builds a Relation from a KEGG relation
        """
        if relation.entry2.name == "undefined":
            s = []
            for component in relation.entry2.components:
                s += [words2set(pathway.entries[component.id].name)]
            targetg = pathway.entries[component.id].graphics[0]
        else:
            s = [words2set(relation.entry2.name)]
            targetg = relation.entry2.graphics[0]
        return cls(relation.type, relation.subtypes, words2set(relation.entry1.name), s, targetg, relation.entry1.graphics[0])

# %%
def relationsFromKEGGpathway(pathway):
    """
        Given a KEGG pathway, returns the list of relations it contains (represented as Relation).
    """
    return [Relation.fromKEGG(r, pathway) for r in pathway.relations]

# %%
def pathwayFromFile(dataDirectory, organism, pathwayID):
    """
        Load and return a KEGG pathway, given the data directory, the organism specifying the subdirectory,
        and the pathwayID (the filename should be organism+pathwayID+"xml".
    """
    return KGML_parser.read(open(os.path.join(dataDirectory, organism, organism+pathwayID+".xml"), "r"))

# %%
def relationsFromFile(dataDirectory, organism, pathwayID):
    """
        Given a pathway file (specified by a root dataDirectory, the name of the organism subdirectory, and the name
        of the file [organism+pathwayID.xml]), reads it and returns the list of its relations.
    """
    pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
    return relationsFromKEGGpathway(pathway)

# %%
def relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway):
    """
        Given a superpathDict (whose keys are superpathway names and whose values are list of
        pairs (pathwayID, pathwayName)), reads all the pathway file for a specific superpathway name
        and returns a dictionary whose keys are the pathwayID's and whose values are the list of relations.
    """
    rel = {}
    for k,v in superpathwayDict[superpathway]:
        #logging.info("Reading", k, v)
        rel[k] = relationsFromFile(dataDirectory, organism, k)
    return rel

# %%
def subtypes(rel):
    """
        Given a map whose values are relations, accumulate all subtypes appearing and assign them a number.
        The result is a map from subtype string to number.
    """
    all_subtypes = set([])
    for pathwayid, relations in rel.items():
        for relation in relations:
            all_subtypes |= set([str(relation.relSubtypes)])
        
    s = sorted(list(all_subtypes))
    subtype2color = {v:k for k,v in enumerate(s)}
    color2subtype = {k:v for k,v in enumerate(s)}

    return subtype2color, color2subtype

# %%
def set2can(s):
    """
        Convert a set to a string in a canonical way.
    """
    return str(sorted(list(s)))

def can2set(c):
    """
        Does the converse of set2can.
    """
    return set(literal_eval(c))

# %%
def indices(rel):
    """
        Given a map whose values are lists of relations, it considers all the relations one by one, and attributes a unique id 
        to each element (i.e., set of components appearing as source or in the target of some relation) and block (the set of
        element id appearing as target of some relation).
        This function returns the dictionaries to move from/to an element or block to the corresponding id.
        Elements are string representations of sorted lists of strings.
        Blocks are string representations of sorted lists of ints.
    """
    element2id = {}
    id2element = {}
    block2id = {}
    id2block = {}

    for relations in rel.values():
        for relation in relations:
            s = set2can(relation.source)
            if s not in element2id.keys():
                element2id[s] = len(element2id)
            targetset = set([])
            for targ in relation.target:
                t = set2can(targ)
                if t not in element2id.keys():
                    element2id[t] = len(element2id)
                targetset |= set([element2id[t]])
            ts = set2can(targetset)
            if ts not in block2id.keys():
                block2id[ts] = len(block2id)

    for k,v in element2id.items():
        id2element[v] = k
    for k,v in block2id.items():
        id2block[v] = k
    return element2id, id2element, block2id, id2block

# %%
def search_gene_KEGG(geneID):
    """
        Search for gene on KEGG. 
        
        Returns list of names.
    """
    url1 = "https://www.kegg.jp/entry/"+geneID
    response1 = requests.get(url1, allow_redirects=False)    
    soup = BeautifulSoup(response1.text, "html.parser")
    tds = [tds for tds in soup.find_all("td", {"class": "td11 defd"})]
    names = tds[0].getText().strip().split(", ")
    return names

# %%
def get_temp_imagefilename(url):
    """Return filename of temporary file containing downloaded image.

    Create a new temporary file to hold the image file at the passed URL
    and return the filename.
    """
    img = urlopen(url).read()
    im = PIL.Image.open(BytesIO(img))
    # im.transpose(Image.FLIP_TOP_BOTTOM)
    f = tempfile.NamedTemporaryFile(delete=False, suffix=".png")
    fname = f.name
    f.close()
    im.save(fname, "PNG")
    return fname


#def enhance_method(klass, method_name, replacement):
#    'replace a method with an enhanced version'
#    method = getattr(klass, method_name)
#    def enhanced(*args, **kwds): return replacement(*args, **kwds)
#    setattr(klass, method_name, enhanced)

def new_draw(self, filename, relations, elaborateArc = None):
        """Add the map elements to the drawing."""
        # Instantiate the drawing, first
        # size x_max, y_max for now - we can add margins, later
        if self.import_imagemap:
            # We're drawing directly on the image, so we set the canvas to the
            # same size as the image
            if os.path.isfile(self.pathway.image):
                imfilename = self.pathway.image
            else:
                imfilename = get_temp_imagefilename(self.pathway.image)
            im = PIL.Image.open(imfilename)
            cwidth, cheight = im.size
        else:
            # No image, so we set the canvas size to accommodate visible
            # elements
            cwidth, cheight = (self.pathway.bounds[1][0], self.pathway.bounds[1][1])
        # Instantiate canvas
        self.drawing = reportlab.pdfgen.canvas.Canvas(
            filename,
            bottomup=0,
            pagesize=(
                cwidth * (1 + 2 * self.margins[0]),
                cheight * (1 + 2 * self.margins[1]),
            ),
        )
        self.drawing.setFont(self.fontname, self.fontsize)
        # Transform the canvas to add the margins
        self.drawing.translate(
            self.margins[0] * self.pathway.bounds[1][0],
            self.margins[1] * self.pathway.bounds[1][1],
        )
        # Add the map image, if required
        if self.import_imagemap:
            self.drawing.saveState()
            self.drawing.scale(1, -1)
            self.drawing.translate(0, -cheight)
            self.drawing.drawImage(imfilename, 0, 0)
            self.drawing.restoreState()
        # Add the reactions, compounds and maps
        # Maps go on first, to be overlaid by more information.
        # By default, they're slightly transparent.
        if self.show_maps:
            self.__add_maps()
        if self.show_reaction_entries:
            KGMLCanvas._KGMLCanvas__add_reaction_entries(self)
        if self.show_orthologs:
            KGMLCanvas._KGMLCanvas__add_orthologs(self)
        if self.show_compounds:
            KGMLCanvas._KGMLCanvas__add_compounds(self)
        if self.show_genes:
            KGMLCanvas._KGMLCanvas__add_genes(self)
        # TODO: complete draw_relations code
        # if self.draw_relations:
        #    self.__add_relations()
        # Write the pathway map to PDF
        if elaborateArc is not None:
            for relation in relations:
                elaborateArc(relation, self.drawing)
        self.drawing.save()
        
#enhance_method(KGMLCanvas, 'draw',  new_draw)
setattr(KGMLCanvas, 'new_draw', new_draw)

# %%
# Build all data needed for the relations of the superpathway
rel = relationsForSuperpathway(dataDirectory, organism, superpathwayDict, superpathway)
element2id, id2element, block2id, id2block = indices(rel)
subtype2color, color2subtype = subtypes(rel)
elements = list(set.union(*[can2set(k) for k in element2id.keys()]))

# %%
# name2gene is a function mapping names to gene IDs (hsa:xxxx)
# e.g. KCNE3, BRGDA6 etc are all mapped to hsa:10008 (see https://www.kegg.jp/entry/hsa:10008)
# This map was produced by scraping kegg, but this has been done only once.
# After that, we just read a pkl file

name2keggFilename = os.path.join(inputDirectory, "name2kegg.pkl")

if os.path.exists(name2keggFilename):
    print("Reading gene names")
    with open(name2keggFilename, "rb") as handle:
        name2gene = pickle.load(handle)
else:
    print("Producing gene names")
    d = {}
    nelements = len(elements)
    for count,element in enumerate(elements):
        if count % 10 == 0:
            print(f"{count}/{nelements}")
        if element.startswith("hsa"):
            names = search_gene_KEGG(element)
            for name in names:
                d[name] = element
    with open(name2keggFilename, "wb") as handle:
        pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
    name2gene = d
# Out:
# Reading gene names

# %%
# Read patient data
print("Reading patient data")
genes = pd.read_csv(os.path.join(inputDirectory, "genes.csv"), dtype={"name": str})
patients = genes["name"].values.tolist()
classification = pd.read_csv(os.path.join(inputDirectory, "classification.csv"), dtype={"name": str})

patient2class = {patient: classification.loc[classification["name"]==patient]["classification"].values.flatten().tolist()[0] for patient in patients}
numHealthy = sum([x == 'healthy' for x in patient2class.values()])
numDiseased = sum([x == 'diseased' for x in patient2class.values()])
# Out:
# Reading patient data

# %%
# Dividing genes into two frames (one for healthy individuals and one for diseased individuals)
genesHealthy = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="healthy"]
genesDiseased = genes.loc[genes["name"].apply(lambda x: patient2class[x])=="diseased"]

# %%
# Building the graph of all relations contained in rel values
# Nodes are IDs, and node x correspond to the set of genes (and/or compound) id2element[x]
print("Building the relation graph")
G = nx.DiGraph() 
for pathwayID, relations in rel.items():
    for relation in relations:
        source = element2id[set2can(relation.source)]
        for targ in relation.target:
            target = element2id[set2can(targ)]
            newType = str(relation.relSubtypes)
            color = subtype2color[newType]
            pl = []
            if G.has_edge(source, target):
                d = G.get_edge_data(source, target)
                if d["color"] != color:
                    oldType = color2subtype[d["color"]]
                    print("- Edge ({},{}) of type {} for {} appears as {} for {}. ".format(
                        source, target, color2subtype[d["color"]], d["pathwayIDs"], 
                        str(relation.relSubtypes), pathwayID
                    ), end="")
                    if oldType[1:-1] in newType[1:-1]:
                        print("Overwriting with type {}".format(newType))
                    elif newType[1:-1] in oldType[1:-1]:
                        print("Overwriting with type {}".format(oldType))
                        color = subtype2color[oldType]
                    else:
                        print("\n****Conflict! Rewriting as {}".format(newType))
                pl = d["pathwayIDs"]
            G.add_edge(source, target, color=color, pathwayIDs=pl + [pathwayID])
            

# Computing the minimum fibres
cc=cardon_crochemore_colored(G)

colors = list(matplotlib.colors.CSS4_COLORS.values())
usedColors = 0

cc2fibresize = {}
cc2fibre = {}
ccnontrivial = {}
nontrivialclass2col = {}

fibres = []
node2fibre = {}
for v in set(cc.values()):
    fibre = [x for x in G.nodes() if cc[x] == v]
    fibres += [fibre]
    for x in fibre:
        node2fibre[x] = fibre
    cc2fibre[v] = fibre
    cc2fibresize[v] = len(fibre)
    if len(fibre) > 0:
        ccnontrivial[v] = cc[v]
        nontrivialclass2col[v] = colors[usedColors]
        usedColors = (usedColors + 1 ) % len(colors)
        if usedColors == 0:
            print("Wrap: more than", len(colors), "colors needed")
# Out:
# Building the relation graph
# - Edge (4,1) of type [('compound', 93)] for ['00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (4,2) of type [('compound', 93)] for ['00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (0,21) of type [('compound', 90)] for ['00010'] appears as [('compound', 91)] for 00010.
# ****Conflict! Rewriting as [('compound', 91)]
# - Edge (21,4) of type [('compound', 93)] for ['00010'] appears as [('compound', 94)] for 00010.
# ****Conflict! Rewriting as [('compound', 94)]
# - Edge (21,4) of type [('compound', 94)] for ['00010', '00010', '00010'] appears as [('compound', 93)] for 00010.
# ****Conflict! Rewriting as [('compound', 93)]
# - Edge (40,38) of type [('compound', 320)] for ['00230'] appears as [('compound', 356)] for 00230.
# ****Conflict! Rewriting as [('compound', 356)]
# - Edge (40,56) of type [('compound', 343)] for ['00230'] appears as [('compound', 355)] for 00230.
# ****Conflict! Rewriting as [('compound', 355)]
# - Edge (54,46) of type [('compound', 368)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (54,55) of type [('compound', 392)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (54,56) of type [('compound', 392)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (55,56) of type [('compound', 392)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (40,51) of type [('compound', 343)] for ['00230', '00230', '00230', '00230'] appears as [('compound', 332)] for 00230.
# ****Conflict! Rewriting as [('compound', 332)]
# - Edge (40,56) of type [('compound', 355)] for ['00230', '00230'] appears as [('compound', 332)] for 00230.
# ****Conflict! Rewriting as [('compound', 332)]
# - Edge (61,56) of type [('compound', 392)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (34,46) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (34,50) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (34,56) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (34,57) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (46,56) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (46,57) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (50,56) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (50,57) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (56,57) of type [('compound', 330)] for ['00230'] appears as [('compound', 365)] for 00230.
# ****Conflict! Rewriting as [('compound', 365)]
# - Edge (57,52) of type [('compound', 331)] for ['00230'] appears as [('compound', 366)] for 00230.
# ****Conflict! Rewriting as [('compound', 366)]
# - Edge (52,56) of type [('compound', 332)] for ['00230'] appears as [('compound', 355)] for 00230.
# ****Conflict! Rewriting as [('compound', 355)]
# - Edge (40,62) of type [('compound', 343)] for ['00230'] appears as [('compound', 355)] for 00230.
# ****Conflict! Rewriting as [('compound', 355)]
# - Edge (41,57) of type [('compound', 365)] for ['00230'] appears as [('compound', 357)] for 00230.
# ****Conflict! Rewriting as [('compound', 357)]
# - Edge (58,57) of type [('compound', 330)] for ['00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (46,57) of type [('compound', 365)] for ['00230', '00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (48,46) of type [('compound', 369)] for ['00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (57,69) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (57,52) of type [('compound', 366)] for ['00230', '00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (69,52) of type [('compound', 331)] for ['00230'] appears as [('compound', 326)] for 00230.
# ****Conflict! Rewriting as [('compound', 326)]
# - Edge (46,45) of type [('compound', 390)] for ['00230'] appears as [('compound', 380)] for 00230.
# ****Conflict! Rewriting as [('compound', 380)]
# - Edge (46,46) of type [('compound', 369)] for ['00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (48,45) of type [('compound', 390)] for ['00230'] appears as [('compound', 380)] for 00230.
# ****Conflict! Rewriting as [('compound', 380)]
# - Edge (49,45) of type [('compound', 390)] for ['00230'] appears as [('compound', 380)] for 00230.
# ****Conflict! Rewriting as [('compound', 380)]
# - Edge (42,53) of type [('compound', 325)] for ['00230'] appears as [('compound', 377)] for 00230.
# ****Conflict! Rewriting as [('compound', 377)]
# - Edge (73,48) of type [('compound', 360)] for ['00230'] appears as [('compound', 324)] for 00230.
# ****Conflict! Rewriting as [('compound', 324)]
# - Edge (73,48) of type [('compound', 324)] for ['00230', '00230'] appears as [('compound', 322)] for 00230.
# ****Conflict! Rewriting as [('compound', 322)]
# - Edge (37,57) of type [('compound', 325)] for ['00230'] appears as [('compound', 321)] for 00230.
# ****Conflict! Rewriting as [('compound', 321)]
# - Edge (58,46) of type [('compound', 325)] for ['00230'] appears as [('compound', 330)] for 00230.
# ****Conflict! Rewriting as [('compound', 330)]
# - Edge (46,45) of type [('compound', 380)] for ['00230', '00230'] appears as [('compound', 325)] for 00230.
# ****Conflict! Rewriting as [('compound', 325)]
# - Edge (40,57) of type [('compound', 367)] for ['00230'] appears as [('compound', 320)] for 00230.
# ****Conflict! Rewriting as [('compound', 320)]
# - Edge (46,73) of type [('compound', 324)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (46,46) of type [('compound', 324)] for ['00230', '00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (46,48) of type [('compound', 324)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (41,48) of type [('compound', 360)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (73,46) of type [('compound', 324)] for ['00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (73,48) of type [('compound', 322)] for ['00230', '00230', '00230'] appears as [('compound', 362)] for 00230.
# ****Conflict! Rewriting as [('compound', 362)]
# - Edge (48,50) of type [('compound', 369)] for ['00230'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (46,46) of type [('compound', 362)] for ['00230', '00230', '00230'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (48,46) of type [('compound', 324)] for ['00230', '00230'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (48,70) of type [('compound', 380)] for ['00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (46,70) of type [('compound', 380)] for ['00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (45,70) of type [('compound', 380)] for ['00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (48,45) of type [('compound', 380)] for ['00230', '00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (46,45) of type [('compound', 325)] for ['00230', '00230', '00230'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (96,46) of type [('compound', 185)] for ['00240'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (46,73) of type [('compound', 362)] for ['00230', '00230'] appears as [('compound', 214)] for 00240.
# ****Conflict! Rewriting as [('compound', 214)]
# - Edge (46,46) of type [('compound', 186)] for ['00230', '00230', '00230', '00240'] appears as [('compound', 214)] for 00240.
# ****Conflict! Rewriting as [('compound', 214)]
# - Edge (57,89) of type [('compound', 221)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (57,94) of type [('compound', 220)] for ['00240'] appears as [('compound', 219)] for 00240.
# ****Conflict! Rewriting as [('compound', 219)]
# - Edge (91,91) of type [('compound', 181)] for ['00240'] appears as [('compound', 180)] for 00240.
# ****Conflict! Rewriting as [('compound', 180)]
# - Edge (48,46) of type [('compound', 186)] for ['00230', '00230', '00240'] appears as [('compound', 214)] for 00240.
# ****Conflict! Rewriting as [('compound', 214)]
# - Edge (48,73) of type [('compound', 214)] for ['00240'] appears as [('compound', 217)] for 00240.
# ****Conflict! Rewriting as [('compound', 217)]
# - Edge (94,38) of type [('compound', 220)] for ['00240'] appears as [('compound', 219)] for 00240.
# ****Conflict! Rewriting as [('compound', 219)]
# - Edge (46,57) of type [('compound', 325)] for ['00230', '00230', '00230'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (48,103) of type [('compound', 217)] for ['00240'] appears as [('compound', 194)] for 00240.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (48,46) of type [('compound', 214)] for ['00230', '00230', '00240', '00240'] appears as [('compound', 194)] for 00240.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (89,38) of type [('compound', 221)] for ['00240'] appears as [('compound', 218)] for 00240.
# ****Conflict! Rewriting as [('compound', 218)]
# - Edge (57,94) of type [('compound', 219)] for ['00240', '00240'] appears as [('compound', 212)] for 00240.
# ****Conflict! Rewriting as [('compound', 212)]
# - Edge (46,46) of type [('compound', 214)] for ['00230', '00230', '00230', '00240', '00240'] appears as [('compound', 194)] for 00240.
# ****Conflict! Rewriting as [('compound', 194)]
# - Edge (46,106) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (106,94) of type [('compound', 212)] for ['00240'] appears as [('compound', 188)] for 00240.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (103,57) of type [('compound', 218)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (57,97) of type [('compound', 219)] for ['00240'] appears as [('compound', 188)] for 00240.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (103,98) of type [('compound', 218)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (102,38) of type [('compound', 218)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (101,106) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (57,94) of type [('compound', 212)] for ['00240', '00240', '00240'] appears as [('compound', 188)] for 00240.
# ****Conflict! Rewriting as [('compound', 188)]
# - Edge (103,38) of type [('compound', 218)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (57,45) of type [('compound', 365)] for ['00230'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (46,57) of type [('compound', 213)] for ['00230', '00230', '00230', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (46,57) of type [('compound', 195)] for ['00230', '00230', '00230', '00240', '00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (99,38) of type [('compound', 219)] for ['00240'] appears as [('compound', 196)] for 00240.
# ****Conflict! Rewriting as [('compound', 196)]
# - Edge (50,57) of type [('compound', 365)] for ['00230', '00230'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (102,57) of type [('compound', 218)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (45,46) of type [('compound', 365)] for ['00230'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (101,57) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (46,45) of type [('compound', 185)] for ['00230', '00230', '00230', '00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (57,99) of type [('compound', 219)] for ['00240'] appears as [('compound', 196)] for 00240.
# ****Conflict! Rewriting as [('compound', 196)]
# - Edge (48,45) of type [('compound', 185)] for ['00230', '00230', '00240'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (98,99) of type [('compound', 219)] for ['00240'] appears as [('compound', 196)] for 00240.
# ****Conflict! Rewriting as [('compound', 196)]
# - Edge (101,88) of type [('compound', 218)] for ['00240'] appears as [('compound', 221)] for 00240.
# ****Conflict! Rewriting as [('compound', 221)]
# - Edge (45,57) of type [('compound', 325)] for ['00230'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (100,107) of type [('compound', 210)] for ['00240'] appears as [('compound', 202)] for 00240.
# ****Conflict! Rewriting as [('compound', 202)]
# - Edge (45,46) of type [('compound', 191)] for ['00230', '00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (48,101) of type [('compound', 214)] for ['00240'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (101,57) of type [('compound', 187)] for ['00240', '00240'] appears as [('compound', 221)] for 00240.
# ****Conflict! Rewriting as [('compound', 221)]
# - Edge (107,92) of type [('compound', 209)] for ['00240'] appears as [('compound', 203)] for 00240.
# ****Conflict! Rewriting as [('compound', 203)]
# - Edge (48,73) of type [('compound', 217)] for ['00240', '00240'] appears as [('compound', 222)] for 00240.
# ****Conflict! Rewriting as [('compound', 222)]
# - Edge (46,50) of type [('compound', 369)] for ['00230'] appears as [('compound', 186)] for 00240.
# ****Conflict! Rewriting as [('compound', 186)]
# - Edge (48,101) of type [('compound', 186)] for ['00240', '00240'] appears as [('compound', 222)] for 00240.
# ****Conflict! Rewriting as [('compound', 222)]
# - Edge (106,45) of type [('compound', 187)] for ['00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (46,45) of type [('compound', 187)] for ['00230', '00230', '00230', '00240', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (45,57) of type [('compound', 213)] for ['00230', '00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (48,45) of type [('compound', 191)] for ['00230', '00230', '00240', '00240'] appears as [('compound', 193)] for 00240.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (46,45) of type [('compound', 195)] for ['00230', '00230', '00230', '00240', '00240', '00240'] appears as [('compound', 193)] for 00240.
# ****Conflict! Rewriting as [('compound', 193)]
# - Edge (46,108) of type [('compound', 193)] for ['00240'] appears as [('compound', 195)] for 00240.
# ****Conflict! Rewriting as [('compound', 195)]
# - Edge (46,108) of type [('compound', 195)] for ['00240', '00240'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (48,108) of type [('compound', 193)] for ['00240'] appears as [('compound', 191)] for 00240.
# ****Conflict! Rewriting as [('compound', 191)]
# - Edge (57,108) of type [('compound', 195)] for ['00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (46,108) of type [('compound', 191)] for ['00240', '00240', '00240'] appears as [('compound', 213)] for 00240.
# ****Conflict! Rewriting as [('compound', 213)]
# - Edge (96,108) of type [('compound', 191)] for ['00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (48,108) of type [('compound', 191)] for ['00240', '00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (46,108) of type [('compound', 213)] for ['00240', '00240', '00240', '00240'] appears as [('compound', 185)] for 00240.
# ****Conflict! Rewriting as [('compound', 185)]
# - Edge (46,108) of type [('compound', 185)] for ['00240', '00240', '00240', '00240', '00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (101,108) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (106,108) of type [('compound', 213)] for ['00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (57,108) of type [('compound', 213)] for ['00240', '00240'] appears as [('compound', 187)] for 00240.
# ****Conflict! Rewriting as [('compound', 187)]
# - Edge (138,176) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04062. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (518,504) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04062.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (518,216) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04062.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (176,189) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->')] for 04066.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (487,166) of type [('compound', 151), ('activation', '-->')] for ['04062'] appears as [('activation', '-->')] for 04066. Overwriting with type [('compound', 151), ('activation', '-->')]
# - Edge (569,572) of type [('compound', 52)] for ['04070'] appears as [('compound', 235)] for 04070.
# ****Conflict! Rewriting as [('compound', 235)]
# - Edge (572,569) of type [('compound', 234)] for ['04070'] appears as [('compound', 68)] for 04070.
# ****Conflict! Rewriting as [('compound', 68)]
# - Edge (576,575) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (575,577) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (582,583) of type [('compound', 66)] for ['04070'] appears as [('compound', 49)] for 04070.
# ****Conflict! Rewriting as [('compound', 49)]
# - Edge (574,577) of type [('compound', 75)] for ['04070'] appears as [('compound', 48)] for 04070.
# ****Conflict! Rewriting as [('compound', 48)]
# - Edge (574,577) of type [('compound', 48)] for ['04070', '04070'] appears as [('compound', 49)] for 04070.
# ****Conflict! Rewriting as [('compound', 49)]
# - Edge (588,575) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (588,571) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (487,576) of type [('compound', 73)] for ['04070'] appears as [('compound', 66)] for 04070.
# ****Conflict! Rewriting as [('compound', 66)]
# - Edge (576,589) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (585,585) of type [('compound', 60)] for ['04070'] appears as [('compound', 231)] for 04070.
# ****Conflict! Rewriting as [('compound', 231)]
# - Edge (577,589) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (574,589) of type [('compound', 72)] for ['04070'] appears as [('compound', 75)] for 04070.
# ****Conflict! Rewriting as [('compound', 75)]
# - Edge (573,575) of type [('compound', 75)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (587,568) of type [('compound', 66)] for ['04070'] appears as [('compound', 74)] for 04070.
# ****Conflict! Rewriting as [('compound', 74)]
# - Edge (584,585) of type [('compound', 56)] for ['04070'] appears as [('compound', 61)] for 04070.
# ****Conflict! Rewriting as [('compound', 61)]
# - Edge (585,585) of type [('compound', 231)] for ['04070', '04070'] appears as [('compound', 60)] for 04070.
# ****Conflict! Rewriting as [('compound', 60)]
# - Edge (576,574) of type [('compound', 75)] for ['04070'] appears as [('compound', 72)] for 04070.
# ****Conflict! Rewriting as [('compound', 72)]
# - Edge (574,577) of type [('compound', 49)] for ['04070', '04070', '04070'] appears as [('compound', 72)] for 04070.
# ****Conflict! Rewriting as [('compound', 72)]
# - Edge (580,591) of type [('compound', 55)] for ['04070'] appears as [('compound', 63)] for 04070.
# ****Conflict! Rewriting as [('compound', 63)]
# - Edge (586,584) of type [('compound', 56)] for ['04070'] appears as [('compound', 61)] for 04070.
# ****Conflict! Rewriting as [('compound', 61)]
# - Edge (591,586) of type [('compound', 55)] for ['04070'] appears as [('compound', 62)] for 04070.
# ****Conflict! Rewriting as [('compound', 62)]
# - Edge (568,576) of type [('compound', 73)] for ['04070'] appears as [('compound', 66)] for 04070.
# ****Conflict! Rewriting as [('compound', 66)]
# - Edge (159,608) of type [('expression', '-->')] for ['04115'] appears as [('activation', '-->')] for 04115.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (482,501) of type [] for ['04062'] appears as [('activation', '-->')] for 04151. Overwriting with type [('activation', '-->')]
# - Edge (166,133) of type [('phosphorylation', '+p'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (197,198) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04151.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (198,493) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->')] for 04151. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (540,176) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (544,546) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (546,548) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04151. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (155,156) of type [] for ['04010'] appears as [('activation', '-->')] for 04210. Overwriting with type [('activation', '-->')]
# - Edge (130,133) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04210. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (110,159) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04218. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (544,538) of type [('inhibition', '--|')] for ['04066'] appears as [('inhibition', '--|'), ('phosphorylation', '+p')] for 04218. Overwriting with type [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (576,501) of type [('inhibition', '--|'), ('dephosphorylation', '-p')] for ['04151'] appears as [('inhibition', '--|')] for 04218. Overwriting with type [('inhibition', '--|'), ('dephosphorylation', '-p')]
# - Edge (737,519) of type [('activation', '-->')] for ['04213'] appears as [('inhibition', '--|')] for 04218.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (159,207) of type [('expression', '-->')] for ['04115', '04115'] appears as [('activation', '-->')] for 04218.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (124,623) of type [('expression', '-->'), ('indirect effect', '..>')] for ['04218'] appears as [('expression', '-->')] for 04218. Overwriting with type [('expression', '-->'), ('indirect effect', '..>')]
# - Edge (792,785) of type [('activation', '-->')] for ['04310'] appears as [('inhibition', '--|')] for 04310.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (165,775) of type [('activation', '-->'), ('dephosphorylation', '-p')] for ['04218'] appears as [('dephosphorylation', '-p')] for 04310. Overwriting with type [('activation', '-->'), ('dephosphorylation', '-p')]
# - Edge (159,619) of type [('expression', '-->')] for ['04115', '04115'] appears as [('indirect effect', '..>')] for 04310.
# ****Conflict! Rewriting as [('indirect effect', '..>')]
# - Edge (487,166) of type [('compound', 151), ('activation', '-->')] for ['04062', '04066'] appears as [('compound', 24)] for 04510.
# ****Conflict! Rewriting as [('compound', 24)]
# - Edge (485,486) of type [('binding/association', '---')] for ['04062'] appears as [('phosphorylation', '+p')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p')]
# - Edge (120,718) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04210'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (138,176) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04010', '04062'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (176,557) of type [('expression', '-->'), ('indirect effect', '..>')] for ['04210'] appears as [('phosphorylation', '+p')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p')]
# - Edge (486,216) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04510.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (492,120) of type [('activation', '-->')] for ['04310'] appears as [('phosphorylation', '+p'), ('indirect effect', '..>')] for 04510.
# ****Conflict! Rewriting as [('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (497,197) of type [('binding/association', '---')] for ['04062'] appears as [('activation', '-->')] for 04510.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (669,166) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04210'] appears as [('phosphorylation', '+p')] for 04510. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (176,228) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (841,704) of type [('binding/association', '---')] for ['04510'] appears as [('activation', '-->')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (487,166) of type [('compound', 24)] for ['04062', '04066', '04510'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04611.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (722,521) of type [('dissociation', '-+-')] for ['04210'] appears as [('inhibition', '--|')] for 04620.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (127,116) of type [('activation', '-->')] for ['04010'] appears as [('binding/association', '---')] for 04620.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (540,176) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151', '04210', '04218'] appears as [('phosphorylation', '+p')] for 04620. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (757,110) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04218'] appears as [('phosphorylation', '+p')] for 04620. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (176,189) of type [('activation', '-->')] for ['04010', '04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (176,157) of type [('phosphorylation', '+p')] for ['04010', '04510'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (189,539) of type [('activation', '-->')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (734,741) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (166,544) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04066'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04910.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (546,548) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151'] appears as [('activation', '-->')] for 04910. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (487,669) of type [('compound', 24)] for ['04510'] appears as [('compound', 71), ('activation', '-->')] for 04910.
# ****Conflict! Rewriting as [('compound', 71), ('activation', '-->')]
# - Edge (198,493) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062', '04151'] appears as [('activation', '-->')] for 04910. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (954,722) of type [('phosphorylation', '+p')] for ['04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (722,521) of type [('inhibition', '--|')] for ['04210', '04620'] appears as [('dissociation', '-+-')] for 04931.
# ****Conflict! Rewriting as [('dissociation', '-+-')]
# - Edge (487,496) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062'] appears as [('activation', '-->')] for 04931. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (734,652) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (536,542) of type [('activation', '-->')] for ['04611', '04931'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 04931. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1018,652) of type [('inhibition', '--|'), ('indirect effect', '..>')] for ['04931'] appears as [('inhibition', '--|')] for 04931. Overwriting with type [('inhibition', '--|'), ('indirect effect', '..>')]
# - Edge (652,487) of type [('activation', '-->')] for ['04151', '04213', '04931', '04931'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 04931. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (796,145) of type [('compound', 12)] for ['04310'] appears as [('compound', 277), ('activation', '-->')] for 05146.
# ****Conflict! Rewriting as [('compound', 277), ('activation', '-->')]
# - Edge (874,875) of type [('compound', 131)] for ['04512'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (176,157) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04010', '04510', '04910'] appears as [('phosphorylation', '+p')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (506,510) of type [('activation', '-->')] for ['04062', '04510', '04611'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (487,166) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04062', '04066', '04510', '04611', '04620'] appears as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (510,850) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['04510'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (635,727) of type [('activation', '-->')] for ['04213'] appears as [('binding/association', '---')] for 05205.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (558,1089) of type [('activation', '-->')] for ['05205'] appears as [('inhibition', '--|')] for 05205.
# ****Conflict! Rewriting as [('inhibition', '--|')]
# - Edge (727,487) of type [('activation', '-->')] for ['04213'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (166,544) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (546,548) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04066', '04151', '04910'] appears as [('activation', '-->')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (546,691) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151'] appears as [('activation', '-->')] for 05205. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (487,669) of type [('compound', 71), ('activation', '-->')] for ['04510', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (669,546) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04910'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (1122,176) of type [('activation', '-->'), ('indirect effect', '..>')] for ['05205'] appears as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')] for 05205.
# ****Conflict! Rewriting as [('activation', '-->'), ('phosphorylation', '+p'), ('indirect effect', '..>')]
# - Edge (529,521) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04066'] appears as [('activation', '-->')] for 05321. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (487,501) of type [('activation', '-->')] for ['04151', '04210', '04213', '04213', '04218', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (652,487) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04213', '04931', '04931', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (166,682) of type [('inhibition', '--|'), ('phosphorylation', '+p')] for ['04151', '04510', '04910', '04931'] appears as [('missing interaction', '-/-')] for 05415.
# ****Conflict! Rewriting as [('missing interaction', '-/-')]
# - Edge (536,542) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04611', '04931', '04931'] appears as [('activation', '-->')] for 05415. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (418,642) of type [('indirect effect', '..>')] for ['04115'] appears as [('activation', '-->'), ('indirect effect', '..>')] for 05417. Overwriting with type [('activation', '-->'), ('indirect effect', '..>')]
# - Edge (955,120) of type [('phosphorylation', '+p')] for ['04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (120,152) of type [('phosphorylation', '+p')] for ['04010', '04620'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (116,133) of type [('phosphorylation', '+p')] for ['04010'] appears as [('activation', '-->'), ('phosphorylation', '+p')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (167,127) of type [('binding/association', '---')] for ['04010'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (166,682) of type [('missing interaction', '-/-')] for ['04151', '04510', '04910', '04931', '05415'] appears as [('inhibition', '--|'), ('phosphorylation', '+p')] for 05417.
# ****Conflict! Rewriting as [('inhibition', '--|'), ('phosphorylation', '+p')]
# - Edge (502,748) of type [('activation', '-->')] for ['04218', '04970'] appears as [('binding/association', '---')] for 05417.
# ****Conflict! Rewriting as [('binding/association', '---')]
# - Edge (521,536) of type [('activation', '-->'), ('indirect effect', '..>')] for ['04931'] appears as [('repression', '--|')] for 05417.
# ****Conflict! Rewriting as [('repression', '--|')]
# - Edge (521,450) of type [('expression', '-->')] for ['04620'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (715,716) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04210'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (521,1208) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,1209) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,1210) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,321) of type [('expression', '-->')] for ['04620'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (521,1211) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,353) of type [('expression', '-->')] for ['04620', '04931', '04931'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (1095,506) of type [('binding/association', '---')] for ['05205'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (521,447) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,187) of type [('expression', '-->')] for ['04620', '04931', '04931', '05321'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (521,450) of type [('activation', '-->')] for ['04620', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,1213) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (487,501) of type [('missing interaction', '-/-')] for ['04151', '04210', '04213', '04213', '04218', '04931', '05415'] appears as [('activation', '-->')] for 05417.
# ****Conflict! Rewriting as [('activation', '-->')]
# - Edge (521,191) of type [('activation', '-->')] for ['05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,321) of type [('activation', '-->')] for ['04620', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (521,353) of type [('activation', '-->')] for ['04620', '04931', '04931', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# - Edge (669,166) of type [('activation', '-->'), ('phosphorylation', '+p')] for ['04151', '04210', '04510', '04910', '04931'] appears as [('activation', '-->')] for 05417. Overwriting with type [('activation', '-->'), ('phosphorylation', '+p')]
# - Edge (521,187) of type [('activation', '-->')] for ['04620', '04931', '04931', '05321', '05417'] appears as [('expression', '-->')] for 05417.
# ****Conflict! Rewriting as [('expression', '-->')]
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed
# Wrap: more than 148 colors needed

# %%
# Build node2columns, mapping each node of G to the list of genes corresponding to it
# for which we know a value (in the genes dataframe), sorted
#

print("Mapping genes to columns")
namedGenes = set(name2gene.values())     
columns = set(genes.columns.values.tolist()[2:])
node2columns = {}
for node in G.nodes():
    nodeGenes = can2set(id2element[node])
    s = []
    for gene in nodeGenes & namedGenes:
        for k,v in name2gene.items():
            if v == gene:
                if k in columns:
                    s += [k]
    node2columns[node]=sorted(s)
# Out:
# Mapping genes to columns

# %%
if produceGraphsWithCCcoloring:
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)
        canvas = KGMLCanvas(pathway)
        for k in pathway.entries:
            name = pathway.entries[k].name
            canonicalName = set2can(words2set(name))
            if canonicalName in element2id.keys():
                node = element2id[canonicalName]
                klass = cc[node]
                if klass in nontrivialclass2col:
                    pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                    pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                else:
                    pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                    pathway.enries[k].graphics[0].fgcolor = "#FFFFFF"
                s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"
        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway)).mkdir(parents=True, exist_ok=True)
        canvas.draw(os.path.join(outputDirectory, organism, safeSuperpathway, pdfName))
    with open(os.path.join(outputDirectory, organism, safeSuperpathway, "all.tsv"), "wt") as file:
        file.write(s)

# %%
def columns2nodes(columns, node2columns, ignoreEmpty = True):
    """
        Returns a map from columns to the nodes where the column appears.
    """
    res = {} 
    for c in columns:
        s = set([])
        for no, co in node2columns.items():
            if c in co:
                s |= set([no])
        if len(s) > 0 or not ignoreEmpty:
            res[c] = s
    return res

c2n = columns2nodes(columns, node2columns)
usableColumns = list(c2n.keys())

# %%
def corrForPair(genes, set1, set2, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Given a dataframe genes (i.e., a set of patients), and two sets of column names (set1, set2), 
        compute the correlation function
        for every pair of columns in set1 and set2 and return the average statistic and its std.
    """
    taus = []
    for gene1 in set1:
        for gene2 in set2:
            expr1 = genes.loc[:,gene1].values.tolist()
            expr2 = genes.loc[:,gene2].values.tolist()
            if len(set(expr1)) == 1 or len(set(expr2)) == 1:
                continue
            taus += [correlationFunction(expr1, expr2).statistic]
    if len(taus) < 2:
        return np.nan, np.nan
    return pd.DataFrame(taus).mean().values[0], pd.DataFrame(taus).std().values[0]

# %%
def sampleDeltaDist(genes, set1, set2, numberOfRows1, numberOfSamples = 500, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Repeatedly (for numberOfSamples times) do the following:
        - select numberOfRows1 rows of genes, and then compute tauForPair on those rows for set1 and set2
        - do the same for remaining rows
        - take the difference between the two resulting set of taus.
        Return the mean and std of differences.
    """
    diffs = []
    
    for i in range(numberOfSamples):
        genes1 = random.sample(range(len(genes)), numberOfRows1)
        genes2 = list(set(range(len(genes)))-set(genes1))
        mt1, mstd1 = corrForPair(genes.iloc[genes1], set1, set2, correlationFunction)
        if np.isnan(mp1):
            continue
        mt2, mstd2 = corrForPair(genes.iloc[genes2], set1, set2, correlationFunction)
        if np.isnan(mp2):
            continue
        diffs += [mt1-mt2]
    return diffs


def deltaForPair(genes1, genes2, set1, set2, correlationFunction = lambda x,y: scipy.stats.kendalltau(x,y).statistic):
    """
        Compute corrForPair for set1 and set2 over the set of rows genes1 and genes2, and return
        the difference of taus.
    """
    mt1, mstd1 = corrForPair(genes1, set1, set2, correlationFunction)
    mt2, mstd2 = corrForPair(genes2, set1, set2, correlationFunction)
    return mt1-mt2

# %%
correlationFunction = lambda x,y:  scipy.stats.spearmanr(x,y).statistic
correlationFunctionName = "spearmanrho"
relAnomalies = os.path.join(inputDirectory, "anomalies-" + correlationFunctionName + ".csv")

if os.path.exists(relAnomalies):
    print("Reading anomalies")
    relcorrel = pd.read_csv(relAnomalies)
else:
    print("Producing anomalies")
    relcorrel = pd.DataFrame(columns=[
        "Source gene(s)",
        "Target gene(s)",
        "Pathway ID",
        "Relation type",
        "Correlation for healthy",
        "Correlation for diseased",
        "Correlation difference (H-D)",
        "Expected correlation difference",
        "P-value",
        "Comment"
        ])
    numberOfEdges = G.number_of_edges()
    doneEdges = 0
    for s,t,d in G.edges(data=True):
        if doneEdges % 10 == 0:
            print("{:.2f}% done".format(100 * doneEdges / numberOfEdges))
        doneEdges += 1
        subtypeName = [k for k,v in subtype2color.items() if d["color"]==v][0]
        sg = node2columns[s]
        tg = node2columns[t]
        if len(sg) == 0 or len(tg) == 0:
            continue
        avgh, stdh = corrForPair(genesHealthy, sg, tg, correlationFunction=correlationFunction)
        avgd, stdd = corrForPair(genesDiseased, sg, tg, correlationFunction=correlationFunction)
        taudiff = avgh - avgd
        ttn = sampleDeltaDist(genes, sg, tg, numHealthy, correlationFunction=correlationFunction)
        tt = [x for x in ttn if ~np.isnan(x)]
        if len(tt) == 0:
            continue
        ttmean = pd.DataFrame(tt).mean().values[0]
        ecdft = scipy.stats.ecdf(tt)  # Empirical CDF
        if taudiff < 0:
            pvalue = ecdft.cdf.evaluate(taudiff)
            comment = "More correlated than for healthy individuals"
        else:
            pvalue = 1 - ecdft.cdf.evaluate(taudiff)    
            comment = "Less correlated than for healthy individuals"
        if produceAnomaliesForNonsignificantPairs or produpvalue <= confidence:
            relcorrel.loc[len(relcorrel)] = [
                str(sg),
                str(tg),
                d["pathwayIDs"],
                subtypeName,
                avgh, 
                avgd,
                taudiff,
                ttmean,
                pvalue,
                comment
            ]
    relcorrel = relcorrel.sort_values(by=["P-value"], ascending=True)
    relcorrel.to_csv(relAnomalies)
# Out:
# Reading anomalies

# %%
print("Anomalies by type")
statisticallySignificant = relcorrel.loc[
    (relcorrel["P-value"]<confidence)   # Statistically significant
]

failingActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

failingInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveActivation = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("activation")) & # Activation  
    (relcorrel["Correlation difference (H-D)"]<0) # More than healthy
]

excessiveInhibition = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    (relcorrel["Relation type"].str.contains("inhibition")) & # Inhibition
    (relcorrel["Correlation difference (H-D)"]>0) # Less than healthy
]

otherTypesOfRelations = relcorrel.loc[
    (relcorrel["P-value"]<confidence) &   # Statistically significant
    ~(relcorrel["Relation type"].str.contains("activation")) & # No activation  
    ~(relcorrel["Relation type"].str.contains("inhibition"))   # No inhibition 
]

print("P-value < {:.2f}: ".format(100 * confidence / 100), len(statisticallySignificant))
print("Failing activations (green):", len(failingActivation))
print("Failing inhibitions (blue):", len(failingInhibition))
print("Excessive activations (red):", len(excessiveActivation))
print("Excessive inhibitions (orange):", len(excessiveInhibition))
print("Other types of relations (yellow):", len(otherTypesOfRelations))
print("Total:", len(failingActivation)+len(failingInhibition)+len(excessiveActivation)+len(excessiveInhibition)+len(otherTypesOfRelations))
# Out:
# Anomalies by type
# P-value < 0.05:  93
# Failing activations (green): 21
# Failing inhibitions (blue): 5
# Excessive activations (red): 13
# Excessive inhibitions (orange): 9
# Other types of relations (yellow): 43
# Total: 91

# %%
def elaborateArc(relation, sdrawing):
    source= str(node2columns[element2id[set2can(relation.source)]])
    for tg in relation.target:
        target = str(node2columns[element2id[set2can(tg)]])
        r = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
        if len(r) == 0:
            continue
        if len(r) > 1:
            pass
            #print(f"({source}, {target}) appearing more than once in relcorrel")
            #print(list(r.to_dict()["Correlation difference (H-D)"].values()))
        rd = r.to_dict()
        pvalue = list(rd["P-value"].values())[0]
        corrdiff = list(rd["Correlation difference (H-D)"].values())[0]
        relationType = list(rd["Relation type"].values())[0]
        if pvalue < confidence:        
            if "activation" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.green
                else:
                    col = reportlab.lib.colors.red
            elif "inhibition" in relationType:
                if corrdiff > 0:
                    col = reportlab.lib.colors.orange
                else:
                    col = reportlab.lib.colors.blue
            else:
                col = reportlab.lib.colors.yellow
            if np.isnan(corrdiff):
                print(f"Correlation for {source} vs. {target} is {corrdiff}")
            else:
                sdrawing.setLineWidth(3*math.exp(abs(corrdiff)*3))
                sdrawing.setStrokeColor(col)
                sdrawing.line(relation.sourceg.x, relation.sourceg.y, relation.targetg.x, relation.targetg.y)

# %%
if produceGraphsWithAnomalies:
    print("Producing anomaly PDFs")
    s = ""
    for pair in superpathwayDict[superpathway]:
        pathwayID = pair[0]
        pathway = pathwayFromFile(dataDirectory, organism, pathwayID)

        relations = []
        for relation in rel[pathwayID]:
            relations += [relation]

        canvas = KGMLCanvas(pathway)

        if useCCcoloringForAnomalies:
            for k in pathway.entries:
                name = pathway.entries[k].name
                canonicalName = set2can(words2set(name))
                if canonicalName in element2id.keys():
                    node = element2id[canonicalName]
                    klass = cc[node]
                    if klass in nontrivialclass2col:
                        pathway.entries[k].graphics[0].bgcolor = nontrivialclass2col[klass]
                        pathway.entries[k].graphics[0].fgcolor = nontrivialclass2col[klass]
                    else:
                        pathway.entries[k].graphics[0].bgcolor = "#FFFFFF"
                        pathway.entries[k].graphics[0].fgcolor = "#FFFFFF"
                    s += pathwayID + "\t" + str(node) + "\t" + str(klass) +"\t"+pathway.entries[k].graphics[0].name+"\t"+canonicalName + "\n"

        canvas.import_imagemap = True
        pdfName = organism + pathwayID + ".pdf"
        pathlib.Path(os.path.join(outputDirectory, organism, safeSuperpathway + "-anomalies")).mkdir(parents=True, exist_ok=True)
        canvas.new_draw(os.path.join(outputDirectory, organism, safeSuperpathway+ "-anomalies", pdfName), relations, elaborateArc)
# Out:
# Producing anomaly PDFs
# Correlation for ['TP53'] vs. ['AIFM2', 'PRG3'] is nan
# Correlation for ['SOST'] vs. ['HBM', 'LRP5', 'LRP6'] is nan
# Correlation for ['IFNB1'] vs. ['IFNAR1', 'IFNAR2'] is nan
# Correlation for ['IRF7'] vs. ['IFNA5', 'IFNB1'] is nan
# Correlation for ['IRF3'] vs. ['IFNA5', 'IFNB1'] is nan

# %%
print("Computing anomalies by pathway")
pathwayAnomalies = pd.DataFrame(columns=[
        "Pathway ID",
        "Pathway",
        "Average square difference",
        "Count",
        "Relative count"
        ])
for pair in superpathwayDict[superpathway]:
    pathwayID = pair[0]
    pathwayName= pair[1]
    ssqd = 0
    count = 0
    countSig = 0
    for relation in rel[pathwayID]:
        source = str(node2columns[element2id[set2can(relation.source)]])
        for targ in relation.target:
            target = str(node2columns[element2id[set2can(targ)]])
            tt = relcorrel.loc[(relcorrel["Source gene(s)"] == source) & (relcorrel["Target gene(s)"] == target)]
            if len(tt) == 1 and tt["P-value"].to_list()[0] <= confidence:
                cd = tt["Correlation difference (H-D)"].to_list()[0]
                if not np.isnan(cd):
                    ssqd += cd * cd
                    countSig += 1
            count += 1
    if count > 0:
        pathwayAnomalies.loc[len(pathwayAnomalies)]=[pathwayID, pathwayName, ssqd, countSig, countSig / count]
# Out:
# Computing anomalies by pathway

# %%
print("Sorting pathways by number of anomalies and writing it out as a csv")
relPathwayAnomalies = os.path.join(inputDirectory, "pathway-anomalies-" + correlationFunctionName + ".csv")
pathwayAnomalies = pathwayAnomalies.sort_values(by=["Count"], ascending=False)
pathwayAnomalies.to_csv(relPathwayAnomalies)
# Out:
# Sorting pathways by number of anomalies and writing it out as a csv

# %%
print("Extracting genes involved in top-k anomalous pathways and appearing as columns")
nTopAnomPathway = len(pathwayAnomalies)
topAnomPathway = pathwayAnomalies.head(nTopAnomPathway)["Pathway ID"].to_list()
anomPathwayGenes = set([])
anomPathwayGenesByPathway = defaultdict(lambda: set([]))
for pathwayId in topAnomPathway:
    for relation in rel[pathwayId]:
        anomPathwayGenes |= relation.source 
        anomPathwayGenesByPathway[pathwayId] |= relation.source 
        for t in relation.target:
            anomPathwayGenes |= t
            anomPathwayGenesByPathway[pathwayId] |= t
anomPathwayGeneNames = [name for name,gene in name2gene.items() if gene in anomPathwayGenes and name in columns]
print(len(anomPathwayGeneNames), "genes involved")
anomPathwayGenesByPathwayNames = {}
print("Genes involved by pathway")
for pathwayId in topAnomPathway:
    anomPathwayGenesByPathwayNames[pathwayId] = [name for name,gene in name2gene.items() if gene in anomPathwayGenesByPathway[pathwayId] and name in columns]
    t = len(anomPathwayGenesByPathwayNames[pathwayId])
    print(f"\t{pathwayId}: {t}")
# Out:
# Extracting genes involved in top-k anomalous pathways and appearing as columns
# 1770 genes involved
# Genes involved by pathway
# 	05417: 195
# 	00010: 65
# 	04010: 290
# 	00240: 57
# 	04218: 142
# 	04620: 87
# 	04512: 84
# 	04060: 258
# 	05205: 197
# 	04151: 304
# 	04062: 188
# 	04931: 92
# 	04910: 131
# 	04310: 164
# 	04210: 126
# 	04115: 73
# 	04611: 122
# 	04510: 206
# 	00230: 126
# 	04066: 100
# 	04213: 56
# 	04975: 11
# 	05146: 36
# 	05321: 43
# 	05415: 101
# 	04970: 52
# 	04974: 3
# 	04979: 35
# 	04145: 16
# 	04070: 86

# %%
print("Computing correlations for anomalous-pathway genes in the two populations")
healthyMatrix = genesHealthy[anomPathwayGeneNames].to_numpy() #Rows are healthy patients, columns are genes appearing in anomalous pathways
diseasedMatrix = genesDiseased[anomPathwayGeneNames].to_numpy() #Rows are diseased patients, columns are genes appearing in anomalous pathways

healthyCorr = np.corrcoef(healthyMatrix, rowvar=False) #Correlation between anomalous genes in healthy individuals
diseasedCorr = np.corrcoef(diseasedMatrix, rowvar=False) #Correlation between anomalous genes in diseased individuals
healthyCorrByPathway = {}
diseasedCorrByPathway = {}
for pathwayId in topAnomPathway:
    healthyMatrix = genesHealthy[anomPathwayGenesByPathwayNames[pathwayId]].to_numpy() #Rows are healthy patients, columns are genes appearing in anomalous pathways
    diseasedMatrix = genesDiseased[anomPathwayGenesByPathwayNames[pathwayId]].to_numpy() #Rows are healthy patients, columns are genes appearing in anomalous pathways
    healthyCorrByPathway[pathwayId] = np.corrcoef(healthyMatrix, rowvar=False)
    diseasedCorrByPathway[pathwayId] = np.corrcoef(diseasedMatrix, rowvar=False)
# Out:
# Computing correlations for anomalous-pathway genes in the two populations
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/boldi/.local/share/virtualenvs/HyperFibrations-l1h_g1LE/lib/python3.9/site-packages/numpy/lib/function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
pd.DataFrame(data=healthyCorr, columns=anomPathwayGeneNames).to_csv("/tmp/matrices/healthy-all.csv")
pd.DataFrame(data=diseasedCorr, columns=anomPathwayGeneNames).to_csv("/tmp/matrices/diseased-all.csv")
for pathwayId in topAnomPathway:
    pd.DataFrame(data=healthyCorrByPathway[pathwayId], columns=anomPathwayGenesByPathwayNames[pathwayId]).to_csv("/tmp/matrices/healthy-" + pathwayId + ".csv")
    pd.DataFrame(data=diseasedCorrByPathway[pathwayId], columns=anomPathwayGenesByPathwayNames[pathwayId]).to_csv("/tmp/matrices/diseased-" + pathwayId + ".csv")

# %%
feb = pd.read_csv("../../LaTeX/Data/KEGG-Pathways/Feb2024/pathway-anomalies-spearmanrho.csv").drop(["Count", "Relative count", "Unnamed: 0"], axis=1).set_index("Pathway ID")
mar = pd.read_csv("../../LaTeX/Data/KEGG-Pathways/Mar2024/pathway-anomalies-spearmanrho.csv").drop(["Count", "Relative count", "Unnamed: 0"], axis=1).set_index("Pathway ID")

# %%
both = feb.join(mar, on="Pathway ID", lsuffix="_feb", rsuffix="_mar")
both["SS"] = both["Average square difference_feb"] * both["Average square difference_mar"]
both = both.sort_values(by=["SS"], ascending=False)

# %%
both
# Out:
#                                                 Pathway_feb
# Pathway ID
# 5417                              Lipid and atherosclerosis  \
# 4010                                 MAPK signaling pathway
# 4218                                    Cellular senescence
# 4931                                     Insulin resistance
# 5205                                Proteoglycans in cancer
# 4060                 Cytokine-cytokine receptor interaction
# 4115                                  p53 signaling pathway
# 4310                                  Wnt signaling pathway
# 240                                   Pyrimidine metabolism
# 4620                   Toll-like receptor signaling pathway
# 230                                       Purine metabolism
# 4062                            Chemokine signaling pathway
# 4512                               ECM-receptor interaction
# 4151                             PI3K-Akt signaling pathway
# 4210                                              Apoptosis
# 5321                             Inflammatory bowel disease
# 4910                              Insulin signaling pathway
# 10                             Glycolysis / Gluconeogenesis
# 4611                                    Platelet activation
# 4510                                         Focal adhesion
# 4213        Longevity regulating pathway - multiple species
# 5415                                Diabetic cardiomyopathy
# 4975                           Fat digestion and absorption
# 4066                                HIF-1 signaling pathway
# 4070                  Phosphatidylinositol signaling system
# 4970                                     Salivary secretion
# 4145                                              Phagosome
# 4974                       Protein digestion and absorption
# 4979                                 Cholesterol metabolism
# 5146                                             Amoebiasis
#
#             Average square difference_feb
# Pathway ID
# 5417                             0.625288  \
# 4010                             0.828898
# 4218                             0.609202
# 4931                             0.470507
# 5205                             0.610077
# 4060                             0.253874
# 4115                             0.331166
# 4310                             0.413964
# 240                              0.409587
# 4620                             0.180650
# 230                              0.725467
# 4062                             0.393130
# 4512                             0.193051
# 4151                             0.349093
# 4210                             0.239570
# 5321                             0.541599
# 4910                             0.269982
# 10                               0.105384
# 4611                             0.232881
# 4510                             0.258699
# 4213                             0.201630
# 5415                             0.156905
# 4975                             0.087746
# 4066                             0.021271
# 4070                             0.554156
# 4970                             0.187899
# 4145                             0.000000
# 4974                             0.000000
# 4979                             0.000000
# 5146                             0.000000
#
#                                                 Pathway_mar
# Pathway ID
# 5417                              Lipid and atherosclerosis  \
# 4010                                 MAPK signaling pathway
# 4218                                    Cellular senescence
# 4931                                     Insulin resistance
# 5205                                Proteoglycans in cancer
# 4060                 Cytokine-cytokine receptor interaction
# 4115                                  p53 signaling pathway
# 4310                                  Wnt signaling pathway
# 240                                   Pyrimidine metabolism
# 4620                   Toll-like receptor signaling pathway
# 230                                       Purine metabolism
# 4062                            Chemokine signaling pathway
# 4512                               ECM-receptor interaction
# 4151                             PI3K-Akt signaling pathway
# 4210                                              Apoptosis
# 5321                             Inflammatory bowel disease
# 4910                              Insulin signaling pathway
# 10                             Glycolysis / Gluconeogenesis
# 4611                                    Platelet activation
# 4510                                         Focal adhesion
# 4213        Longevity regulating pathway - multiple species
# 5415                                Diabetic cardiomyopathy
# 4975                           Fat digestion and absorption
# 4066                                HIF-1 signaling pathway
# 4070                  Phosphatidylinositol signaling system
# 4970                                     Salivary secretion
# 4145                                              Phagosome
# 4974                       Protein digestion and absorption
# 4979                                 Cholesterol metabolism
# 5146                                             Amoebiasis
#
#             Average square difference_mar        SS
# Pathway ID
# 5417                             1.962452  1.227097
# 4010                             0.869938  0.721090
# 4218                             0.690115  0.420420
# 4931                             0.746365  0.351169
# 5205                             0.428428  0.261374
# 4060                             0.875745  0.222329
# 4115                             0.622686  0.206212
# 4310                             0.429984  0.177998
# 240                              0.424209  0.173751
# 4620                             0.935194  0.168943
# 230                              0.226474  0.164300
# 4062                             0.390351  0.153458
# 4512                             0.773692  0.149362
# 4151                             0.387528  0.135283
# 4210                             0.546943  0.131031
# 5321                             0.210383  0.113943
# 4910                             0.358141  0.096691
# 10                               0.698681  0.073630
# 4611                             0.280477  0.065318
# 4510                             0.248795  0.064363
# 4213                             0.314748  0.063463
# 5415                             0.148089  0.023236
# 4975                             0.056692  0.004975
# 4066                             0.163584  0.003480
# 4070                             0.000000  0.000000
# 4970                             0.000000  0.000000
# 4145                             0.000000  0.000000
# 4974                             0.000000  0.000000
# 4979                             0.000000  0.000000
# 5146                             0.226558  0.000000
